# %%
import pickle
import csv
from pprint import pprint as myprint
from bs4 import BeautifulSoup as bs
import thulac

# %%
# html_file = open(r"../tmp/html.txt","r",encoding="utf-8")
# html_string = html_file.read()
# html_file.close()
# soup = bs(html_string,"html5lib")
# root = soup.html.body
# print(root.prettify())

# %% [markdown]
# 再次读取的时候，发现原有的层次结构被破化了,应该考虑别的方法存储BeautifulSoup对象而非使用字符串，另一种思路是继续在bigram2html文件中写下去
# Python对象的序列化可以使用pickle模块来实现

# %%
html_file_b = open(r"../tmp/html.dat","rb")
soup = pickle.load(html_file_b)
root = soup.html.body

# %% [markdown]
# 恢复二进制文件到对象

# %%
for item in list(root.descendants)[:20]:
    if isinstance(item,str):
        continue
    print(item.name,item.parent.name)
# Out:
# h1 body
# h2 h1
# h3 h2
# h3 h2
# h4 h3
# h4 h3
# h4 h3
# h4 h3
# h4 h3
# h4 h3

# %% [markdown]
# 此处遍历的顺序是无所谓的，但是BeautifulSoup按照预期的顺序遍历了，也就是创建时的顺序

# %%
triple_list = []
course_name = "信息资源建设"
verb = "sub-concept"
i = 1
for item in root.descendants:
    if isinstance(item,str):
        continue
    sbj = item.contents[0]
    if item.parent.name == "body":
        obj = course_name
    else:
        obj = item.parent.contents[0]
    triple_list.append((sbj,verb,obj))
myprint(triple_list[:20])
# Out:
# [('信息、信息媒体与信息资源', 'sub-concept', '信息资源建设'),
#  ('信息概述', 'sub-concept', '信息、信息媒体与信息资源'),
#  ('信息的定义从广义上理解，信息可以被认为是物质的一种属性，是物质存在方式和运动规律与特点的表现形式。从狭义上理解，信息是一种消息、信号、数据或资料，是用来消除不定性的东西。',
#   'sub-concept',
#   '信息概述'),
#  ('信息的特征', 'sub-concept', '信息概述'),
#  ('真实性', 'sub-concept', '信息的特征'),
#  ('知识性', 'sub-concept', '信息的特征'),
#  ('指向性', 'sub-concept', '信息的特征'),
#  ('共享性', 'sub-concept', '信息的特征'),
#  ('无限性', 'sub-concept', '信息的特征'),
#  ('时效性', 'sub-concept', '信息的特征'),
#  ('依附性', 'sub-concept', '信息的特征'),
#  ('信息的种类', 'sub-concept', '信息概述'),
#  ('按信息的产生和作用机制划分，有自然信息和社会信息两大类；', 'sub-concept', '信息的种类'),
#  ('按信息是否被人感知来划分，有显性信息和隐性信息两大类；', 'sub-concept', '信息的种类'),
#  ('按信息的运动状态来划分，有动态信息和静态信息两大类；', 'sub-concept', '信息的种类'),
#  ('按信息的存在和接受情况划分，有直接信息和间接信息两大类。', 'sub-concept', '信息的种类'),
#  ('信息的功能与作用', 'sub-concept', '信息概述'),
#  ('维系社会存在与发展', 'sub-concept', '信息的功能与作用'),
#  ('社会经济发展的动力', 'sub-concept', '信息的功能与作用'),
#  ('科学决策、科学研究和生产建设的参谋和依据', 'sub-concept', '信息的功能与作用')]

# %% [markdown]
# 遍历html文档树的所有节点，并获得其父节点，子结点与父节点之间存在着语义上的被包含与包含关系

# %%
trigram_file = open(r"../tmp/trigram.csv","w",encoding="utf-8")
csv_writer = csv.writer(trigram_file)
for item in triple_list:
    csv_writer.writerow(item)
trigram_file.close()

# %% [markdown]
# 将结果写在csv文件中，同样暂时没有什么用，只是保存当前成果

# %%
stop_set = set()
stop_list_file_1 = open(r"../stoplist/哈工大停用词表.txt","r",encoding="utf8")
stop_list_file_2 = open(r"../stoplist/百度停用词表.txt","r",encoding="utf8")
stop_list_file_3 = open(r"../stoplist/中文停用词表.txt","r",encoding="utf8")
stop_list_file_4 = open(r"../stoplist/四川大学机器智能实验室停用词库.txt","r",encoding="utf8")
for word in stop_list_file_1.readlines():
    stop_set.add(word.strip())
for word in stop_list_file_2.readlines():
    stop_set.add(word.strip())
for word in stop_list_file_3.readlines():
    stop_set.add(word.strip())
for word in stop_list_file_4.readlines():
    stop_set.add(word.strip())
print(stop_set)
# Out:
# {'', '每逢', '趁势', '尽如人意', '）÷（１－', 'thus', '大举', '故', '能够', '以故', '目前', '并且', 'before', '尽管如此', 'am', '严格', 'appear', 'toward', '若果', '愿意', '不料', '根本', '或曰', '怪不得', '漫说', '［①ｉ］', '＜λ', '结果', 'probably', 'ask', '极其', '取道', '其', '只是', '战斗', '凝神', 'alone', '数/', '除却', 'go', 'obviously', '容易', '然而', '对待', "they've", '当庭', 'across', 'hereupon', 'provides', '反倒', '不亦乐乎', '立时', '安全', 'yourselves', '论', '应用', '成为', 'cause', 'lately', '.数', '于是', 'able', '不定', '独自', '连声', '切不可', 'become', '不拘', '是', 'our', 'consider', '顷刻间', '打开天窗说亮话', '要', '属于', '敢于', '一样', '如何', '甚至于', '首先', '~~~~', '这一来', 'already', '由是', 'certain', 'exactly', '前面', 'apart', 'brief', '藉以', '此处', 'whole', '下面', '以免', 'wants', '进入', '前后', 'within', '可见', '向使', ')', 'thereby', '每个', '＝', 'at', '前此', '至于', '℃', 'here', '它', '三番两次', '能', '着呢', '基本上', 'five', '因此', "it'll", '每年', 'he', '上述', '正如', '不由得', '喏', '并不是', 'say', '尽然', '但凡', "couldn't", '末##末', '从中', 'not', '所以', '一定', '完成', '产生', '恰如', '沙沙', '举凡', 'shall', '默然', '_', '究竟', 'away', '分头', '除非', '若是', '越是', '大大', '或许', 'whence', '既然', '说明', '按期', '嘻', '着', 'throughout', '*', '也', '中小', '她们', 'seeing', 'forth', '何时', '［①④］', '慢说', '呃', '鉴于', '这个', '清楚', "it's", '起来', '传闻', '叫', 'theirs', 'been', '怎么办', 'others', '决非', '今後', '［③］', '当然', '趁', '.一', '那时', 'seen', '长话短说', '且说', '使得', '这么点儿', '弹指之间', '别人', '来说', '向', '｛－', 'three', 'ours', '少数', '这般', 'myself', '一致', '下来', '略为', '合理', '牢牢', '从头', '恐怕', '再者说', '被', '千万千万', 'you', '更加', 'comes', '不怎么', '譬如', '几经', '专门', '要不然', '具体', 'anyways', '巴', '贼死', 'whose', '另方面', '遵循', '日见', '不怕', '反之亦然', '有所', '而且', '您们', '打', '非特', '大概', '特别是', '哈哈', 'likely', '竟然', 'cannot', 'contains', '依', '宁可', '互相', '.日', '问题', '就是说', '任', '［①Ａ］', '不论', 'used', '近年来', '最', '连日', '何以', 'th', '［', '该当', '有时', '各位', '别是', '岂非', 'Δ', '［①①］', '除去', '此间', 'lest', '自从', 'against', 'latter', '一转眼', '偶尔', 'nearly', '自后', '凡', 'other', '今', '难得', '顺着', '看', '严重', '同一', '无宁', '［⑤ｅ］', '哪', '便于', '即便', 'like', '～＋', '略微', 'way', '一边', 'just', 'currently', '过去', '不可', '顺', '出现', 'plus', "they'd", '［③ｄ］', '的话', '［①］', '今年', 'many', '庶几', '全年', '较之', 'example', '倒不如', '归齐', ']', '却', '多多少少', '挨着', '云云', '不但', 'him', 'one', '她是', '欢迎', '间或', 'γ', '而况', 'after', 'must', '进步', '↑', 'self', '替', 'mean', '不光', 'wish', '具体地说', 'of', '宣布', '趁着', '［①Ｄ］', '遇到', '到了儿', '宁愿', '［①ｄ］', '１２％', '为止', '会', '认识', '/', '嗡嗡', '尽量', '仍', 'it', '虽则', '必将', '许多', '２．３％', '依照', '［－', '不至于', '［①Ｂ］', '各级', '广泛', '当', 'appreciate', '来讲', '适当', '暗中', '照着', '何况', 'themselves', 'inward', '之前', '＝☆', '不得已', '极了', 'hello', '向着', '同时', 'merely', '//', '除此', '不比', '交口', '不过', '-', '归', '方才', '赶早不赶晚', '那边', 'try', '可以', '嗬', '随', 'φ．', '诸如', '到处', 'goes', '+', '非徒', '用', 'done', 'respectively', '不问', "hasn't", 'should', '［③ａ］', '不是', '不再', 'containing', 'to', 'qv', '多次', '得起', '［④ｂ］', '背地里', '反应', '这', '::', '乘', 'often', '倘然', 'might', '简而言之', '无', 'welcome', 'use', '起首', '现在', '之後', 'whenever', '呀', '始而', '除了', '自家', '于', '从严', '》', '有及', '每时每刻', '以前', '切莫', '一片', 'via', 'further', '差不多', 'going', '大家', '眨眼', '从古到今', '设或', 'selves', '突然', '下去', 'those', '与否', '动辄', '嘎登', '或则', '从未', '＝″', '特点', '［①②］', '上下', '为何', 'the', '倒是', '限制', 'corresponding', 'by', '何乐而不为', '难说', 'actually', '来', 'eg', '基本', '策略地', 'unless', '［③ｃ］', '此地', '不起', '■', 'along', '八成', '经过', 'six', 'sensible', '赶快', '它是', '──', '矣乎', '这种', 'wonder', '难道', '哗', 'or', '意思', '下', 'ZT', '而论', '必要', '更进一步', '哉', '则', '并没有', '得了', '般的', '到', '}', '(', '失去', '随着', '不如', '先不先', 'everything', 'would', '得到', 'everywhere', 'among', '［⑤ｄ］', '／', '她', 'ever', 'up', '从速', "where's", '大致', '以至', '又及', '竟而', '你', 'than', 'did', '沿', '以後', '这么样', '不尽', '依据', '正在', '）、', '不日', '哪个', '比方', '格外', "don't", '迅速', '快要', '尔', '不妨', '呢', '毕竟', 'will', '嗡', '来着', '豁然', '呵呵', '有着', 'Lex', 'normally', '归根到底', 'has', 'specifying', '那样', '不巧', '加以', '乃至', '几乎', '良好', '乃', 'us', '至若', 'these', '到目前为止', '啦', '全身心', '＋＋', '随著', '［②Ｇ］', '啊哈', '［②⑤］', '奋勇', '坚持', '谁知', '万一', '先生', '大约', 'may', '＞', '别说', ...

# %% [markdown]
# 准备一个停用词表

# %%
thu = thulac.thulac(seg_only=True)
s_string,verb,o_string = triple_list[2]
# s_list = thu.cut(s_string,text=False)
s_list = [word for word,pos in thu.cut(s_string,text=False) if word not in stop_set]
print(s_list)
# Out:
# Model loaded succeed
# ['信息', '定义', '广义', '理解', '信息', '物质', '属性', '物质', '方式', '运动', '规律', '表现', '形式', '狭义', '理解', '信息', '消息', '信号', '数据', '资料', '消除', '定性', '东西']

# %% [markdown]
# 测试分词的功能是否可用

# %%
triple_set = set()
thu = thulac.thulac(seg_only=True)
for s_string,v_string,o_string in triple_list:
    s_list = [word for word,pos in thu.cut(s_string,text=False) if word not in stop_set]
    o_list = [word for word,pos in thu.cut(o_string,text=False) if word not in stop_set]
    for s in s_list:
        for o in o_list:
            triple_set.add((s,verb,o))    
myprint(list(triple_set)[:20])
# Out:
# Model loaded succeed
# [('纸质', 'sub-concept', '信息'),
#  ('两', 'sub-concept', '居多'),
#  ('出版', 'sub-concept', '手段'),
#  ('组织', 'sub-concept', '看法'),
#  ('中', 'sub-concept', '版式'),
#  ('磁带', 'sub-concept', '称'),
#  ('媒体', 'sub-concept', '卷'),
#  ('种类', 'sub-concept', '资源'),
#  ('数量', 'sub-concept', '名称'),
#  ('完整', 'sub-concept', '类型'),
#  ('记载', 'sub-concept', '超过'),
#  ('隐蔽', 'sub-concept', '客观'),
#  ('索取', 'sub-concept', '类型'),
#  ('易于', 'sub-concept', '媒体'),
#  ('作用', 'sub-concept', '极'),
#  ('源优点', 'sub-concept', '客观'),
#  ('表现', 'sub-concept', '类型'),
#  ('有限', 'sub-concept', '媒体'),
#  ('电', 'sub-concept', '内容'),
#  ('人才', 'sub-concept', '版式')]

# %% [markdown]
# 至此，一篇文档就由文本转换成了三元组
# 浏览上面的结果，目前比较难判断处理的效果，但是从一些元组中可以明显看到可用的逻辑
# 对于并不很严肃的课件能得到这样的结果是满意的

# %%
trigram_file_update = open(r"../tmp/trigram_update.csv","w",encoding="utf-8")
csv_writer = csv.writer(trigram_file_update)
for item in triple_set:
    csv_writer.writerow(item)
trigram_file_update.close()

# %% [markdown]
# 写入三元组列表到csv文件中备用

# %%
trigram_b = open(r"../tmp/trigram.dat","wb")
pickle.dump(triple_set,trigram_b)
trigram_b.close()

# %% [markdown]
# 保存三元组列表到二进制文件
