# %%
import pickle
import csv
from pprint import pprint as myprint
from bs4 import BeautifulSoup as bs
import thulac

# %%
html_file = open(r"../tmp/html.txt","r",encoding="utf-8")
html_string = html_file.read()
html_file.close()
soup = bs(html_string,"html5lib")
root = soup.html.body
print(root.prettify())
# Out:
# <body>
#  <h1>
#   信息、信息媒体与信息资源
#  </h1>
#  <h2>
#   信息概述
#  </h2>
#  <h3>
#   信息的定义从广义上理解，信息可以被认为是物质的一种属性，是物质存在方式和运动规律与特点的表现形式。从狭义上理解，信息是一种消息、信号、数据或资料，是用来消除不定性的东西。
#  </h3>
#  <h3>
#   信息的特征
#  </h3>
#  <h4>
#   真实性
#  </h4>
#  <h4>
#   知识性
#  </h4>
#  <h4>
#   指向性
#  </h4>
#  <h4>
#   共享性
#  </h4>
#  <h4>
#   无限性
#  </h4>
#  <h4>
#   时效性
#  </h4>
#  <h4>
#   依附性
#  </h4>
#  <h3>
#   信息的种类
#  </h3>
#  <h4>
#   按信息的产生和作用机制划分，有自然信息和社会信息两大类；
#  </h4>
#  <h4>
#   按信息是否被人感知来划分，有显性信息和隐性信息两大类；
#  </h4>
#  <h4>
#   按信息的运动状态来划分，有动态信息和静态信息两大类；
#  </h4>
#  <h4>
#   按信息的存在和接受情况划分，有直接信息和间接信息两大类。
#  </h4>
#  <h3>
#   信息的功能与作用
#  </h3>
#  <h4>
#   维系社会存在与发展
#  </h4>
#  <h4>
#   社会经济发展的动力
#  </h4>
#  <h4>
#   科学决策、科学研究和生产建设的参谋和依据
#  </h4>
#  <h2>
#   信息媒体
#  </h2>
#  <h3>
#   信息媒体的含义信息与信息载体是密不可分的，没有载体，信息就无法存在。我们现在所称的载体，客观上有两大类：
#  </h3>
#  <h4>
#   信息载体，又称软载体或第一载体，指信息、知识得以表达、存在的语言、文字、符号、声波、光波、电波等用于直接承载信息的载体；
#  </h4>
#  <h4>
#   载体的载体，又称硬载体或第二载体。指承载信息、知识的物质载体，如纸张、胶片、磁带、磁盘、光盘等。只有第一载体和第二载体有机结合，信息才能得到永久的保存、加工和传递。人类信息交流时常用的信息源
#  </h4>
#  <h4>
#   口头信息源优点：（1）获得信息直接、迅速；（2）信息内容新；（3）针对性强；（4）信息反馈及时；（5）可以提供其他信息源不能包含的许多细节。缺点：（1）瞬时性，不能够保存；（2）主观随意性强，可靠性不足；（3）传递范围有限，且辗转传递信息容易失真。
#  </h4>
#  <h4>
#   实物信息源（1）真实可靠；（2）信息浓度大；（3）易于开发利用。（1）传递不方便；（2）信息隐蔽，有时不易提取。
#  </h4>
#  <h4>
#   文献信息源信息可以通过人脑、实物和文献得以存在和表现，但只有文献才是专门用来存储和传递信息的信息媒体。信息媒体的定义：信息媒体是指所有记录有信息，并专门用于保存和传递信息的物质载体。信息媒体是我们能够实际掌握的信息，是信息资源建设的对象。
#  </h4>
#  <h3>
#   信息媒体的构成要素
#  </h3>
#  <h4>
#   信息内容指信息媒体所表述的思想意识、知识、情报、信息的内容。
#  </h4>
#  <h4>
#   信息符号指信息内容的标识符号和表达手段。
#  </h4>
#  <h4>
#   载体材料指信息内容存贮的依附体或媒介。
#  </h4>
#  <h4>
#   记录方式指将信息符号所代表的信息内容存贮到载体材料上的方式。
#  </h4>
#  <h2>
#   信息资源
#  </h2>
#  <h3>
#   信息资源的含义目前有多种看法：
#  </h3>
#  <h4>
#   信息资源等同于文献资源；
#  </h4>
#  <h4>
#   信息资源等价于数据信息；
#  </h4>
#  <h4>
#   信息资源是多种媒介和形式的信息总称；
#  </h4>
#  <h4>
#   信息资源是信息活动中各种要素的总称，包括信息、设备、技术和人等。综合国内外目前比较流行的观点，我们可以把人们对信息资源概念的理解归纳为两大类：一类是狭义的理解，即从信息本体出发，认为信息资源是经过人类选择、组织、序化并大量积累起来的有用信息的集合。另一类是广义的理解，即认为信息资源是指人类社会活动中所积累的信息，以及创造信息的人和相关信息技术的集合。我们对信息资源的定义：在人类信息活动中产生的，并经过人们的选择、收集、组织、加工、存贮、转换等过程而形成的可利用的信息集合。这个定义的要点：
#  </h4>
#  <h4>
#   信息资源是信息的集合；
#  </h4>
#  <h4>
#   信息资源对信息是有选择的；
#  </h4>
#  <h4>
#   信息资源是可利用的；
#  </h4>
#  <h4>
#   信息资源是经过组织和有序化的；
#  </h4>
#  <h4>
#   信息资源是通过人类的一系列劳动而建设起来的。
#  </h4>
#  <h3>
#   信息资源的特性：
#  </h3>
#  <h4>
#   可建设性
#  </h4>
#  <h4>
#   再生性
#  </h4>
#  <h4>
#   动态性
#  </h4>
#  <h4>
#   冗余性
#  </h4>
#  <h4>
#   价值的潜在性
#  </h4>
#  <h3>
#   信息资源的种类：
#  </h3>
#  <h4>
#   按照信息载体的形式进行划分，有纸张印刷型、缩微型、视听型、电子型、网络型；
#  </h4>
#  <h4>
#   按照信息资源的编辑出版形式进行划分，有图书、期刊、科技报告、专利文献、会议文献、政府出版物、学位论文、标准文献、产品样本等。
#  </h4>
#  <h4>
#   按照信息资源的维护和使用权限划分，有：永久保存型指信息服务机构需要长期入藏的信息资源，如纸本书刊、光盘等。镜像服务型主要指国内外一些大型数据库，通过镜像的方式拷贝到本地的服务器上供用户存取。尽管这类资源的保存和维护责任不由自己承担，但它使用起来就如同自己的资源一样方便、快捷。网络服务型如远程数据库，存放在远程服务器上，并由其他机构负责管理和维护，使用者通过一定的协议取得对该资源的存取权限，并在自己的网页上设置连接点，点击接点登录并使用该资源库。链接存取型主要是对网络上的各类免费使用的数据库资源进行捕获和筛选，并通过组织资源导航链接而进行信息的存取。思考题
#  </h4>
#  <h4>
#   什么是信息？信息有那些基本特征？
#  </h4>
#  <h4>
#   常用的信息源有哪些？它们各有什么优缺点？
#  </h4>
#  <h4>
#   什么是信息媒体？信息媒体的构成要素有哪些？
#  </h4>
#  <h4>
#   什么是信息资源？信息资源的特征是什么？
#  </h4>
#  <h4>
#   信息资源的类型是怎样划分的？
#  </h4>
#  <h1>
#   纸质信息资源纸质信息资源是指包括各种以纸张材料为载体，以印刷、手写、复制等为记录手段而形成的各种信息媒体的集合。
#  </h1>
#  <h2>
#   图书
#  </h2>
#  <h3>
#   定义ISO规定，49页及49页以上，构成一个单元的文献（不包括封面和扉页）。UNISCO规定，图书是指49页以上（不含封面）的非定期出版物。我们的定义：图书是通过一定的方法与手段，将知识内容以一定形式的符号，按照一定的体例，系统地记录于一定形态的载体之上，用以表达思想、积累经验、保存知识、传递信息的工具。
#  </h3>
#  <h2>
#   期刊期刊是一种定期或不定期的连续出版物，以定期的居多，出版周期一般不超过一年，具有固定的名称和统一的版式，使用连续的卷、期和年月顺序号，各期内容不重复，登载多个作者的多篇文章，极少有再版。
#  </h2>
#  <h3>
#   学术性期刊的作用1   是科学技术成就的记载；2   是传递学术信息的重要媒体；3   能够培养和发现人才；4能够检阅单位和个人的研究成果
#  </h3>
#  <h3>
#   核心期刊布拉德福搜集了一年中登载了电技术方面论文的所有期刊共284种，并按照每种期刊登载电技术方面论文数量的多少排序。经过统计他发现，登载电技术论文最多的前10种期刊，包含了全部电技术论文的1/3；而紧接着的49种期刊，也登载了1/3的论文；而剩下的1/3的论文，则是由225种期刊登载的。于是，布拉德福得出结论：在登载某一学科文献的所有期刊中，存在着由若干种期刊构成的核心区域，在其周围还有另外两个区域，其中的每一个区域都含有与核心区域中数量相等的该学科文献。那么，第二区域的期刊数量为核心区域期刊数量的n倍，而第三区域的期刊数量则为核心区域期刊数量的n2倍。
#  </h3>
#  <h2>
#   期刊即P1 : p2 : p3 = 1: n : n2n ≈5如下图：这就是著名的布拉德福文献分布定律。人们据此就将核心区域的期刊称为核心期刊。1    n    n2.核心期刊定义：核心期刊又称重点期刊，是指那些学科信息含量大，代表该学科发展水平，所刊载的论文使用寿命长，利用率较高的期刊。.判别核心期刊的标准：（1）期刊论文的被摘率；（2）期刊论文的被引用率；（3）期刊流通过程中的读者利用率。
#  </h2>
#  <h2>
#   其他类型的纸质信息资源
#  </h2>
#  <h3>
#   科技报告也称研究报告或技术报告，是研究课题进展期情况的实际记录与研究成果的系统总结。.美国著名的四大报告：PB 报告——政府研究报告AD报告——国防部研究报告NASA报告——国家宇航局报告DOE报告——国家能源部报告科技报告一般分为机密、秘密、非密限制发行和非密公开发行四个密级。每种报告都有特定的代号。
#  </h3>
#  <h3>
#   政府出版物联合国教科文组织规定，凡根据国家机关的命令，并且由国家负担经费而出版的一切记录，都是政府出版物。包括：国会记录、司法资料、方针政策、规章制度、政府报告、政府决议以及调查、统计资料等。由于是官方正式出版，信息内容准确、权威，是政务信息和决策信息的重要来源。
#  </h3>
#  <h3>
#   会议文献指在国内外各种学术会议上宣读或交流的论文、报告以及由会议编辑的会议录等。会议文献具有以下特点：（1）传递信息新颖及时；（2）信息的针对性强；（3）集中反映了各种观点；（4）能够获得许多难得的信息。会议文献的不足是：反映的信息不够完整、准确。
#  </h3>
#  <h3>
#   学位论文指研究机构、高等院校的研究生为获取学位而撰写的学术论文。学位论文的作用表现在：（1）了解一门学科或课题研究的历史与现状；（2）作为重要的书目参考工具或原始情报源；（3）帮助确定研究选题；（4）开发院校课程内容。学位论文的收集、利用目前极不理想。
#  </h3>
#  <h3>
#   专利文献指伴随各种发明的专利申请、审查、确认和公布而产生的一系列文献，主要是专利说明书。专利文献具有新颖性、实用性和详细性的特征。专利文献的作用表现在：（1）避免研究的重复；（2）在引进或输出技术时获得知识产权保护或规避侵权；（3）了解竞争对手的技术实力；（4）在不侵权的情况下直接利用专利技术。
#  </h3>
#  <h3>
#   标准文献指由各种技术标准、具有标准性质的文件、标准分类表和标准检索工具所构成的文献体系，其中技术标准是最有信息价值的部分。技术标准分为国际标准、国家标准、行业标准和企业自定标准。技术标准的作用表现在：（1）获得先进、完整、可靠的技术内容，促进生产经营活动与社会大生产协调一致；（2）作为引进或输出产品时对产品质量进行检测的依据；
#  </h3>
#  <h3>
#   产品样本又称产品资料。指由各公司、企业为推销自己的产品而编印的出版物或商业宣传品。产品资料反映的技术比较成熟，数据真实可靠，对企业进行产品设计、技术模仿、开展技术合作、国内外贸易有重要参考价值。产品资料通常是免费发放或免费索取。
#  </h3>
#  <h1>
#   思考题
#  </h1>
#  <h4>
#   什么是核心期刊？怎样判别核心期刊？
#  </h4>
#  <h4>
#   什么是科技报告？美国的四大报告是指哪些科技报告？
#  </h4>
#  <h4>
#   什么是政府出版物？它有什么作用？
#  </h4>
#  <h4>
#   什么是会议文献？它有什么特点？
#  </h4>
#  <h4>
#   什么是学位论文？它有什么作用？
#  </h4>
#  <h4>
#   什么是专利文献？它有什么特点与作用？
#  </h4>
#  <h4>
#   什么是标准文献？它有什么作用？
#  </h4>
#  <h1>
#   非纸质信息资源
#  </h1>
#  <h2>
#   缩微型信息资源
#  </h2>
#  <h3>
#   含义缩微型信息资源是各种缩微资料的总称。它利用摄影的方法，把纸张型文献缩小或把电子型文献转换后直接输出在感光胶卷或胶片上，然后借助于专门的阅读设备进行阅读。
#  </h3>
#  <h3>
#   主要类型缩微型文献主要有两种类型：（1）缩微胶卷用成卷的感光胶片连续拍摄而成的缩微复制品，规格多为16毫米，长度30或50米。（2）缩微胶片用专门的缩微照相机将原始信息媒体的内容拍摄在感光胶片上而成的一种缩微复制品，标准规格为148×105毫米，一张普通的缩微胶片能够拍摄98页印刷品，超缩微片能够拍摄2500—3200页，而现在的特超缩微片能够拍摄22500页。
#  </h3>
#  <h3>
#   主要优点与纸张型信息媒体相比，缩微型信息媒体有许多优点：（1）体积小，重量轻，便于收藏，节省存贮空间；（2）规格统一，存贮标准，适于计算机自动化检索和自动化管理；（3）生产迅速，制造成本低，价格便宜；（4）复制性能好；（5）技术成熟，具有法律效力。
#  </h3>
#  <h3>
#   主要缺点（1）通过荧光屏阅读，眼睛易疲劳；（2）需要专门场所与设备，使用不方便；（3）存贮环境条件要求较严格。随着计算机的广泛应用，计算机技术与缩微技术相结合，产生了CAR、COM、CIM ，为缩微型信息资源的普及创造了有利的条件。CAR  (Computer Assisted Retrieval)，计算机辅助检索缩微品的设备COM (Computer  Output  Microfilm)，计算机自动输出缩微品的设备CIM  (Computer  Input  Microfilm)，计算机自动读入缩微品的设备
#  </h3>
#  <h2>
#   视听型信息资源主要是以磁性材料和感光材料为载体，借助特殊的机械装置，直接记录声音和图像信息而产生的一种信息媒体类型。根据人的感观接受方式，视听型信息媒体又有三种类型:. 听觉资料如录音带、唱片等. 视觉资料如幻灯片、无声电影片等. 视听资料如录像带、有声电影片等
#  </h2>
#  <h3>
#   视听型信息资源在信息交流中的独特作用：（1）历史凭证作用；（2）科学研究作用；（3）广泛传播作用；（4）宣传教育作用；（5）艺术欣赏作用。
#  </h3>
#  <h2>
#   电子型信息资源通常是指以磁性材料或特殊的光敏材料为载体，以数字代码和图像为信息符号，用编码和程序设计的手段，通过计算机存贮和显示信息的一类信息媒体。
#  </h2>
#  <h3>
#   常见类型目前常见的实体形电子信息资源的载体主要有：磁带、磁盘、光盘、芯片等。
#  </h3>
#  <h3>
#   优点
#  </h3>
#  <h4>
#   能够高密度、大容量存贮信息如一张直径13厘米的光盘，存贮量达到了1000兆字节，相当于830张高密度软磁盘。
#  </h4>
#  <h4>
#   能高效率、多功能加工、转换信息；
#  </h4>
#  <h4>
#   信息存取速度快如光盘尽管存贮量巨大，但随机读取信息时平均寻址时间却低于0.1秒。
#  </h4>
#  <h4>
#   借助通讯线路，能够实现信息的远距离传输；
#  </h4>
#  <h4>
#   可以同时存贮多种类型的信息如同时存贮文字、声音和图象等。
#  </h4>
#  <h2>
#   电子出版物电子出版物是以出版为目的，以磁、光、电等为载体，以数字形式表示其内容，体现数据库结构并辅之以计算机检索软件等信息处理手段，通过计算机加以利用的信息媒体。
#  </h2>
#  <h3>
#   电子出版物的分类单行版电子出版物联机数据库型电子出版物网络型电子出版物磁带型磁盘型光盘型芯片型（集成电路卡）电子图书电子报刊电子论坛电子公告板电子出版物书目数据库事实数据库数值数据库全文数据库
#  </h3>
#  <h3>
#   电子出版物特有的功能（1）具有计算机自动检索功能（2）具有信息计量功能（3）具有知识聚类功能（4）具有多媒体功能（5）具有超文本功能
#  </h3>
#  <h1>
#   思考题
#  </h1>
#  <h4>
#   什么是缩微型信息媒体？它有哪些种类？
#  </h4>
#  <h4>
#   缩微型信息资源有哪些优缺点？
#  </h4>
#  <h4>
#   什么是视听型信息媒体，它有哪些特殊的作用？
#  </h4>
#  <h4>
#   电子型信息资源指什么？它的优点有哪些？
#  </h4>
#  <h4>
#   什么是电子出版物？它有哪些种类？
#  </h4>
#  <h4>
#   与传统的信息媒体相比，电子出版物有什么特殊功能？
#  </h4>
#  <h1>
#   网络信息资源
#  </h1>
#  <h2>
#   网络信息资源的产生与发展
#  </h2>
#  <h3>
#   网络信息资源产生的背景网络信息资源的产生，根源于网络信息环境的形成与发展。因特网的飞速发展是网络信息资源得以产生与发展的基础。网络技术的进步、网络用户规模的扩大为我们创建网络信息资源环境提供了有利条件。1．传统信息媒体上网2．大量原生网站的产生3．个人网站、个人主页的普及
#  </h3>
#  <h3>
#   我国网络信息资源现状我国现有在线数据库为45598个，已经拥有在线数据库的网站占全部网站的14％。在线数据库的主要服务内容为产品数据库，如粮油、医药、机械产品等数据库，在所拥有在线数据库的网站中，近60％是此类数据库，其他一些如科技信息数据库、报刊新闻数据库、政策法规数据库的占有比例大致在11-15％之间。从在线数据库的记录数量来看，产品数据库占有62．3％的记录，其次为企业名录数据库，记录数占18．6％，科技信息库、报刊新闻数据库的记录占有比例不足3％。
#  </h3>
#  <h2>
#   网络信息资源的类型
#  </h2>
#  <h3>
#   网络信息资源的类型划分1．按照信息的内容划分可以把网络信息资源分成7类：①电子期刊，电子通讯期刊，图书的文本；②论文的抽印本，技术报告；③法律文件，判例，政府出版物；④数值数据，统计资料，实验数据；⑤软件；⑥图像数据，声音数据；⑦数据库。2．按照信息存取方式划分可以把网络信息资源分成6类：①邮件型②电话型以BBS和网上聊天为代表；③揭示板型代表性的是网络新闻和匿名FPT。④广播型指可以在网络上向特定的多数利用者即时提供的图像和声音传播方式；⑤图书馆型以Gopher和WWW等为代表；⑥书目型主要指用于检索网络信息资源的各种检索工具。3．按照科学交流方式划分可以把网络信息资源分成两大类：不稳定的信息资源指比较流动的、即时性的和变化的信息。稳定性的信息资源指信息资源的来源比较稳定，内容经过一定的加工和处理，有比较固定的存取途径和手续，可以重复进行操作。例如各种联机检索系统在网络上提供的各种数据库检索，网上提供的OPAC目录等。4．按照信息在网上的存在形式划分可以把网络信息资源分为四类：①书目信息；②电子报刊；③文件文档；④网上电子信件、电子公告、专题讨论栏目等形式的非正式信息发布活动所产生的大量信息。5．按照人类信息交流方式划分可以把网络信息资源分为三类：①非正式出版信息指流动性、随意性较强的，质量难以保证的动态性信息，如电子邮件、专题讨论小组和论坛、电子布告板等；②半正式出版信息又称“灰色”信息。指受到一定产权保护但没有纳入正式出版信息系统中的信息，如各种学术团体和教育机构、企业和商业部门、国际组织和政府机构、行业协会等单位介绍宣传自己或产品的描述性信息。③正式出版信息指受到一定产权保护、信息质量可靠、利用率较高的知识性、分析性信息，如各种数据库、联机杂志和电子杂志、电子版工具书、报纸等。2007-11-462第二节网络信息资源的类型四、各种类型的网络信息资源1.网站资源中国分类域名数（2007年）100%1,179,439合计1.9%174,304ORG6.0%553,372NET25.1%2,301,912COM67%6,149,851CN占域名总数比例数量（个）2007-11-463第二节网络信息资源的类型中国分类CN域名数（2007年）100.0%6,149,851合计0.0%7.MIL.CN0.1%3,139.EDU.CN0.1%10,178.AC.CN0.5%31,093.GOV.CN1.7%103,585.ORG.CN2.4%147,121.ADM.CN3.5%215,797.NET.CN32.8%2,018,880.COM.CN58.9%3,620,051.CN占CN域名总数比例数量（个）2.BBS资源3.邮件列表资源如:生物化学方面的邮件列表，Biology and Chemistry  Mailing Listshttp:// tile.net/lists/ biology.html古典音乐方面的邮件列表，Classical Music Electronic Mailing Listshttp://www.gprep.pvt.k12.md.us/classical/email.html澳大利亚图书馆邮件列表ALG: Australian Library-Related Discussion Listshttp://www.nla.gov.au/libraries/resource/lists.html4.个人主页资源如：老徐的博客5.搜索引擎资源如：百度、google、Yahoo！6. 联机数据库7. 联机馆藏目录8. 网络图书9．网络报纸10. 网络杂志11．软件资源网上信息资源大多可以免费获取，不过这类免费资源主要是大众传播类的信息，学术性信息不多，价值不高。因此，许多有价值的学术性网络信息资源是需要付费才能够使用的。信息服务机构采集这些付费资源，可以通过购买、链接、镜像等途径。网络信息资源建设不同于传统信息资源的一大特点是它不仅可以通过购买获得网络资源使用权，还可以通过对网络资源的指引、链接、导航形成自己的虚拟资源。
#  </h3>
#  <h2>
#   网络信息资源的特点1.数字化2.数量巨大3.类型多样4.超文本多媒体化5.远程可取6.共享7.更新及时8.网络化传播9.不稳定10.无序
#  </h2>
#  <h1>
#   思考题1. 网络信息资源产生的背景是什么?2. 网络信息资源的类型划分有哪几种方法?3. 网络信息资源具有哪些特点?作业某学科研究人员信息资源利用情况的调查与分析任意选择一个学科（如新闻学、情报学、社会学、遗传生物学、肿瘤医学等），通过该对学科研究人员进行科学研究时主要参考文献的来源进行调查，结合课堂学习的内容，分析其原因，并对该学科研究人员提出信息资源利用的建议。提示：可以选择该学科的一种核心期刊，对该期刊至少20篇论文后面的参考文献进行统计，分析各种类型文献在所有参考文献中的比例，并对此结果提出自己的看法。作业要求：必须列出你所选择的20篇论文的篇名、作者、来源和总参考文献的数量。作业形式不限，可以是纯文本，也可以是表格，也可以用统计图表。作业一律通过教学平台提交。注意提交作业的时间，过期将无法提交。
#  </h1>
#  <h1>
#   信息媒体的生产发行机制
#  </h1>
#  <h2>
#   信息媒体的生产过程及其管理
#  </h2>
#  <h3>
#   信息媒体的生产过程信息媒体的生产本质上是精神生产，它是人们把创造出的知识、信息物化为有形的信息媒体形式的过程。一般来说，信息媒体的生产有三个环节，即信息原料的采集、信息内容的加工创造、信息媒体的制作和包装。信息媒体的生产存在着正式生产和非正式生产两种形式。信息媒体的正式生产也叫社会化生产。
#  </h3>
#  <h3>
#   信息媒体生产的管理自从信息媒体的有组织社会化生产开始以后，无论古今中外，都是国家对信息媒体生产进行统一领导和集中管理。国家的管理体现在：制定专门的法律、法令和各种出版政策；设置专门的机构统一管理出版事业；对出版社的建立进行严格审批；建立出版物登记制度等。
#  </h3>
#  <h2>
#   我国信息媒体的生产机制
#  </h2>
#  <h3>
#   我国出版事业的体制总的来看，我国各类型信息媒体出版机构都是按一定的领导系统建立的，大多依附于一个母体机构，很少有纯商业性的出版社。这种按系统管理出版事业的体制，决定了我国出版工作较强的计划性和高度的组织性。
#  </h3>
#  <h3>
#   我国出版社的类型按出版内容划分，有综合性出版社、多科性出版社、专业出版社；按出版物类型划分，有图书出版社、期刊出版社、音像出版社、电子出版物出版社等；按读者对象划分，有工人出版社、妇女出版社、少年儿童出版社、盲文出版社、农村读物出版社等。
#  </h3>
#  <h2>
#   我国信息媒体的发行机制
#  </h2>
#  <h3>
#   发行体制我国对于信息媒体的发行，基本上实行统一管理、分散经营、多渠道流通的发行体制。国家有关部门对从事信息媒体发行的机构或个人实行许可证制度。2003年9月1日起，国家放开了出版物发行的限制，允许外资企业在中国境内开展信息媒体发行业务。
#  </h3>
#  <h3>
#   我国信息媒体发行的主要渠道新华书店外文书店中国书店或古旧书店图书发行公司出版社自办发行社会发行网点网上书店邮局中国图书进出口总公司中国教育图书进出口总公司
#  </h3>
#  <h2>
#   国外信息媒体的生产机制
#  </h2>
#  <h3>
#   国外出版机构的类型与特征国外凡从事出版活动的机构，即使一年只出版一、两种信息媒体，只要在有关部门注册，都可以称为出版社。可见国外出版社数量虽多，但相当一些是“皮包公司”性质的出版社。国外出版社主要有7种类型：
#  </h3>
#  <h4>
#   综合性出版社
#  </h4>
#  <h4>
#   专业性出版社
#  </h4>
#  <h4>
#   参考工具书出版社
#  </h4>
#  <h4>
#   教科书出版社
#  </h4>
#  <h4>
#   大学出版社
#  </h4>
#  <h4>
#   政府出版机构
#  </h4>
#  <h4>
#   学术团体出版机构
#  </h4>
#  <h3>
#   国外著名出版机构国外的出版社数以十万计，但真正具有出版质量高、出版信誉好等特点的出版社不过数千家。一般认为美、英、法、德、日、俄、荷兰等国是出版事业比较先进，出版物质量较高国家，因此我国在引进国外信息媒体时，通常以这些国家出版的信息媒体为主。一些著名的出版社如：美国的John Wiley &amp; Sons Inc.、Mcgraw-Hill、Academic Press 等；英国的Pergam Press, Ltd. 、Langman Group, Ltd. 、Oxford Univ. Press 等；德国的Springer、Verlagsgruppe Bertelsmann、K.G.Saur 等；日本的讲谈社、岩波书店、丸善书店等；荷兰的Elsevier、Kluwer等
#  </h3>
#  <h3>
#   国外非纸质信息媒体的生产机构
#  </h3>
#  <h4>
#   缩微资料出版商国际文献公司（Inter Documentation Co.）该公司营业部设在瑞士，制作部设在荷兰，专门经营绝版的古旧图书和善本书以及难得资料的缩微胶片。现有来自于世界各主要图书馆的珍贵资料缩微胶片母片300余万张。大学缩微品国际公司(University Microfilms International)   该公司是美国一家主要负责制作大学学位论文缩微制品的公司，拥有学位论文超过150万篇。普林斯顿缩微品公司(Princeton Microfilm Co.) 该公司是美国的一家专门提供学术研究期刊和其他重要文献的缩微制品的公司，生产美国的四大报告、科学文摘、医学文摘以及美国电气与电子工程师协会（IEEE)的各种期刊的缩微制品。
#  </h4>
#  <h4>
#   视听资料出版商宝丽金国际唱片集团(PoiyGram)、BMG国际唱片集团（贝塔斯曼）、索尼-哥伦比亚唱片公司（Sony/CBS) 、百代唱片公司（EMI )、JVC唱片公司等。
#  </h4>
#  <h4>
#   电子资源生产机构联机计算机图书馆中心（OCLC）、美国银盘公司、盖尔集团、埃尔塞维尔科学出版集团、美国国家技术情报服务处（NTIS）等。
#  </h4>
#  <h2>
#   国外信息媒体的发行渠道
#  </h2>
#  <h3>
#   出版社自办发行
#  </h3>
#  <h3>
#   批发商、代理商发行
#  </h3>
#  <h3>
#   零售书店发行
#  </h3>
#  <h1>
#   思考题
#  </h1>
#  <h4>
#   怎样理解信息媒体生产的三个环节？
#  </h4>
#  <h4>
#   我国信息媒体生产在机制上有什么特点？
#  </h4>
#  <h4>
#   国外出版社有哪些类型，各有什么特点？
#  </h4>
#  <h4>
#   我国信息媒体的发行渠道有哪些？
#  </h4>
#  <h1>
#   信息媒体采集的书目工具
#  </h1>
#  <h2>
#   书目工具概说书目是对一批相关的信息媒体进行著录，并按照一定的次序编排而成，供揭示和报导信息媒体有关信息的工具。对信息资源建设有用的书目主要是：
#  </h2>
#  <h4>
#   书商目录
#  </h4>
#  <h4>
#   出版社书目
#  </h4>
#  <h4>
#   国家书目
#  </h4>
#  <h4>
#   在售书目（books in print)
#  </h4>
#  <h4>
#   机读目录（MARC）.一部好的书目应该达到以下要求：
#  </h4>
#  <h4>
#   具有较高的权威性
#  </h4>
#  <h4>
#   收录范围的广泛性
#  </h4>
#  <h4>
#   著录的详细性和准确性
#  </h4>
#  <h4>
#   报导的及时性
#  </h4>
#  <h2>
#   采集中文信息媒体的书目工具
#  </h2>
#  <h4>
#   征订目录如《科技新书目》、《社科新书目》、《全国报刊简明目录》等。
#  </h4>
#  <h4>
#   通报目录和回溯性目录如《全国新书目》、《全国总书目》等。
#  </h4>
#  <h4>
#   其他参考书目和书评如《中文科技期刊联合目录》、《中国图书评论》等。
#  </h4>
#  <h2>
#   采集境外信息媒体的书目工具了解境外信息媒体生产情况的书目工具可分为两部分，一部分是国内有关机构编制的征订目录，另一部分是境外出版商、书商编制的书目。
#  </h2>
#  <h3>
#   国内编制的书目主要是中国图书进出口总公司编制的系列书目：. 《外国科学技术新书征订目录》简称T目录.《外国社会科学新书征订目录》简称S目录.《外国学术团体新书征订目录》简称L目录.《外国丛刊目录》简称C目录.《外国报刊目录》
#  </h3>
#  <h3>
#   境外出版的原版书目（1）出版社新书目录如Pergamon Bulletin、Springer  New  books等。（2）通报书目和累积书目如《图书累积索引》、《英国国家书目》、《法国出版物总目》等。（3）在售书目（在版书目、库存书目）如《国际在版书目》、《美国在版书目》等（4）书评、书讯如《出版商周刊》、《选目》、《书评摘要》等。（5）报刊目录如《乌利希国际期刊指南》
#  </h3>
#  <h3>
#   非纸质信息资源的书目《全国图书馆文献缩微复制中心缩微品目录》中国国家图书馆编辑出版。中国音像电影网中国音像行业政府网站美国《在版缩微品主题指南》美国《录音带指南》美国《视听资料市场：多媒体指南》美国《在版CD-ROM》等。
#  </h3>
#  <h1>
#   思考题
#  </h1>
#  <h4>
#   信息媒体采集的书目工具有哪些种类？
#  </h4>
#  <h4>
#   怎样衡量书目工具的质量？
#  </h4>
#  <h4>
#   采集中文信息媒体有哪些常用书目工具？
#  </h4>
#  <h4>
#   采集境外信息媒体有哪些常用的书目工具？
#  </h4>
#  <h1>
#   信息资源建设的原则
#  </h1>
#  <h2>
#   实用性原则
#  </h2>
#  <h3>
#   实用性原则是信息资源建设最基本的原则
#  </h3>
#  <h3>
#   实用性原则的基本要求根据信息服务机构承担的任务采集信息媒体根据信息服务机构用户的需要采集信息媒体.  保加利亚图书馆学家M.斯坦切夫提出的信息资源与用户需求相符合的公式：f 1:f 2:f 3 ··· f n≌q 1: q 2: q 3 ··· q n
#  </h3>
#  <h2>
#   系统性原则
#  </h2>
#  <h3>
#   系统性原则的依据
#  </h3>
#  <h3>
#   系统性原则的要求
#  </h3>
#  <h4>
#   采集入藏的重点信息资源要保证做到系统完整。也就是说，这部分信息资源要能系统反映本学科或本领域的发展历史，内容上要完整。对于决定采集入藏的各种连续出版物、重点出版物，要完整无缺，成龙配套，即形式上也要完整；
#  </h4>
#  <h4>
#   采集入藏的全部信息资源，从总体上看，要互相联系、有比例、成体系。也就是说，整体的信息资源要能反映各学科之间的相互交叉、互相联系的关系，各学科、各类型的信息资源之间要保持合理的比例，形成一个有专有博、有主有从的知识体系；
#  </h4>
#  <h4>
#   采访人员要系统地进行信息媒源的采集工作。
#  </h4>
#  <h3>
#   关于信息资源建设重点与一般的关系限于人、财、物力的条件，任何机构都不可能在进行信息资源建设时对各学科、各类型的信息媒体平均使用力量，只能根据本单位承担的主要任务和主要用户的需要，选择某些学科和某种类型的信息媒体予以完整系统的收藏，以形成重点；而将重点以外的信息媒体则做一般性的收藏。通过这种一般与重点的结合，才能够形成合理的信息资源体系。信息资源中的重点部分，是信息资源的核心，它反映了信息资源的特征，代表了信息资源的发展方向。. 确定信息资源建设的重点需考虑的因素：
#  </h3>
#  <h4>
#   本地区、本系统、本单位生产建设和科学研究的重点
#  </h4>
#  <h4>
#   本单位原有信息资源的基础
#  </h4>
#  <h4>
#   本地区历史和地理的特点
#  </h4>
#  <h4>
#   本地区、本系统信息服务机构的分工情况确定重点的范围，要持严肃、慎重的态度，不能随心所欲、朝令夕改。处理重点与一般的关系：保证重点，照顾一般。
#  </h4>
#  <h2>
#   发展与剔除原则新陈代谢是一切事物生存发展的客观规律，信息资源作为信息服务机构建设起来的有机体系，也必须遵循这个规律。所谓发展，是指信息资源中新的信息媒体的增加；所谓剔除，是指信息资源中陈旧的、无用的信息媒体的清除。信息资源的实用性、系统性，只有通过发展和剔除来控制和调整才能得以实现。
#  </h2>
#  <h3>
#   发展和剔除的原因
#  </h3>
#  <h4>
#   保存人类优秀的文化成果；
#  </h4>
#  <h4>
#   保持信息资源利用的活力；
#  </h4>
#  <h4>
#   建立结构合理的信息资源体系。
#  </h4>
#  <h3>
#   信息媒体剔除的理论依据知识老化带来信息媒体的老化。常用信息媒体半衰期这一术语来描述信息媒体老化的速度。所谓信息媒体半衰期是指，某一学科或专业现在仍被利用的所有信息媒体中，较新的一半是在多长一段时间内生产的。国外推算的一些学科信息媒体的半衰期：医学3年冶金3.9年物理学4.6年化工4.8年机械制造5.2年生物学7.2年化学8.1年植物学10年数学10.5年地质学11.8年地理学16年
#  </h3>
#  <h3>
#   信息媒体剔除的范围
#  </h3>
#  <h4>
#   复本过多，长期积压的信息媒体；
#  </h4>
#  <h4>
#   内容陈旧过时的信息媒体；
#  </h4>
#  <h4>
#   内容有错误，不宜公开流通的信息媒体；
#  </h4>
#  <h4>
#   残缺不全，破损不堪，已无法使用的信息媒体；
#  </h4>
#  <h4>
#   实用性差，利用率很低的信息媒体。
#  </h4>
#  <h2>
#   特色化和协调原则又称分工协调原则。在这里，特色化原则就是专门化原则，指对各信息机构进行信息资源建设时从主题、类型等方面所做的有意限制，以最大限度地使各信息机构收藏的信息媒体在内容上、结构上接近本单位用户的真正需求；而协调性原则则是要将社会上各级各类信息机构看成一个整体，有目的地在各信息机构之间实行信息媒体采集的分工合作，避免重复和浪费，从而以最少的花费建设起最完备的信息资源体系。
#  </h2>
#  <h2>
#   特色化和协调原则
#  </h2>
#  <h3>
#   特色化与协调原则的依据.  信息资源利用的“二八律”（2/8 rule)由美国图书馆学家特鲁斯威尔在大量的统计基础上提出：指在信息机构入藏的全部信息媒体中，大约有20％是常用的，能够满足用户80％的经常性需求；而其余80％的信息媒体，则只是为了满足20％用户的偶然需求而存在的。专业性信息服务机构只要能够满足用户80％的需求就可以了，满足需求比例的进一步提高，在经济上是不合理的。余下20％的需求，应该依靠各信息机构之间的协作，用馆际互借的方法解决。
#  </h3>
#  <h3>
#   特色化的意义与内容特色是事物所表现的独特风格，是一事物区别于它事物的显著特征。信息资源的特色，就是一个信息机构入藏的信息媒体所形成的独特风格，是与其他信息机构拥有的信息资源的区别所在。特色化的内容包括：专业特色、地方特色、类型特色、文种特色等。
#  </h3>
#  <h3>
#   协调性的意义与内容
#  </h3>
#  <h4>
#   有助于把各信息机构的信息媒体采集纳入统一的信息资源建设活动中进行规划，克服各机构之间信息媒体采集的重复与遗漏；
#  </h4>
#  <h4>
#   有助于改善各信息机构原有的信息媒体收藏结构，形成本单位信息资源特色；
#  </h4>
#  <h4>
#   有助于合理使用信息资源建设的经费;
#  </h4>
#  <h4>
#   有助于各信息机构提高信息资源的利用率。协调性的内容包括：信息媒体采集的分工协调和原有信息资源的调整和重组。
#  </h4>
#  <h3>
#   特色化与协调性原则的目标及关系目标是：一是要使各级各类信息机构建立起有特色的专门化的信息资源体系，能够满足本单位用户大部分的需求；二是要使各地区乃至全国范围内的所有信息机构共同建立起类型多样、学科齐全的综合化信息资源体系，能够满足整个社会广泛的信息需求。二者的关系：辨证的关系。特色化是协调性的基础，如果没有各单位信息资源的特色，协调将无法进行；协调性是特色化的保障，如果没有信息媒体收藏的协调作为各信息机构的后盾，则一信息机构的特色化也不可能持久。二者是一个整体。
#  </h3>
#  <h1>
#   思考题
#  </h1>
#  <h4>
#   什么是实用性原则，它有哪些基本要求？
#  </h4>
#  <h4>
#   为什么要贯彻系统性原则？系统性原则有哪些基本要求？
#  </h4>
#  <h4>
#   怎样确定信息资源建设的重点？
#  </h4>
#  <h4>
#   什么是信息媒体的半衰期？什么是信息资源利用的“二八律”？
#  </h4>
#  <h4>
#   特色化和协调原则的含义和目标是什么？二者之间是什么关系？
#  </h4>
#  <h1>
#   信息媒体采集的组织与方法在信息服务机构，信息媒体采集又称为信息媒体采访。从采访工作的过程看，可以分为信息媒体选择和信息媒体搜集两个部分。选择是搜集的前期活动，它要根据一定的原则，从大量信息媒体中选出信息服务机构所需的信息媒体。这是一项指令性活动，其结果对信息媒体采访质量起决定性的作用，具有很强的知识性和学术性。搜集则是通过一定的方式和途径去获取经过选择需要入藏的信息媒体。这是一项执行性活动，具有较强的实践性和灵活性。
#  </h1>
#  <h2>
#   信息媒体采访调查信息媒体采访调查涉及三方面内容：
#  </h2>
#  <h3>
#   本单位原有信息媒体收藏情况的调查
#  </h3>
#  <h3>
#   用户需求调查
#  </h3>
#  <h3>
#   信息媒体来源调查.选择发行机构需考虑的几个因素：
#  </h3>
#  <h4>
#   供货满足率连续出版物应100％，其他80％以上。
#  </h4>
#  <h4>
#   到货速度
#  </h4>
#  <h4>
#   信誉
#  </h4>
#  <h4>
#   价格与付款方式
#  </h4>
#  <h2>
#   信息媒体的选择
#  </h2>
#  <h3>
#   信息媒体选择理论的形成和发展
#  </h3>
#  <h4>
#   美国的“价值论”和“需要论”以杜威为代表的value theory 派，主张选择科学性、艺术性强，学术价值高的优秀图书，即best books。认为必须重视文献的价值，要向读者提供最好的阅读。19世纪末20世纪初，“价值论”占了主导地位。以普尔和克特为代表的demand theory 派，主张以读者需要为宗旨，挑选right books ,而不是所谓最好的图书。20世纪初以后，“需要论”逐渐占了上风。
#  </h4>
#  <h4>
#   麦戈文的信息媒体选择“综合评分法”1925年，英国图书馆学家麦戈文发表了《公共图书馆选书理论》的论文，把“价值论”和“需要论”结合起来，提出了一个纯理论的“图书选择综合评分法”。例1：图书A的知识价值为10，图书B的知识价值为1，而两种图书的社会需求值都为6。则A的评分为10×6＝60；B的评分为1×6＝6，A＞B，二者选一时，选A不选B。例2：图书A的知识价值为10，图书B的知识价值为1，但A的社会需求值为6，B的社会需求值为72。则A的评分为10 ×6＝60，B的评分为1 ×72＝72，B ＞A，二者选一时，选B 不选A。
#  </h4>
#  <h4>
#   印度阮冈纳赞的“概率选书论”根据读者对文献利用的概率大小来决定是否入藏某种文献。
#  </h4>
#  <h4>
#   前苏联的藏书补充原则和复选理论20世纪初，苏联的几位选书理论专家鲁巴金、哈夫金娜等提出，要客观地完备地选择出版物；列宁提出了藏书补充的完整性、高效率、集中化和党性原则；克鲁普斯卡娅提出，藏书补充应有最大的知识量，所耗最小。70年代，格里科尔耶夫提出，信息媒体选择是一个过程，不仅要在信息媒体入藏前选择，还应在信息媒体入藏后进行再次选择，即复选。
#  </h4>
#  <h3>
#   信息媒体选择的依据
#  </h3>
#  <h4>
#   信息媒体内容的主题和学科归属
#  </h4>
#  <h4>
#   用户对象
#  </h4>
#  <h4>
#   责任者
#  </h4>
#  <h4>
#   出版机构
#  </h4>
#  <h4>
#   其他特征
#  </h4>
#  <h2>
#   信息媒体采集中的复本问题
#  </h2>
#  <h3>
#   复本的含义所谓复本，指信息服务机构对同一种信息媒体的重复收藏。信息媒体的品种与复本是一对矛盾，在经费一定的前提下，增加复本必然要减少品种；而减少复本，增加品种，对于一些高利用率的信息媒体就会加大拒借率。从增加信息资源的信息量上看，应该减少复本；而从方便用户、及时满足用户需求上看，增加复本又是必要的。目前，复本问题是困扰我国信息机构信息资源建设的一个老大难问题。
#  </h3>
#  <h3>
#   影响复本量的因素
#  </h3>
#  <h4>
#   现实用户人数
#  </h4>
#  <h4>
#   信息服务机构信息资源的规模
#  </h4>
#  <h4>
#   信息服务机构信息资源的布局
#  </h4>
#  <h4>
#   信息服务机构对信息资源的使用制度
#  </h4>
#  <h4>
#   信息媒体的有效使用期
#  </h4>
#  <h4>
#   信息媒体的类型、载体、文种及专深程度
#  </h4>
#  <h4>
#   信息服务机构对信息媒体的复制能力
#  </h4>
#  <h4>
#   丢失、损耗的比例
#  </h4>
#  <h2>
#   信息媒体的补充方式
#  </h2>
#  <h3>
#   购入方式
#  </h3>
#  <h4>
#   订购指信息服务机构预先收集、选择并填写有关信息媒体发行机构的征订目录，有计划地预订信息媒体的方式。这是大中型信息服务机构补充信息媒体的主要方式。目前，为了方便信息服务机构订购信息媒体，国外发展了纲目订购、全数订购、提类订购、长期订购等新的订购方式。.  纲目订购指信息服务机构将自己需要采集的信息媒体的学科、类型、文种、水平等要求列成一个大纲，交给信息媒体发行机构，由发行机构根据信息服务机构提出的大纲主动进行信息媒体的选配并发送给信息服务机构。
#  </h4>
#  <h4>
#   选购指信息服务机构采访人员直接到信息媒体销售现场挑选、购买所需的信息媒体。
#  </h4>
#  <h4>
#   邮购指信息服务机构通过邮政汇款方式，请外地的出版发行机构按所开列的清单，将信息媒体寄送信息服务机构。
#  </h4>
#  <h4>
#   复制指用抄写、复印、照相、转录、拷贝等方式获取稀缺信息媒体。
#  </h4>
#  <h4>
#   租借指对一些信息服务机构不拟长期保存的信息媒体通过租借方式获得一定时期的使用权。
#  </h4>
#  <h3>
#   非购入方式
#  </h3>
#  <h4>
#   呈缴指正式出版物的法定缴送制度。它是根据国家有关法律或法令的规定，凡正式出版的各种信息媒体，必须向指定的机构免费缴送一定数量的样本。这种制度称为缴送本制度。
#  </h4>
#  <h4>
#   调拨指信息服务机构无偿接收有关单位拨付的信息媒体。
#  </h4>
#  <h4>
#   征集指信息服务机构根据有关线索，有针对性地从信息媒体所有人手中募集各种内部资料或珍贵文献。
#  </h4>
#  <h4>
#   交换指两个以上信息服务机构之间，互相交换各自的信息媒体，达到互通有无、丰富收藏的一种方式。交换的形式有：（1）双边式交换（2）多边式交换（UNESCO出版物交换所)（3）集中式交换( USBE )
#  </h4>
#  <h4>
#   捐赠指接受国内外个人或团体的赠送。
#  </h4>
#  <h2>
#   信息媒体采集的工作流程信息媒体采集流程图（以订购为例）：接收征订目录及订单根据征订目录圈选信息媒体查重确定订购品种及复本量填写订单、发送订单编制、组织采访目录接收信息媒体验收、登录
#  </h2>
#  <h1>
#   思考题
#  </h1>
#  <h4>
#   信息媒体采访调查包括哪些内容？
#  </h4>
#  <h4>
#   关于信息媒体选择，国际上曾经有哪些理论流派？
#  </h4>
#  <h4>
#   影响信息媒体复本率的因素有哪些？
#  </h4>
#  <h4>
#   信息媒体补充的方法有哪些？
#  </h4>
#  <h4>
#   试述信息媒体采访的工作流程。
#  </h4>
#  <h1>
#   信息资源的数量控制与质量评价
#  </h1>
#  <h2>
#   信息资源数量控制
#  </h2>
#  <h3>
#   控制信息资源数量增长的客观要求
#  </h3>
#  <h4>
#   信息资源收藏空间紧张；
#  </h4>
#  <h4>
#   相关设备短缺；
#  </h4>
#  <h4>
#   信息资源利用率降低；
#  </h4>
#  <h4>
#   信息资源增长过快，工作人员疲于应付。
#  </h4>
#  <h3>
#   藏书发展稳定状态理论英国的阿金森等人在英国大学拨款委员会的一个报告中提出，大型图书馆不要无限制地发展藏书数量，而应当在藏书发展到一定规模时控制其增长速度，即在一个相对的时限内，入藏新书的数量与剔除旧书的数量保持一致，从而使藏书的实际增长量等于零。因此这个理论又被称为藏书的零增长理论。
#  </h3>
#  <h3>
#   控制信息资源数量增长的方法
#  </h3>
#  <h4>
#   精选信息媒体
#  </h4>
#  <h4>
#   复选与剔除
#  </h4>
#  <h4>
#   制订标准，规定信息服务机构合理的收藏规模
#  </h4>
#  <h4>
#   实行资源共享，分工入藏信息媒体
#  </h4>
#  <h2>
#   信息资源评价
#  </h2>
#  <h3>
#   信息资源评价的含义信息资源评价是对信息服务机构现有信息资源体系所具有的各种属性进行检测、评估，包括对信息资源数量、质量、结构以及信息资源满足用户需求的能力等进行综合评判。
#  </h3>
#  <h3>
#   信息资源评价的方法
#  </h3>
#  <h4>
#   书目核对法
#  </h4>
#  <h4>
#   统计测量分析法
#  </h4>
#  <h4>
#   用户评议法
#  </h4>
#  <h1>
#   思考题
#  </h1>
#  <h4>
#   为什么要控制信息资源的数量增长？怎样控制？
#  </h4>
#  <h4>
#   什么是藏书发展稳定状态理论？对信息资源建设有什么意义？
#  </h4>
#  <h4>
#   信息资源评价有哪些常用的方法？课程讲授到此结束谢谢各位
#  </h4>
# </body>

# %% [markdown]
# 再次读取的时候，发现原有的层次结构被破化了,应该考虑别的方法存储BeautifulSoup对象而非使用字符串，另一种思路是继续在bigram2html文件中写下去
# Python对象的序列化可以使用pickle模块来实现

# %%
html_file_b = open(r"../tmp/html.dat","rb")
soup = pickle.load(html_file_b)
root = soup.html.body

# %%
for item in root.descendants:
    if isinstance(item,str):
        continue
    print(item.name,item.parent.name)
# Out:
# h1 body
# h2 h1
# h3 h2
# h3 h2
# h4 h3
# h4 h3
# h4 h3
# h4 h3
# h4 h3
# h4 h3
# h4 h3
# h3 h2
# h4 h3
# h4 h3
# h4 h3
# h4 h3
# h3 h2
# h4 h3
# h4 h3
# h4 h3
# h2 h1
# h3 h2
# h4 h3
# h4 h3
# h4 h3
# h4 h3
# h4 h3
# h3 h2
# h4 h3
# h4 h3
# h4 h3
# h4 h3
# h2 h1
# h3 h2
# h4 h3
# h4 h3
# h4 h3
# h4 h3
# h4 h3
# h4 h3
# h4 h3
# h4 h3
# h4 h3
# h3 h2
# h4 h3
# h4 h3
# h4 h3
# h4 h3
# h4 h3
# h3 h2
# h4 h3
# h4 h3
# h4 h3
# h4 h3
# h4 h3
# h4 h3
# h4 h3
# h4 h3
# h1 body
# h2 h1
# h3 h2
# h2 h1
# h3 h2
# h3 h2
# h2 h1
# h2 h1
# h3 h2
# h3 h2
# h3 h2
# h3 h2
# h3 h2
# h3 h2
# h3 h2
# h1 body
# h4 h1
# h4 h1
# h4 h1
# h4 h1
# h4 h1
# h4 h1
# h4 h1

# %% [markdown]
# 此处遍历的顺序是无所谓的，但是BeautifulSoup按照预期的顺序遍历了，也就是创建时的顺序

# %%
triple_list = []
course_name = "信息资源建设"
verb = "sub-concept"
i = 1
for item in root.descendants:
    if isinstance(item,str):
        continue
    sbj = item.contents[0]
    if item.parent.name == "body":
        obj = course_name
    else:
        obj = item.parent.contents[0]
    triple_list.append((sbj,verb,obj))
myprint(triple_list)
# Out:
# [('信息、信息媒体与信息资源', 'sub-concept', '信息资源建设'),
#  ('信息概述', 'sub-concept', '信息、信息媒体与信息资源'),
#  ('信息的定义从广义上理解，信息可以被认为是物质的一种属性，是物质存在方式和运动规律与特点的表现形式。从狭义上理解，信息是一种消息、信号、数据或资料，是用来消除不定性的东西。',
#   'sub-concept',
#   '信息概述'),
#  ('信息的特征', 'sub-concept', '信息概述'),
#  ('真实性', 'sub-concept', '信息的特征'),
#  ('知识性', 'sub-concept', '信息的特征'),
#  ('指向性', 'sub-concept', '信息的特征'),
#  ('共享性', 'sub-concept', '信息的特征'),
#  ('无限性', 'sub-concept', '信息的特征'),
#  ('时效性', 'sub-concept', '信息的特征'),
#  ('依附性', 'sub-concept', '信息的特征'),
#  ('信息的种类', 'sub-concept', '信息概述'),
#  ('按信息的产生和作用机制划分，有自然信息和社会信息两大类；', 'sub-concept', '信息的种类'),
#  ('按信息是否被人感知来划分，有显性信息和隐性信息两大类；', 'sub-concept', '信息的种类'),
#  ('按信息的运动状态来划分，有动态信息和静态信息两大类；', 'sub-concept', '信息的种类'),
#  ('按信息的存在和接受情况划分，有直接信息和间接信息两大类。', 'sub-concept', '信息的种类'),
#  ('信息的功能与作用', 'sub-concept', '信息概述'),
#  ('维系社会存在与发展', 'sub-concept', '信息的功能与作用'),
#  ('社会经济发展的动力', 'sub-concept', '信息的功能与作用'),
#  ('科学决策、科学研究和生产建设的参谋和依据', 'sub-concept', '信息的功能与作用'),
#  ('信息媒体', 'sub-concept', '信息、信息媒体与信息资源'),
#  ('信息媒体的含义信息与信息载体是密不可分的，没有载体，信息就无法存在。我们现在所称的载体，客观上有两大类：',
#   'sub-concept',
#   '信息媒体'),
#  ('信息载体，又称软载体或第一载体，指信息、知识得以表达、存在的语言、文字、符号、声波、光波、电波等用于直接承载信息的载体；',
#   'sub-concept',
#   '信息媒体的含义信息与信息载体是密不可分的，没有载体，信息就无法存在。我们现在所称的载体，客观上有两大类：'),
#  ('载体的载体，又称硬载体或第二载体。指承载信息、知识的物质载体，如纸张、胶片、磁带、磁盘、光盘等。只有第一载体和第二载体有机结合，信息才能得到永久的保存、加工和传递。人类信息交流时常用的信息源',
#   'sub-concept',
#   '信息媒体的含义信息与信息载体是密不可分的，没有载体，信息就无法存在。我们现在所称的载体，客观上有两大类：'),
#  ('口头信息源优点：（1）获得信息直接、迅速；（2）信息内容新；（3）针对性强；（4）信息反馈及时；（5）可以提供其他信息源不能包含的许多细节。缺点：（1）瞬时性，不能够保存；（2）主观随意性强，可靠性不足；（3）传递范围有限，且辗转传递信息容易失真。',
#   'sub-concept',
#   '信息媒体的含义信息与信息载体是密不可分的，没有载体，信息就无法存在。我们现在所称的载体，客观上有两大类：'),
#  ('实物信息源（1）真实可靠；（2）信息浓度大；（3）易于开发利用。（1）传递不方便；（2）信息隐蔽，有时不易提取。',
#   'sub-concept',
#   '信息媒体的含义信息与信息载体是密不可分的，没有载体，信息就无法存在。我们现在所称的载体，客观上有两大类：'),
#  ('文献信息源信息可以通过人脑、实物和文献得以存在和表现，但只有文献才是专门用来存储和传递信息的信息媒体。信息媒体的定义：信息媒体是指所有记录有信息，并专门用于保存和传递信息的物质载体。信息媒体是我们能够实际掌握的信息，是信息资源建设的对象。',
#   'sub-concept',
#   '信息媒体的含义信息与信息载体是密不可分的，没有载体，信息就无法存在。我们现在所称的载体，客观上有两大类：'),
#  ('信息媒体的构成要素', 'sub-concept', '信息媒体'),
#  ('信息内容指信息媒体所表述的思想意识、知识、情报、信息的内容。', 'sub-concept', '信息媒体的构成要素'),
#  ('信息符号指信息内容的标识符号和表达手段。', 'sub-concept', '信息媒体的构成要素'),
#  ('载体材料指信息内容存贮的依附体或媒介。', 'sub-concept', '信息媒体的构成要素'),
#  ('记录方式指将信息符号所代表的信息内容存贮到载体材料上的方式。', 'sub-concept', '信息媒体的构成要素'),
#  ('信息资源', 'sub-concept', '信息、信息媒体与信息资源'),
#  ('信息资源的含义目前有多种看法：', 'sub-concept', '信息资源'),
#  ('信息资源等同于文献资源；', 'sub-concept', '信息资源的含义目前有多种看法：'),
#  ('信息资源等价于数据信息；', 'sub-concept', '信息资源的含义目前有多种看法：'),
#  ('信息资源是多种媒介和形式的信息总称；', 'sub-concept', '信息资源的含义目前有多种看法：'),
#  ('信息资源是信息活动中各种要素的总称，包括信息、设备、技术和人等。综合国内外目前比较流行的观点，我们可以把人们对信息资源概念的理解归纳为两大类：一类是狭义的理解，即从信息本体出发，认为信息资源是经过人类选择、组织、序化并大量积累起来的有用信息的集合。另一类是广义的理解，即认为信息资源是指人类社会活动中所积累的信息，以及创造信息的人和相关信息技术的集合。我们对信息资源的定义：在人类信息活动中产生的，并经过人们的选择、收集、组织、加工、存贮、转换等过程而形成的可利用的信息集合。这个定义的要点：',
#   'sub-concept',
#   '信息资源的含义目前有多种看法：'),
#  ('信息资源是信息的集合；', 'sub-concept', '信息资源的含义目前有多种看法：'),
#  ('信息资源对信息是有选择的；', 'sub-concept', '信息资源的含义目前有多种看法：'),
#  ('信息资源是可利用的；', 'sub-concept', '信息资源的含义目前有多种看法：'),
#  ('信息资源是经过组织和有序化的；', 'sub-concept', '信息资源的含义目前有多种看法：'),
#  ('信息资源是通过人类的一系列劳动而建设起来的。', 'sub-concept', '信息资源的含义目前有多种看法：'),
#  ('信息资源的特性：', 'sub-concept', '信息资源'),
#  ('可建设性', 'sub-concept', '信息资源的特性：'),
#  ('再生性', 'sub-concept', '信息资源的特性：'),
#  ('动态性', 'sub-concept', '信息资源的特性：'),
#  ('冗余性', 'sub-concept', '信息资源的特性：'),
#  ('价值的潜在性', 'sub-concept', '信息资源的特性：'),
#  ('信息资源的种类：', 'sub-concept', '信息资源'),
#  ('按照信息载体的形式进行划分，有纸张印刷型、缩微型、视听型、电子型、网络型；', 'sub-concept', '信息资源的种类：'),
#  ('按照信息资源的编辑出版形式进行划分，有图书、期刊、科技报告、专利文献、会议文献、政府出版物、学位论文、标准文献、产品样本等。',
#   'sub-concept',
#   '信息资源的种类：'),
#  ('按照信息资源的维护和使用权限划分，有：永久保存型指信息服务机构需要长期入藏的信息资源，如纸本书刊、光盘等。镜像服务型主要指国内外一些大型数据库，通过镜像的方式拷贝到本地的服务器上供用户存取。尽管这类资源的保存和维护责任不由自己承担，但它使用起来就如同自己的资源一样方便、快捷。网络服务型如远程数据库，存放在远程服务器上，并由其他机构负责管理和维护，使用者通过一定的协议取得对该资源的存取权限，并在自己的网页上设置连接点，点击接点登录并使用该资源库。链接存取型主要是对网络上的各类免费使用的数据库资源进行捕获和筛选，并通过组织资源导航链接而进行信息的存取。思考题',
#   'sub-concept',
#   '信息资源的种类：'),
#  ('什么是信息？信息有那些基本特征？', 'sub-concept', '信息资源的种类：'),
#  ('常用的信息源有哪些？它们各有什么优缺点？', 'sub-concept', '信息资源的种类：'),
#  ('什么是信息媒体？信息媒体的构成要素有哪些？', 'sub-concept', '信息资源的种类：'),
#  ('什么是信息资源？信息资源的特征是什么？', 'sub-concept', '信息资源的种类：'),
#  ('信息资源的类型是怎样划分的？', 'sub-concept', '信息资源的种类：'),
#  ('纸质信息资源纸质信息资源是指包括各种以纸张材料为载体，以印刷、手写、复制等为记录手段而形成的各种信息媒体的集合。',
#   'sub-concept',
#   '信息资源建设'),
#  ('图书',
#   'sub-concept',
#   '纸质信息资源纸质信息资源是指包括各种以纸张材料为载体，以印刷、手写、复制等为记录手段而形成的各种信息媒体的集合。'),
#  ('定义ISO规定，49页及49页以上，构成一个单元的文献（不包括封面和扉页）。UNISCO规定，图书是指49页以上（不含封面）的非定期出版物。我们的定义：图书是通过一定的方法与手段，将知识内容以一定形式的符号，按照一定的体例，系统地记录于一定形态的载体之上，用以表达思想、积累经验、保存知识、传递信息的工具。',
#   'sub-concept',
#   '图书'),
#  ('期刊期刊是一种定期或不定期的连续出版物，以定期的居多，出版周期一般不超过一年，具有固定的名称和统一的版式，使用连续的卷、期和年月顺序号，各期内容不重复，登载多个作者的多篇文章，极少有再版。',
#   'sub-concept',
#   '纸质信息资源纸质信息资源是指包括各种以纸张材料为载体，以印刷、手写、复制等为记录手段而形成的各种信息媒体的集合。'),
#  ('学术性期刊的作用1   是科学技术成就的记载；2   是传递学术信息的重要媒体；3   能够培养和发现人才；4能够检阅单位和个人的研究成果',
#   'sub-concept',
#   '期刊期刊是一种定期或不定期的连续出版物，以定期的居多，出版周期一般不超过一年，具有固定的名称和统一的版式，使用连续的卷、期和年月顺序号，各期内容不重复，登载多个作者的多篇文章，极少有再版。'),
#  ('核心期刊布拉德福搜集了一年中登载了电技术方面论文的所有期刊共284种，并按照每种期刊登载电技术方面论文数量的多少排序。经过统计他发现，登载电技术论文最多的前10种期刊，包含了全部电技术论文的1/3；而紧接着的49种期刊，也登载了1/3的论文；而剩下的1/3的论文，则是由225种期刊登载的。于是，布拉德福得出结论：在登载某一学科文献的所有期刊中，存在着由若干种期刊构成的核心区域，在其周围还有另外两个区域，其中的每一个区域都含有与核心区域中数量相等的该学科文献。那么，第二区域的期刊数量为核心区域期刊数量的n倍，而第三区域的期刊数量则为核心区域期刊数量的n2倍。',
#   'sub-concept',
#   '期刊期刊是一种定期或不定期的连续出版物，以定期的居多，出版周期一般不超过一年，具有固定的名称和统一的版式，使用连续的卷、期和年月顺序号，各期内容不重复，登载多个作者的多篇文章，极少有再版。'),
#  ('期刊即P1 : p2 : p3 = 1: n : n2n '
#   '≈5如下图：这就是著名的布拉德福文献分布定律。人们据此就将核心区域的期刊称为核心期刊。1    n    '
#   'n2.核心期刊定义：核心期刊又称重点期刊，是指那些学科信息含量大，代表该学科发展水平，所刊载的论文使用寿命长，利用率较高的期刊。.判别核心期刊的标准：（1）期刊论文的被摘率；（2）期刊论文的被引用率；（3）期刊流通过程中的读者利用率。',
#   'sub-concept',
#   '纸质信息资源纸质信息资源是指包括各种以纸张材料为载体，以印刷、手写、复制等为记录手段而形成的各种信息媒体的集合。'),
#  ('其他类型的纸质信息资源',
#   'sub-concept',
#   '纸质信息资源纸质信息资源是指包括各种以纸张材料为载体，以印刷、手写、复制等为记录手段而形成的各种信息媒体的集合。'),
#  ('科技报告也称研究报告或技术报告，是研究课题进展期情况的实际记录与研究成果的系统总结。.美国著名的四大报告：PB '
#   '报告——政府研究报告AD报告——国防部研究报告NASA报告——国家宇航局报告DOE报告——国家能源部报告科技报告一般分为机密、秘密、非密限制发行和非密公开发行四个密级。每种报告都有特定的代号。',
#   'sub-concept',
#   '其他类型的纸质信息资源'),
#  ('政府出版物联合国教科文组织规定，凡根据国家机关的命令，并且由国家负担经费而出版的一切记录，都是政府出版物。包括：国会记录、司法资料、方针政策、规章制度、政府报告、政府决议以及调查、统计资料等。由于是官方正式出版，信息内容准确、权威，是政务信息和决策信息的重要来源。',
#   'sub-concept',
#   '其他类型的纸质信息资源'),
#  ('会议文献指在国内外各种学术会议上宣读或交流的论文、报告以及由会议编辑的会议录等。会议文献具有以下特点：（1）传递信息新颖及时；（2）信息的针对性强；（3）集中反映了各种观点；（4）能够获得许多难得的信息。会议文献的不足是：反映的信息不够完整、准确。',
#   'sub-concept',
#   '其他类型的纸质信息资源'),
#  ('学位论文指研究机构、高等院校的研究生为获取学位而撰写的学术论文。学位论文的作用表现在：（1）了解一门学科或课题研究的历史与现状；（2）作为重要的书目参考工具或原始情报源；（3）帮助确定研究选题；（4）开发院校课程内容。学位论文的收集、利用目前极不理想。',
#   'sub-concept',
#   '其他类型的纸质信息资源'),
#  ('专利文献指伴随各种发明的专利申请、审查、确认和公布而产生的一系列文献，主要是专利说明书。专利文献具有新颖性、实用性和详细性的特征。专利文献的作用表现在：（1）避免研究的重复；（2）在引进或输出技术时获得知识产权保护或规避侵权；（3）了解竞争对手的技术实力；（4）在不侵权的情况下直接利用专利技术。',
#   'sub-concept',
#   '其他类型的纸质信息资源'),
#  ('标准文献指由各种技术标准、具有标准性质的文件、标准分类表和标准检索工具所构成的文献体系，其中技术标准是最有信息价值的部分。技术标准分为国际标准、国家标准、行业标准和企业自定标准。技术标准的作用表现在：（1）获得先进、完整、可靠的技术内容，促进生产经营活动与社会大生产协调一致；（2）作为引进或输出产品时对产品质量进行检测的依据；',
#   'sub-concept',
#   '其他类型的纸质信息资源'),
#  ('产品样本又称产品资料。指由各公司、企业为推销自己的产品而编印的出版物或商业宣传品。产品资料反映的技术比较成熟，数据真实可靠，对企业进行产品设计、技术模仿、开展技术合作、国内外贸易有重要参考价值。产品资料通常是免费发放或免费索取。',
#   'sub-concept',
#   '其他类型的纸质信息资源'),
#  ('思考题', 'sub-concept', '信息资源建设'),
#  ('什么是核心期刊？怎样判别核心期刊？', 'sub-concept', '思考题'),
#  ('什么是科技报告？美国的四大报告是指哪些科技报告？', 'sub-concept', '思考题'),
#  ('什么是政府出版物？它有什么作用？', 'sub-concept', '思考题'),
#  ('什么是会议文献？它有什么特点？', 'sub-concept', '思考题'),
#  ('什么是学位论文？它有什么作用？', 'sub-concept', '思考题'),
#  ('什么是专利文献？它有什么特点与作用？', 'sub-concept', '思考题'),
#  ('什么是标准文献？它有什么作用？', 'sub-concept', '思考题')]

# %%
trigram_file = open(r"../tmp/trigram.csv","w",encoding="utf-8")
csv_writer = csv.writer(trigram_file)
for item in triple_list:
    csv_writer.writerow(item)
trigram_file.close()

# %% [markdown]
# 将结果写在csv文件中

# %%
stop_set = set()
stop_list_file_1 = open(r"../stoplist/哈工大停用词表.txt","r",encoding="utf8")
stop_list_file_2 = open(r"../stoplist/百度停用词表.txt","r",encoding="utf8")
stop_list_file_3 = open(r"../stoplist/中文停用词表.txt","r",encoding="utf8")
stop_list_file_4 = open(r"../stoplist/四川大学机器智能实验室停用词库.txt","r",encoding="utf8")
for word in stop_list_file_1.readlines():
    stop_set.add(word.strip())
for word in stop_list_file_2.readlines():
    stop_set.add(word.strip())
for word in stop_list_file_3.readlines():
    stop_set.add(word.strip())
for word in stop_list_file_4.readlines():
    stop_set.add(word.strip())
print(stop_set)
# Out:
# {'', '‘', '就地', '类如', '与否', '反倒是', '－－', 're', '不怎么', 'somehow', '.日', '上述', 'upon', '突出', '］', 'hello', 'which', '中间', '权时', 'furthermore', '略为', '极度', '千万千万', '只有', 'certainly', "it'd", '此中', '∪φ∈', '设使', 'four', '陡然', 'regarding', '你是', '密切', 'Ｒ．Ｌ．', 'thus', '-', 'especially', '此后', '此地', '论说', '—', 'then', '切切', 'some', '不管', '人家', '个', '尽管', '［①Ｄ］', '有所', 'here', 'is', '恰逢', '还是', '不外乎', '+', '表示', '更为', '碰巧', '出于', '不只', '::', '反之亦然', '全然', '马上', '譬如', '"', '欤', '怎样', '④', "we'll", '就是说', '个人', '［②Ｂ］', '极力', 'selves', 'perhaps', 'somebody', '多多少少', '绝顶', '亲手', '砰', '从而', '说说', '要求', 'want', '＜', '自后', '不力', '赶早不赶晚', 'into', '＝（', '平素', '加入', 'hereby', '她的', '离', '甚至', '赶快', '尽心竭力', '根据', '某某', '向着', 'beforehand', 'various', '无法', 'because', 'also', '最', 'moreover', '大约', 'throughout', '竟然', 'merely', 'noone', 'though', '乘隙', 'hereafter', '［③⑩］', 'plus', '十分', '挨次', '动不动', "weren't", 'overall', '极其', '常常', '尽早', '到处', 'does', '......', '转动', '即或', '挨门挨户', '［②②］', '一何', '｝＞', '＇', 'ZZ', '0', '反过来说', '隔夜', '不独', '来得及', '大量', '诚如', '大略', '基于', '而后', '不然的话', '［⑤ｆ］', '只', '之前', '充其极', '够瞧的', '嘎嘎', '着呢', '－［＊］－', '@', '若是', '故此', '借', '}', '将才', '２．３％', '难怪', 'more', '不得已', '有点', 'ignored', 'uses', '通常', '自', '假若', '咚', 'accordingly', '分期分批', '起先', 'truly', '最后', '［③ｃ］', '近年来', ']', 'becomes', '直到', '顷刻之间', '▲', '相信', '凑巧', '恍然', '上面', '⑥', '这就是说', '相当', '方才', '惟其', '何以', '［①ｅ］', '连同', 'still', '呢', 'name', '逐步', '通过', 'Lex', 'sometimes', 'are', '亲眼', '并', '觉得', 'little', '恰巧', '呕', 'regardless', '每个', 'be', '得了', 'ｅ］', 'able', "didn't", '双方', '＞', '腾', '不得', '）÷（１－', '→', '[', '乘虚', '轰然', '从优', '屡次三番', '↑', '抽冷子', '不怕', '该当', '到', 'seem', '当着', '得出', '有利', 'down', '倘使', '此间', '即便', '就算', '八成', '从头', 'contain', '本地', '成年累月', '之类', 'every', 'saying', '尽然', '＜λ', '此', '同样', '总结', '顷刻', '后来', '本人', '因着', '一下', '他们', '［①⑧］', '理当', '尔尔', '［③Ｆ］', '［②⑧］', 'itself', '依照', '它', '反之', 'former', '莫若', '５：０', 'even', '注意', 'got', 'hardly', '豁然', '各人', '不然', 'come', '考虑', '谁知', 'where', 'co', '且不说', '具体', '大力', '别人', '说来', '［②ｊ］', '具体地说', 'should', '’', '但是', '大致', 'whereby', '全都', '转贴', '缕缕', '［②Ｇ］', '以为', '及', 'γ', '嘻', '＋ξ', '㈧', '怎', '若夫', '合理', 'the', 'best', '组成', '对于', '绝对', '维持', '隔日', '仍旧', '没有', '起见', '来看', '年复一年', '即若', '［①］', 'none', '根本', 'will', '如何', '...', '连日', '一转眼', '看', '，', "where's", 'we', '起首', '各地', '大面儿上', '乃至于', '紧接着', '由于', '那时', '单纯', '连日来', '後面', '日益', '以致', '为何', '沿着', 'but', '不但', '倘然', '而且', '但', '即将', '可', 'thanks', 'that', '＋＋', '相同', '［③ｈ］', '：', '眨眼', 'yet', '就是了', '亲口', 'somewhat', '接连不断', '归齐', '引起', '按照', '趁机', 'far', 'their', '某个', '虽', '———', '［②⑩］', '加之', '今後', 'immediate', '⑤', '［④ｃ］', '进而', '上下', '就是', '难道说', '敞开儿', '看见', '显然', '＝', 'example', '兮', 'lately', '大大', '长期以来', '嘎', '$', 'ie', '最大', 'lest', '即如', '奋勇', 'indicate', '另', 'both', '原来', 'que', '与其说', '一一', '而论', '近来', '不曾', '甚而', '一', '清楚', '倍感', '之一', '故而', '／', '不过', '背地里', 'associated', '出去', 'ａ］', '归根到底', '哪样', '~~~~', '哪些', '/', '吓', '最高', '趁热', 'thereupon', 'Δ', '某些', 'have', '看看', 'whatever', 'near', 'tries', 'self', '全力', '［①ｆ］', '真正', '为着', '不变', '坚决', '本身', '自身', '率然', '很少', '长此下去', '总是', '刚巧', 'so', 'you', '不妨', '′∈', '几度', '继之', '加以', '［①②］', 'along', 'else', '乎', '待到', '②ｃ', '&', '从速', '哇', '分头', '［①ｉ］', 'ＺＸＦＩＴＬ', '以至于', '恐怕', '若', 'sometime', '几番', '决定', 'one', '按理', '焉', '－β', '用', '普通', '至', 'containing', '诸如', 'zero', '且说', '要', '知道', '深入', '莫不', '立地', '等等', 'ask', '应该', '［⑦］', '遭到', '愤然', '这会儿', '⑩', '以後', 'had', '实际', '何尝', 'keeps', '随著', '另一个', '准备', '不止一次', '三番两次', "couldn't", '连声', 'follows', '往往', 'specify', '从古到今', 'mostly', '仍', '赖以', '帮助', "wouldn't", 'your', 'unless', '必将', '范围', '朝着', '人', 'allows', '如同', '产生', '看到', '每逢', '三天两头', '而又', '存在', '那边', 'see', '相反', '凡是', '那么样', ',', 'something', '暗地里', '使用', '切勿', 'further', '进入', '共总', '如其', '不尽然', '依据', '方面', '岂非', '有效', '一.', '来讲', ';', '不大', '总的来说', 'elsewhere', '必然', '只怕', '当下', '当地', '趁', 'whole', 'unfortunately', '』', '每当', '％', "hadn't", '不再', '各自', '大抵', '或' ...

# %% [markdown]
# 准备一个停用词表

# %%
thu = thulac.thulac(seg_only=True)
s_string,verb,o_string = triple_list[2]
# s_list = thu.cut(s_string,text=False)
s_list = [word for word,pos in thu.cut(s_string,text=False) if word not in stop_set]
myprint(s_list)
# Out:
# Model loaded succeed
# ['信息',
#  '定义',
#  '广义',
#  '理解',
#  '信息',
#  '物质',
#  '属性',
#  '物质',
#  '方式',
#  '运动',
#  '规律',
#  '表现',
#  '形式',
#  '狭义',
#  '理解',
#  '信息',
#  '消息',
#  '信号',
#  '数据',
#  '资料',
#  '消除',
#  '定性',
#  '东西']

# %% [markdown]
# 测试分词的功能是否可用

# %%
triple_set = set()
thu = thulac.thulac(seg_only=True)
for s_string,v_string,o_string in triple_list:
    s_list = [word for word,pos in thu.cut(s_string,text=False) if word not in stop_set]
    o_list = [word for word,pos in thu.cut(o_string,text=False) if word not in stop_set]
    for s in s_list:
        for o in o_list:
            triple_set.add((s,verb,o))    
myprint(triple_set)
# Out:
# Model loaded succeed
# {(' ', 'sub-concept', '作者'),
#  (' ', 'sub-concept', '信息'),
#  (' ', 'sub-concept', '内容'),
#  (' ', 'sub-concept', '再版'),
#  (' ', 'sub-concept', '出版'),
#  (' ', 'sub-concept', '出版物'),
#  (' ', 'sub-concept', '包括'),
#  (' ', 'sub-concept', '印刷'),
#  (' ', 'sub-concept', '卷'),
#  (' ', 'sub-concept', '各期'),
#  (' ', 'sub-concept', '名称'),
#  (' ', 'sub-concept', '周期'),
#  (' ', 'sub-concept', '固定'),
#  (' ', 'sub-concept', '复制'),
#  (' ', 'sub-concept', '媒体'),
#  (' ', 'sub-concept', '定期'),
#  (' ', 'sub-concept', '少'),
#  (' ', 'sub-concept', '居多'),
#  (' ', 'sub-concept', '年'),
#  (' ', 'sub-concept', '年月'),
#  (' ', 'sub-concept', '手写'),
#  (' ', 'sub-concept', '手段'),
#  (' ', 'sub-concept', '指'),
#  (' ', 'sub-concept', '文章'),
#  (' ', 'sub-concept', '期'),
#  (' ', 'sub-concept', '期刊'),
#  (' ', 'sub-concept', '材料'),
#  (' ', 'sub-concept', '极'),
#  (' ', 'sub-concept', '版式'),
#  (' ', 'sub-concept', '登载'),
#  (' ', 'sub-concept', '篇'),
#  (' ', 'sub-concept', '类型'),
#  (' ', 'sub-concept', '纸张'),
#  (' ', 'sub-concept', '纸质'),
#  (' ', 'sub-concept', '统一'),
#  (' ', 'sub-concept', '续'),
#  (' ', 'sub-concept', '般'),
#  (' ', 'sub-concept', '记录'),
#  (' ', 'sub-concept', '资源'),
#  (' ', 'sub-concept', '超过'),
#  (' ', 'sub-concept', '载体'),
#  (' ', 'sub-concept', '连续'),
#  (' ', 'sub-concept', '重复'),
#  (' ', 'sub-concept', '集合'),
#  (' ', 'sub-concept', '顺序号'),
#  ('10', 'sub-concept', '作者'),
#  ('10', 'sub-concept', '内容'),
#  ('10', 'sub-concept', '再版'),
#  ('10', 'sub-concept', '出版'),
#  ('10', 'sub-concept', '出版物'),
#  ('10', 'sub-concept', '卷'),
#  ('10', 'sub-concept', '各期'),
#  ('10', 'sub-concept', '名称'),
#  ('10', 'sub-concept', '周期'),
#  ('10', 'sub-concept', '固定'),
#  ('10', 'sub-concept', '定期'),
#  ('10', 'sub-concept', '少'),
#  ('10', 'sub-concept', '居多'),
#  ('10', 'sub-concept', '年'),
#  ('10', 'sub-concept', '年月'),
#  ('10', 'sub-concept', '文章'),
#  ('10', 'sub-concept', '期'),
#  ('10', 'sub-concept', '期刊'),
#  ('10', 'sub-concept', '极'),
#  ('10', 'sub-concept', '版式'),
#  ('10', 'sub-concept', '登载'),
#  ('10', 'sub-concept', '篇'),
#  ('10', 'sub-concept', '统一'),
#  ('10', 'sub-concept', '续'),
#  ('10', 'sub-concept', '般'),
#  ('10', 'sub-concept', '超过'),
#  ('10', 'sub-concept', '连续'),
#  ('10', 'sub-concept', '重复'),
#  ('10', 'sub-concept', '顺序号'),
#  ('225', 'sub-concept', '作者'),
#  ('225', 'sub-concept', '内容'),
#  ('225', 'sub-concept', '再版'),
#  ('225', 'sub-concept', '出版'),
#  ('225', 'sub-concept', '出版物'),
#  ('225', 'sub-concept', '卷'),
#  ('225', 'sub-concept', '各期'),
#  ('225', 'sub-concept', '名称'),
#  ('225', 'sub-concept', '周期'),
#  ('225', 'sub-concept', '固定'),
#  ('225', 'sub-concept', '定期'),
#  ('225', 'sub-concept', '少'),
#  ('225', 'sub-concept', '居多'),
#  ('225', 'sub-concept', '年'),
#  ('225', 'sub-concept', '年月'),
#  ('225', 'sub-concept', '文章'),
#  ('225', 'sub-concept', '期'),
#  ('225', 'sub-concept', '期刊'),
#  ('225', 'sub-concept', '极'),
#  ('225', 'sub-concept', '版式'),
#  ('225', 'sub-concept', '登载'),
#  ('225', 'sub-concept', '篇'),
#  ('225', 'sub-concept', '统一'),
#  ('225', 'sub-concept', '续'),
#  ('225', 'sub-concept', '般'),
#  ('225', 'sub-concept', '超过'),
#  ('225', 'sub-concept', '连续'),
#  ('225', 'sub-concept', '重复'),
#  ('225', 'sub-concept', '顺序号'),
#  ('284', 'sub-concept', '作者'),
#  ('284', 'sub-concept', '内容'),
#  ('284', 'sub-concept', '再版'),
#  ('284', 'sub-concept', '出版'),
#  ('284', 'sub-concept', '出版物'),
#  ('284', 'sub-concept', '卷'),
#  ('284', 'sub-concept', '各期'),
#  ('284', 'sub-concept', '名称'),
#  ('284', 'sub-concept', '周期'),
#  ('284', 'sub-concept', '固定'),
#  ('284', 'sub-concept', '定期'),
#  ('284', 'sub-concept', '少'),
#  ('284', 'sub-concept', '居多'),
#  ('284', 'sub-concept', '年'),
#  ('284', 'sub-concept', '年月'),
#  ('284', 'sub-concept', '文章'),
#  ('284', 'sub-concept', '期'),
#  ('284', 'sub-concept', '期刊'),
#  ('284', 'sub-concept', '极'),
#  ('284', 'sub-concept', '版式'),
#  ('284', 'sub-concept', '登载'),
#  ('284', 'sub-concept', '篇'),
#  ('284', 'sub-concept', '统一'),
#  ('284', 'sub-concept', '续'),
#  ('284', 'sub-concept', '般'),
#  ('284', 'sub-concept', '超过'),
#  ('284', 'sub-concept', '连续'),
#  ('284', 'sub-concept', '重复'),
#  ('284', 'sub-concept', '顺序号'),
#  ('49', 'sub-concept', '作者'),
#  ('49', 'sub-concept', '内容'),
#  ('49', 'sub-concept', '再版'),
#  ('49', 'sub-concept', '出版'),
#  ('49', 'sub-concept', '出版物'),
#  ('49', 'sub-concept', '卷'),
#  ('49', 'sub-concept', '各期'),
#  ('49', 'sub-concept', '名称'),
#  ('49', 'sub-concept', '周期'),
#  ('49', 'sub-concept', '固定'),
#  ('49', 'sub-concept', '图书'),
#  ('49', 'sub-concept', '定期'),
#  ('49', 'sub-concept', '少'),
#  ('49', 'sub-concept', '居多'),
#  ('49', 'sub-concept', '年'),
#  ('49', 'sub-concept', '年月'),
#  ('49', 'sub-concept', '文章'),
#  ('49', 'sub-concept', '期'),
#  ('49', 'sub-concept', '期刊'),
#  ('49', 'sub-concept', '极'),
#  ('49', 'sub-concept', '版式'),
#  ('49', 'sub-concept', '登载'),
#  ('49', 'sub-concept', '篇'),
#  ('49', 'sub-concept', '统一'),
#  ('49', 'sub-concept', '续'),
#  ('49', 'sub-concept', '般'),
#  ('49', 'sub-concept', '超过'),
#  ('49', 'sub-concept', '连续'),
#  ('49', 'sub-concept', '重复'),
#  ('49', 'sub-concept', '顺序号'),
#  ('AD', 'sub-concept', '信息'),
#  ('AD', 'sub-concept', '类型'),
#  ('AD', 'sub-concept', '纸质'),
#  ('AD', 'sub-concept', '资源'),
#  ('DOE', 'sub-concept', '信息'),
#  ('DOE', 'sub-concept', '类型'),
#  ('DOE', 'sub-concept', '纸质'),
#  ('DOE', 'sub-concept', '资源'),
#  ('ISO规定', 'sub-concept', '图书'),
#  ('NASA', 'sub-concept', '信息'),
#  ('NASA', 'sub-concept', '类型'),
#  ('NASA', 'sub-concept', '纸质'),
#  ('NASA', 'sub-concept', '资源'),
#  ('PB', 'sub-concept', '信息'),
#  ('PB', 'sub-concept', '类型'),
#  ('PB', 'sub-concept', '纸质'),
#  ('PB', 'sub-concept', '资源'),
#  ('UNISCO', 'sub-concept', '图书'),
#  ('n', 'sub-concept', '信息'),
#  ('n', 'sub-concept', '包括'),
#  ('n', 'sub-concept', '印刷'),
#  ('n', 'sub-concept', '复制'),
#  ('n', 'sub-concept', '媒体'),
#  ('n', 'sub-concept', '手写'),
#  ('n', 'sub-concept', '手段'),
#  ('n', 'sub-concept', '指'),
#  ('n', 'sub-concept', '材料'),
#  ('n', 'sub-concept', '纸张'),
#  ('n', 'sub-concept', '纸质'),
#  ('n', 'sub-concept', '记录'),
#  ('n', 'sub-concept', '资源'),
#  ('n', 'sub-concept', '载体'),
#  ('n', 'sub-concept', '集合'),
#  ('n2', 'sub-concept', '作者'),
#  ('n2', 'sub-concept', '信息'),
#  ('n2', 'sub-concept', '内容'),
#  ('n2', 'sub-concept', '再版'),
#  ('n2', 'sub-concept', '出版'),
#  ('n2', 'sub-concept', '出版物'),
#  ('n2', 'sub-concept', '包括'),
#  ('n2', 'sub-concept', '印刷'),
#  ('n2', 'sub-concept', '卷'),
#  ('n2', 'sub-concept', '各期'),
#  ('n2', 'sub-concept', '名称'),
#  ('n2', 'sub-concept', '周期'),
#  ('n2', 'sub-concept', '固定'),
#  ('n2', 'sub-concept', '复制'),
#  ('n2', 'sub-concept', '媒体'),
#  ('n2', 'sub-concept', '定期'),
#  ('n2', 'sub-concept', '少'),
#  ('n2', 'sub-concept', '居多'),
#  ('n2', 'sub-concept', '年'),
#  ('n2', 'sub-concept', '年月'),
#  ('n2', 'sub-concept', '手写'),
#  ('n2', 'sub-concept', '手段'),
#  ('n2', 'sub-concept', '指'),
#  ('n2', 'sub-concept', '文章'),
#  ('n2', 'sub-concept', '期'),
#  ('n2', 'sub-concept', '期刊'),
#  ('n2', 'sub-concept', '材料'),
#  ('n2', 'sub-concept', '极'),
#  ('n2', 'sub-concept', '版式'),
#  ('n2', 'sub-concept', '登载'),
#  ('n2', 'sub-concept', '篇'),
#  ('n2', 'sub-concept', '纸张'),
#  ('n2', 'sub-concept', '纸质'),
#  ('n2', 'sub-concept', '统一'),
#  ('n2', 'sub-concept', '续'),
#  ('n2', 'sub-concept', '般'),
#  ('n2', 'sub-concept', '记录'),
#  ('n2', 'sub-concept', '资源'),
#  ('n2', 'sub-concept', '超过'),
#  ('n2', 'sub-concept', '载体'),
#  ('n2', 'sub-concept', '连续'),
#  ('n2', 'sub-concept', '重复'),
#  ('n2', 'sub-concept', '集合'),
#  ('n2', 'sub-concept', '顺序号'),
#  ('n倍', 'sub-concept', '作者'),
#  ('n倍', 'sub-concept', '内容'),
#  ('n倍', 'sub-concept', '再版'),
#  ('n倍', 'sub-concept', '出版'),
#  ('n倍', 'sub-concept', '出版物'),
#  ('n倍', 'sub-concept', '卷'),
#  ('n倍', 'sub-concept', '各期'),
#  ('n倍', 'sub-concept', '名称'),
#  ('n倍', 'sub-concept', '周期'),
#  ('n倍', 'sub-concept', '固定'),
#  ('n倍', 'sub-concept', '定期'),
#  ('n倍', 'sub-concept', '少'),
#  ('n倍', 'sub-concept', '居多'),
#  ('n倍', 'sub-concept', '年'),
#  ('n倍', 'sub-concept', '年月'),
#  ('n倍', 'sub-concept', '文章'),
#  ('n倍', 'sub-concept', '期'),
#  ('n倍', 'sub-concept', '期刊'),
#  ('n倍', 'sub-concept', '极'),
#  ('n倍', 'sub-concept', '版式'),
#  ('n倍', 'sub-concept', '登载'),
#  ('n倍', 'sub-concept', '篇'),
#  ('n倍', 'sub-concept', '统一'),
#  ('n倍', 'sub-concept', '续'),
#  ('n倍', 'sub-concept', '般'),
#  ('n倍', 'sub-concept', '超过'),
#  ('n倍', 'sub-concept', '连续'),
#  ('n倍', 'sub-concept', '重复'),
#  ('n倍', 'sub-concept', '顺序号'),
#  ('p', 'sub-concept', '信息'),
#  ('p', 'sub-concept', '包括'),
#  ('p', 'sub-concept', '印刷'),
#  ('p', 'sub-concept', '复制'),
#  ('p', 'sub-concept', '媒体'),
#  ('p', 'sub-concept', '手写'),
#  ('p', 'sub-concept', '手段'),
#  ('p', 'sub-concept', '指'),
#  ('p', 'sub-concept', '材料'),
#  ('p', 'sub-concept', '纸张'),
#  ('p', 'sub-concept', '纸质'),
#  ('p', 'sub-concept', '记录'),
#  ('p', 'sub-concept', '资源'),
#  ('p', 'sub-concept', '载体'),
#  ('p', 'sub-concept', '集合'),
#  ('专利', 'sub-concept', '信息'),
#  ('专利', 'sub-concept', '思考'),
#  ('专利', 'sub-concept', '种类'),
#  ('专利', 'sub-concept', '类型'),
#  ('专利', 'sub-concept', '纸质'),
#  ('专利', 'sub-concept', '资源'),
#  ('专利', 'sub-concept', '题'),
#  ('东西', 'sub-concept', '信息'),
#  ('东西', 'sub-concept', '概述'),
#  ('两', 'sub-concept', '作者'),
#  ('两', 'sub-concept', '信息'),
#  ('两', 'sub-concept', '内容'),
#  ('两', 'sub-concept', '再版'),
#  ('两', 'sub-concept', '出版'),
#  ('两', 'sub-concept', '出版物'),
#  ('两', 'sub-concept', '卷'),
#  ('两', 'sub-concept', '各期'),
#  ('两', 'sub-concept', '名称'),
#  ('两', 'sub-concept', '含义'),
#  ('两', 'sub-concept', '周期'),
#  ('两', 'sub-concept', '固定'),
#  ('两', 'sub-concept', '多种'),
#  ('两', 'sub-concept', '媒体'),
#  ('两', 'sub-concept', '定期'),
#  ('两', 'sub-concept', '少'),
#  ('两', 'sub-concept', '居多'),
#  ('两', 'sub-concept', '年'),
#  ('两', 'sub-concept', '年月'),
#  ('两', 'sub-concept', '文章'),
#  ('两', 'sub-concept', '期'),
#  ('两', 'sub-concept', '期刊'),
#  ('两', 'sub-concept', '极'),
#  ('两', 'sub-concept', '版式'),
#  ('两', 'sub-concept', '登载'),
#  ('两', 'sub-concept', '看法'),
#  ('两', 'sub-concept', '种类'),
#  ('两', 'sub-concept', '篇'),
#  ('两', 'sub-concept', '统一'),
#  ('两', 'sub-concept', '续'),
#  ('两', 'sub-concept', '般'),
#  ('两', 'sub-concept', '资源'),
#  ('两', 'sub-concept', '超过'),
#  ('两', 'sub-concept', '连续'),
#  ('两', 'sub-concept', '重复'),
#  ('两', 'sub-concept', '顺序号'),
#  ('中', 'sub-concept', '作者'),
#  ('中', 'sub-concept', '信息'),
#  ('中', 'sub-concept', '内容'),
#  ('中', 'sub-concept', '再版'),
#  ('中', 'sub-concept', '出版'),
#  ('中', 'sub-concept', '出版物'),
#  ('中', 'sub-concept', '包括'),
#  ('中', 'sub-concept', '印刷'),
#  ('中', 'sub-concept', '卷'),
#  ('中', 'sub-concept', '各期'),
#  ('中', 'sub-concept', '名称'),
#  ('中', 'sub-concept', '含义'),
#  ('中', 'sub-concept', '周期'),
#  ('中', 'sub-concept', '固定'),
#  ('中', 'sub-concept', '复制'),
#  ('中', 'sub-concept', '多种'),
#  ('中', 'sub-concept', '媒体'),
#  ('中', 'sub-concept', '定期'),
#  ('中', 'sub-concept', '少'),
#  ('中', 'sub-concept', '居多'),
#  ('中', 'sub-concept', '年'),
#  ('中', 'sub-concept', '年月'),
#  ('中', 'sub-concept', '手写'),
#  ('中', 'sub-concept', '手段'),
#  ('中', 'sub-concept', '指'),
#  ('中', 'sub-concept', '文章'),
#  ('中', 'sub-concept', '期'),
#  ('中', 'sub-concept', '期刊'),
#  ('中', 'sub-concept', '材料'),
#  ('中', 'sub-concept', '极'),
#  ('中', 'sub-concept', '版式'),
#  ('中', 'sub-concept', '登载'),
#  ('中', 'sub-concept', '看法'),
#  ('中', 'sub-concept', '篇'),
#  ('中', 'sub-concept', '纸张'),
#  ('中', 'sub-concept', '纸质'),
#  ('中', 'sub-concept', '统一'),
#  ('中', 'sub-concept', '续'),
#  ('中', 'sub-concept', '般'),
#  ('中', 'sub-concept', '记录'),
#  ('中', 'sub-concept', '资源'),
#  ('中', 'sub-concept', '超过'),
#  ('中', 'sub-concept', '载体'),
#  ('中', 'sub-concept', '连续'),
#  ('中', 'sub-concept', '重复'),
#  ('中', 'sub-concept', '集合'),
#  ('中', 'sub-concept', '顺序号'),
#  ('主观', 'sub-concept', '两'),
#  ('主观', 'sub-concept', '信息'),
#  ('主观', 'sub-concept', '分'),
#  ('主观', 'sub-concept', '含义'),
#  ('主观', 'sub-concept', '媒体'),
#  ('主观', 'sub-concept', '客观'),
#  ('主观', 'sub-concept', '密'),
#  ('主观', 'sub-concept', '称'),
#  ('主观', 'sub-concept', '类'),
#  ('主观', 'sub-concept', '载体'),
#  ('之上', 'sub-concept', '图书'),
#  ('书刊', 'sub-concept', '信息'),
#  ('书刊', 'sub-concept', '种类'),
#  ('书刊', 'sub-concept', '资源'),
#  ('书目', 'sub-concept', '信息'),
#  ('书目', 'sub-concept', '类型'),
#  ('书目', 'sub-concept', '纸质'),
#  ('书目', 'sub-concept', '资源'),
#  ('交流', 'sub-concept', '两'),
#  ('交流', 'sub-concept', '信息'),
#  ('交流', 'sub-concept', '分'),
#  ('交流', 'sub-concept', '含义'),
#  ('交流', 'sub-concept', '媒体'),
#  ('交流', 'sub-concept', '客观'),
#  ('交流', 'sub-concept', '密'),
#  ('交流', 'sub-concept', '称'),
#  ('交流', 'sub-concept', '类'),
#  ('交流', 'sub-concept', '类型'),
#  ('交流', 'sub-concept', '纸质'),
#  ('交流', 'sub-concept', '资源'),
#  ('交流', 'sub-concept', '载体'),
#  ('产品', 'sub-concept', '信息'),
#  ('产品', 'sub-concept', '种类'),
#  ('产品', 'sub-concept', '类型'),
#  ('产品', 'sub-concept', '纸质'),
#  ('产品', 'sub-concept', '资源'),
#  ('产权', 'sub-concept', '信息'),
#  ('产权', 'sub-concept', '类型'),
#  ('产权', 'sub-concept', '纸质'),
#  ('产权', 'sub-concept', '资源'),
#  ('人才', 'sub-concept', '作者'),
#  ('人才', 'sub-concept', '内容'),
#  ('人才', 'sub-concept', '再版'),
#  ('人才', 'sub-concept', '出版'),
#  ('人才', 'sub-concept', '出版物'),
#  ('人才', 'sub-concept', '卷'),
#  ('人才', 'sub-concept', '各期'),
#  ('人才', 'sub-concept', '名称'),
#  ('人才', 'sub-concept', '周期'),
#  ('人才', 'sub-concept', '固定'),
#  ('人才', 'sub-concept', '定期'),
#  ('人才', 'sub-concept', '少'),
#  ('人才', 'sub-concept', '居多'),
#  ('人才', 'sub-concept', '年'),
#  ('人才', 'sub-concept', '年月'),
#  ('人才', 'sub-concept', '文章'),
#  ('人才', 'sub-concept', '期'),
#  ('人才', 'sub-concept', '期刊'),
#  ('人才', 'sub-concept', '极'),
#  ('人才', 'sub-concept', '版式'),
#  ('人才', 'sub-concept', '登载'),
#  ('人才', 'sub-concept', '篇'),
#  ('人才', 'sub-concept', '统一'),
#  ('人才', 'sub-concept', '续'),
#  ('人才', 'sub-concept', '般'),
#  ('人才', 'sub-concept', '超过'),
#  ('人才', 'sub-concept', '连续'),
#  ('人才', 'sub-concept', '重复'),
#  ('人才', 'sub-concept', '顺序号'),
#  ('人类', 'sub-concept', '两'),
#  ('人类', 'sub-concept', '信息'),
#  ('人类', 'sub-concept', '分'),
#  ('人类', 'sub-concept', '含义'),
#  ('人类', 'sub-concept', '多种'),
#  ('人类', 'sub-concept', '媒体'),
#  ('人类', 'sub-concept', '客观'),
#  ('人类', 'sub-concept', '密'),
#  ('人类', 'sub-concept', '看法'),
#  ('人类', 'sub-concept', '称'),
#  ('人类', 'sub-concept', '类'),
#  ('人类', 'sub-concept', '资源'),
#  ('人类', 'sub-concept', '载体'),
#  ('人脑', 'sub-concept', '两'),
#  ('人脑', 'sub-concept', '信息'),
#  ('人脑', 'sub-concept', '分'),
#  ('人脑', 'sub-concept', '含义'),
#  ('人脑', 'sub-concept', '媒体'),
#  ('人脑', 'sub-concept', '客观'),
#  ('人脑', 'sub-concept', '密'),
#  ('人脑', 'sub-concept', '称'),
#  ('人脑', 'sub-concept', '类'),
#  ('人脑', 'sub-concept', '载体'),
#  ('什', 'sub-concept', '信息'),
#  ('什', 'sub-concept', '思考'),
#  ('什', 'sub-concept', '种类'),
#  ('什', 'sub-concept', '资源'),
#  ('什', 'sub-concept', '题'),
#  ('代号', 'sub-concept', '信息'),
#  ('代号', 'sub-concept', '类型'),
#  ('代号', 'sub-concept', '纸质'),
#  ('代号', 'sub-concept', '资源'),
#  ('代表', 'sub-concept', '信息'),
#  ('代表', 'sub-concept', '包括'),
#  ('代表', 'sub-concept', '印刷'),
#  ('代表', 'sub-concept', '复制'),
#  ('代表', 'sub-concept', '媒体'),
#  ('代表', 'sub-concept', '手写'),
#  ('代表', 'sub-concept', '手段'),
#  ('代表', 'sub-concept', '指'),
#  ('代表', 'sub-concept', '材料'),
#  ('代表', 'sub-concept', '纸张'),
#  ('代表', 'sub-concept', '纸质'),
#  ('代表', 'sub-concept', '要素'),
#  ('代表', 'sub-concept', '记录'),
#  ('代表', 'sub-concept', '资源'),
#  ('代表', 'sub-concept', '载体'),
#  ('代表', 'sub-concept', '集合'),
#  ('价', 'sub-concept', '信息'),
#  ('价', 'sub-concept', '含义'),
#  ('价', 'sub-concept', '多种'),
#  ('价', 'sub-concept', '特性'),
#  ('价', 'sub-concept', '看法'),
#  ('价', 'sub-concept', '类型'),
#  ('价', 'sub-concept', '纸质'),
#  ('价', 'sub-concept', '资源'),
#  ('企业', 'sub-concept', '信息'),
#  ('企业', 'sub-concept', '类型'),
#  ('企业', 'sub-concept', '纸质'),
#  ('企业', 'sub-concept', '资源'),
#  ('优缺点', 'sub-concept', '信息'),
#  ('优缺点', 'sub-concept', '种类'),
#  ('优缺点', 'sub-concept', '资源'),
#  ('会议', 'sub-concept', '信息'),
#  ('会议', 'sub-concept', '思考'),
#  ('会议', 'sub-concept', '种类'),
#  ('会议', 'sub-concept', '类型'),
#  ('会议', 'sub-concept', '纸质'),
#  ('会议', 'sub-concept', '资源'),
#  ('会议', 'sub-concept', '题'),
#  ('会议录', 'sub-concept', '信息'),
#  ('会议录', 'sub-concept', '类型'),
#  ('会议录', 'sub-concept', '纸质'),
#  ('会议录', 'sub-concept', '资源'),
#  ('传递', 'sub-concept', '两'),
#  ('传递', 'sub-concept', '作者'),
#  ('传递', 'sub-concept', '信息'),
#  ('传递', 'sub-concept', '内容'),
#  ('传递', 'sub-concept', '再版'),
#  ('传递', 'sub-concept', '出版'),
#  ('传递', 'sub-concept', '出版物'),
#  ('传递', 'sub-concept', '分'),
#  ('传递', 'sub-concept', '卷'),
#  ('传递', 'sub-concept', '各期'),
#  ('传递', 'sub-concept', '名称'),
#  ('传递', 'sub-concept', '含义'),
#  ('传递', 'sub-concept', '周期'),
#  ('传递', 'sub-concept', '固定'),
#  ('传递', 'sub-concept', '图书'),
#  ('传递', 'sub-concept', '媒体'),
#  ('传递', 'sub-concept', '定期'),
#  ('传递', 'sub-concept', '客观'),
#  ('传递', 'sub-concept', '密'),
#  ('传递', 'sub-concept', '少'),
#  ('传递', 'sub-concept', '居多'),
#  ('传递', 'sub-concept', '年'),
#  ('传递', 'sub-concept', '年月'),
#  ('传递', 'sub-concept', '文章'),
#  ('传递', 'sub-concept', '期'),
#  ('传递', 'sub-concept', '期刊'),
#  ('传递', 'sub-concept', '极'),
#  ('传递', 'sub-concept', '版式'),
#  ('传递', 'sub-concept', '登载'),
#  ('传递', 'sub-concept', '称'),
#  ('传递', 'sub-concept', '篇'),
#  ('传递', 'sub-concept', '类'),
#  ('传递', 'sub-concept', '类型'),
#  ('传递', 'sub-concept', '纸质'),
#  ('传递', 'sub-concept', '统一'),
#  ('传递', 'sub-concept', '续'),
#  ('传递', 'sub-concept', '般'),
#  ('传递', 'sub-concept', '资源'),
#  ('传递', 'sub-concept', '超过'),
#  ('传递', 'sub-concept', '载体'),
#  ('传递', 'sub-concept', '连续'),
#  ('传递', 'sub-concept', '重复'),
#  ('传递', 'sub-concept', '顺序号'),
#  ('伴随', 'sub-concept', '信息'),
#  ('伴随', 'sub-concept', '类型'),
#  ('伴随', 'sub-concept', '纸质'),
#  ('伴随', 'sub-concept', '资源'),
#  ('体例', 'sub-concept', '图书'),
#  ('体系', 'sub-concept', '信息'),
#  ('体系', 'sub-concept', '类型'),
#  ('体系', 'sub-concept', '纸质'),
#  ('体系', 'sub-concept', '资源'),
#  ('作用', 'sub-concept', '作者'),
#  ('作用', 'sub-concept', '信息'),
#  ('作用', 'sub-concept', '内容'),
#  ('作用', 'sub-concept', '再版'),
#  ('作用', 'sub-concept', '出版'),
#  ('作用', 'sub-concept', '出版物'),
#  ('作用', 'sub-concept', '卷'),
#  ('作用', 'sub-concept', '各期'),
#  ('作用', 'sub-concept', '名称'),
#  ('作用', 'sub-concept', '周期'),
#  ('作用', 'sub-concept', '固定'),
#  ('作用', 'sub-concept', '定期'),
#  ('作用', 'sub-concept', '少'),
#  ('作用', 'sub-concept', '居多'),
#  ('作用', 'sub-concept', '年'),
#  ('作用', 'sub-concept', '年月'),
#  ('作用', 'sub-concept', '思考'),
#  ('作用', 'sub-concept', '文章'),
#  ('作用', 'sub-concept', '期'),
#  ('作用', 'sub-concept', '期刊'),
#  ('作用', 'sub-concept', '极'),
#  ('作用', 'sub-concept', '概述'),
#  ('作用', 'sub-concept', '版式'),
#  ('作用', 'sub-concept', '登载'),
#  ('作用', 'sub-concept', '种类'),
#  ('作用', 'sub-concept', '篇'),
#  ('作用', 'sub-concept', '类型'),
#  ('作用', 'sub-concept', '纸质'),
#  ('作用', 'sub-concept', '统一'),
#  ('作用', 'sub-concept', '续'),
#  ('作用', 'sub-concept', '般'),
#  ('作用', 'sub-concept', '资源'),
#  ('作用', 'sub-concept', '超过'),
#  ('作用', 'sub-concept', '连续'),
#  ('作用', 'sub-concept', '重复'),
#  ('作用', 'sub-concept', '顺序号'),
#  ('作用', 'sub-concept', '题'),
#  ('作者', 'sub-concept', '信息'),
#  ('作者', 'sub-concept', '包括'),
#  ('作者', 'sub-concept', '印刷'),
#  ('作者', 'sub-concept', '复制'),
#  ('作者', 'sub-concept', '媒体'),
#  ('作者', 'sub-concept', '手写'),
#  ('作者', 'sub-concept', '手段'),
#  ('作者', 'sub-concept', '指'),
#  ('作者', 'sub-concept', '材料'),
#  ('作者', 'sub-concept', '纸张'),
#  ('作者', 'sub-concept', '纸质'),
#  ('作者', 'sub-concept', '记录'),
#  ('作者', 'sub-concept', '资源'),
#  ('作者', 'sub-concept', '载体'),
#  ('作者', 'sub-concept', '集合'),
#  ('使用者', 'sub-concept', '信息'),
#  ('使用者', 'sub-concept', '种类'),
#  ('使用者', 'sub-concept', '资源'),
#  ('供', 'sub-concept', '信息'),
#  ('供', 'sub-concept', '种类'),
#  ('供', 'sub-concept', '资源'),
#  ('依附体', 'sub-concept', '信息'),
#  ('依附体', 'sub-concept', '媒体'),
#  ('依附体', 'sub-concept', '要素'),
#  ('依附性', 'sub-concept', '信息'),
#  ('依附性', 'sub-concept', '特征'),
#  ('侵权', 'sub-concept', '信息'),
#  ('侵权', 'sub-concept', '类型'),
#  ('侵权', 'sub-concept', '纸质'),
#  ('侵权', 'sub-concept', '资源'),
#  ('保存', 'sub-concept', '两'),
#  ('保存', 'sub-concept', '信息'),
#  ('保存', 'sub-concept', '分'),
#  ('保存', 'sub-concept', '含义'),
#  ('保存', 'sub-concept', '图书'),
#  ('保存', 'sub-concept', '媒体'),
#  ('保存', 'sub-concept', '客观'),
#  ('保存', 'sub-concept', '密'),
#  ('保存', 'sub-concept', '种类'),
#  ('保存', 'sub-concept', '称'),
#  ('保存', 'sub-concept', '类'),
#  ('保存', 'sub-concept', '资源'),
#  ('保存', 'sub-concept', '载体'),
#  ('保存型', 'sub-concept', '信息'),
#  ('保存型', 'sub-concept', '种类'),
#  ('保存型', 'sub-concept', '资源'),
#  ('保护', 'sub-concept', '信息'),
#  ('保护', 'sub-concept', '类型'),
#  ('保护', 'sub-concept', '纸质'),
#  ('保护', 'sub-concept', '资源'),
#  ('信号', 'sub-concept', '信息'),
#  ('信号', 'sub-concept', '概述'),
#  ('信息', 'sub-concept', '两'),
#  ('信息', 'sub-concept', '作者'),
#  ('信息', 'sub-concept', '信息'),
#  ('信息', 'sub-concept', '内容'),
#  ('信息', 'sub-concept', '再版'),
#  ('信息', 'sub-concept', '出版'),
#  ('信息', 'sub-concept', '出版物'),
#  ('信息', 'sub-concept', '分'),
#  ('信息', 'sub-concept', '包括'),
#  ('信息', 'sub-concept', '印刷'),
#  ('信息', 'sub-concept', '卷'),
#  ('信息', 'sub-concept', '各期'),
#  ('信息', 'sub-concept', '名称'),
#  ('信息', 'sub-concept', '含义'),
#  ('信息', 'sub-concept', '周期'),
#  ('信息', 'sub-concept', '固定'),
#  ('信息', 'sub-concept', '图书'),
#  ('信息', 'sub-concept', '复制'),
#  ('信息', 'sub-concept', '多种'),
#  ('信息', 'sub-concept', '媒体'),
#  ('信息', 'sub-concept', '定期'),
#  ('信息', 'sub-concept', '客观'),
#  ('信息', 'sub-concept', '密'),
#  ('信息', 'sub-concept', '少'),
#  ('信息', 'sub-concept', '居多'),
#  ('信息', 'sub-concept', '年'),
#  ('信息', 'sub-concept', '年月'),
#  ('信息', 'sub-concept', '建设'),
#  ('信息', 'sub-concept', '手写'),
#  ('信息', 'sub-concept', '手段'),
#  ('信息', 'sub-concept', '指'),
#  ('信息', 'sub-concept', '文章'),
#  ('信息', 'sub-concept', '期'),
#  ('信息', 'sub-concept', '期刊'),
#  ('信息', 'sub-concept', '材料'),
#  ('信息', 'sub-concept', '极'),
#  ('信息', 'sub-concept', '概述'),
#  ('信息', 'sub-concept', '版式'),
#  ('信息', 'sub-concept', '登载'),
#  ('信息', 'sub-concept', '看法'),
#  ('信息', 'sub-concept', '种类'),
#  ('信息', 'sub-concept', '称'),
#  ('信息', 'sub-concept', '篇'),
#  ('信息', 'sub-concept', '类'),
#  ('信息', 'sub-concept', '类型'),
#  ('信息', 'sub-concept', '纸张'),
#  ('信息', 'sub-concept', '纸质'),
#  ('信息', 'sub-concept', '统一'),
#  ('信息', 'sub-concept', '续'),
#  ('信息', 'sub-concept', '般'),
#  ('信息', 'sub-concept', '要素'),
#  ('信息', 'sub-concept', '记录'),
#  ('信息', 'sub-concept', '资源'),
#  ('信息', 'sub-concept', '超过'),
#  ('信息', 'sub-concept', '载体'),
#  ('信息', 'sub-concept', '连续'),
#  ('信息', 'sub-concept', '重复'),
#  ('信息', 'sub-concept', '集合'),
#  ('信息', 'sub-concept', '顺序号'),
#  ('信息源', 'sub-concept', '两'),
#  ('信息源', 'sub-concept', '信息'),
#  ('信息源', 'sub-concept', '分'),
#  ('信息源', 'sub-concept', '含义'),
#  ('信息源', 'sub-concept', '媒体'),
#  ('信息源', 'sub-concept', '客观'),
#  ('信息源', 'sub-concept', '密'),
#  ('信息源', 'sub-concept', '种类'),
#  ('信息源', 'sub-concept', '称'),
#  ('信息源', 'sub-concept', '类'),
#  ('信息源', 'sub-concept', '资源'),
#  ('信息源', 'sub-concept', '载体'),
#  ('倍', 'sub-concept', '作者'),
#  ('倍', 'sub-concept', '内容'),
#  ('倍', 'sub-concept', '再版'),
#  ('倍', 'sub-concept', '出版'),
#  ('倍', 'sub-concept', '出版物'),
#  ('倍', 'sub-concept', '卷'),
#  ('倍', 'sub-concept', '各期'),
#  ('倍', 'sub-concept', '名称'),
#  ('倍', 'sub-concept', '周期'),
#  ('倍', 'sub-concept', '固定'),
#  ('倍', 'sub-concept', '定期'),
#  ('倍', 'sub-concept', '少'),
#  ('倍', 'sub-concept', '居多'),
#  ('倍', 'sub-concept', '年'),
#  ('倍', 'sub-concept', '年月'),
#  ('倍', 'sub-concept', '文章'),
#  ('倍', 'sub-concept', '期'),
#  ('倍', 'sub-concept', '期刊'),
#  ('倍', 'sub-concept', '极'),
#  ('倍', 'sub-concept', '版式'),
#  ('倍', 'sub-concept', '登载'),
#  ('倍', 'sub-concept', '篇'),
#  ('倍', 'sub-concept', '统一'),
#  ('倍', 'sub-concept', '续'),
#  ('倍', 'sub-concept', '般'),
#  ('倍', 'sub-concept', '超过'),
#  ('倍', 'sub-concept', '连续'),
#  ('倍', 'sub-concept', '重复'),
#  ('倍', 'sub-concept', '顺序号'),
#  ('值', 'sub-concept', '信息'),
#  ('值', 'sub-concept', '特性'),
#  ('值', 'sub-concept', '类型'),
#  ('值', 'sub-concept', '纸质'),
#  ('值', 'sub-concept', '资源'),
#  ('先进', 'sub-concept', '信息'),
#  ('先进', 'sub-concept', '类型'),
#  ('先进', 'sub-concept', '纸质'),
#  ('先进', 'sub-concept', '资源'),
#  ('光波', 'sub-concept', '两'),
#  ('光波', 'sub-concept', '信息'),
#  ('光波', 'sub-concept', '分'),
#  ('光波', 'sub-concept', '含义'),
#  ('光波', 'sub-concept', '媒体'),
#  ('光波', 'sub-concept', '客观'),
#  ('光波', 'sub-concept', '密'),
#  ('光波', 'sub-concept', '称'),
#  ('光波', 'sub-concept', '类'),
#  ('光波', 'sub-concept', '载体'),
#  ('光盘', 'sub-concept', '两'),
#  ('光盘', 'sub-concept', '信息'),
#  ('光盘', 'sub-concept', '分'),
#  ('光盘', 'sub-concept', '含义'),
#  ('光盘', 'sub-concept', '媒体'),
#  ('光盘', 'sub-concept', '客观'),
#  ('光盘', 'sub-concept', '密'),
#  ('光盘', 'sub-concept', '种类'),
#  ('光盘', 'sub-concept', '称'),
#  ('光盘', 'sub-concept', '类'),
#  ('光盘', 'sub-concept', '资源'),
#  ('光盘', 'sub-concept', '载体'),
#  ('免费', 'sub-concept', '信息'),
#  ('免费', 'sub-concept', '种类'),
#  ('免费', 'sub-concept', '类型'),
#  ('免费', 'sub-concept', '纸质'),
#  ('免费', 'sub-concept', '资源'),
#  ('入', 'sub-concept', '信息'),
#  ('入', 'sub-concept', '种类'),
#  ('入', 'sub-concept', '资源'),
#  ('公司', 'sub-concept', '信息'),
#  ('公司', 'sub-concept', '类型'),
#  ('公司', 'sub-concept', '纸质'),
#  ('公司', 'sub-concept', '资源'),
#  ('公布', 'sub-concept', '信息'),
#  ('公布', 'sub-concept', '类型'),
#  ('公布', 'sub-concept', '纸质'),
#  ('公布', 'sub-concept', '资源'),
#  ('公开', 'sub-concept', '信息'),
#  ('公开', 'sub-concept', '类型'),
#  ('公开', 'sub-concept', '纸质'),
#  ('公开', 'sub-concept', '资源'),
#  ('共', 'sub-concept', '作者'),
#  ('共', 'sub-concept', '内容'),
#  ('共', 'sub-concept', '再版'),
#  ('共', 'sub-concept', '出版'),
#  ('共', 'sub-concept', '出版物'),
#  ('共', 'sub-concept', '卷'),
#  ('共', 'sub-concept', '各期'),
#  ('共', 'sub-concept', '名称'),
#  ('共', 'sub-concept', '周期'),
#  ('共', 'sub-concept', '固定'),
#  ('共', 'sub-concept', '定期'),
#  ('共', 'sub-concept', '少'),
#  ('共', 'sub-concept', '居多'),
#  ('共', 'sub-concept', '年'),
#  ('共', 'sub-concept', '年月'),
#  ('共', 'sub-concept', '文章'),
#  ('共', 'sub-concept', '期'),
#  ('共', 'sub-concept', '期刊'),
#  ('共', 'sub-concept', '极'),
#  ('共', 'sub-concept', '版式'),
#  ('共', 'sub-concept', '登载'),
#  ('共', 'sub-concept', '篇'),
#  ('共', 'sub-concept', '统一'),
#  ('共', 'sub-concept', '续'),
#  ('共', 'sub-concept', '般'),
#  ('共', 'sub-concept', '超过'),
#  ('共', 'sub-concept', '连续'),
#  ('共', 'sub-concept', '重复'),
#  ('共', 'sub-concept', '顺序号'),
#  ('共享性', 'sub-concept', '信息'),
#  ('共享性', 'sub-concept', '特征'),
#  ('内外', 'sub-concept', '信息'),
#  ('内外', 'sub-concept', '含义'),
#  ('内外', 'sub-concept', '多种'),
#  ('内外', 'sub-concept', '看法'),
#  ('内外', 'sub-concept', '资源'),
#  ('内容', 'sub-concept', '两'),
#  ('内容', 'sub-concept', '信息'),
#  ('内容', 'sub-concept', '分'),
#  ('内容', 'sub-concept', '包括'),
#  ('内容', 'sub-concept', '印刷'),
#  ('内容', 'sub-concept', '含义'),
#  ('内容', 'sub-concept', '图书'),
#  ('内容', 'sub-concept', '复制'),
#  ('内容', 'sub-concept', '媒体'),
#  ('内容', 'sub-concept', '客观'),
#  ('内容', 'sub-concept', '密'),
#  ('内容', 'sub-concept', '手写'),
#  ('内容', 'sub-concept', '手段'),
#  ('内容', 'sub-concept', '指'),
#  ('内容', 'sub-concept', '材料'),
#  ('内容', 'sub-concept', '称'),
#  ('内容', 'sub-concept', '类'),
#  ('内容', 'sub-concept', '类型'),
#  ('内容', 'sub-concept', '纸张'),
#  ('内容', 'sub-concept', '纸质'),
#  ('内容', 'sub-concept', '要素'),
#  ('内容', 'sub-concept', '记录'),
#  ('内容', 'sub-concept', '资源'),
#  ('内容', 'sub-concept', '载体'),
#  ('内容', 'sub-concept', '集合'),
#  ('再版', 'sub-concept', '信息'),
#  ('再版', 'sub-concept', '包括'),
#  ('再版', 'sub-concept', '印刷'),
#  ('再版', 'sub-concept', '复制'),
#  ('再版', 'sub-concept', '媒体'),
#  ('再版', 'sub-concept', '手写'),
#  ('再版', 'sub-concept', '手段'),
#  ('再版', 'sub-concept', '指'),
#  ('再版', 'sub-concept', '材料'),
#  ('再版', 'sub-concept', '纸张'),
#  ('再版', 'sub-concept', '纸质'),
#  ('再版', 'sub-concept', '记录'),
#  ('再版', 'sub-concept', '资源'),
#  ('再版', 'sub-concept', '载体'),
#  ('再版', 'sub-concept', '集合'),
#  ('再生性', 'sub-concept', '信息'),
#  ('再生性', 'sub-concept', '特性'),
#  ('再生性', 'sub-concept', '资源'),
#  ('冗余性', 'sub-concept', '信息'),
#  ('冗余性', 'sub-concept', '特性'),
#  ('冗余性', 'sub-concept', '资源'),
#  ('决策', 'sub-concept', '作用'),
#  ('决策', 'sub-concept', '信息'),
#  ('决策', 'sub-concept', '功能'),
#  ('决策', 'sub-concept', '类型'),
#  ('决策', 'sub-concept', '纸质'),
#  ('决策', 'sub-concept', '资源'),
#  ('决议', 'sub-concept', '信息'),
#  ('决议', 'sub-concept', '类型'),
#  ('决议', 'sub-concept', '纸质'),
#  ('决议', 'sub-concept', '资源'),
#  ('准确', 'sub-concept', '信息'),
#  ('准确', 'sub-concept', '类型'),
#  ('准确', 'sub-concept', '纸质'),
#  ('准确', 'sub-concept', '资源'),
#  ('出发', 'sub-concept', '信息'),
#  ('出发', 'sub-concept', '含义'),
#  ('出发', 'sub-concept', '多种'),
#  ('出发', 'sub-concept', '看法'),
#  ('出发', 'sub-concept', '资源'),
#  ('出版', 'sub-concept', '信息'),
#  ('出版', 'sub-concept', '包括'),
#  ('出版', 'sub-concept', '印刷'),
#  ('出版', 'sub-concept', '复制'),
#  ('出版', 'sub-concept', '媒体'),
#  ('出版', 'sub-concept', '手写'),
#  ('出版', 'sub-concept', '手段'),
#  ('出版', 'sub-concept', '指'),
#  ('出版', 'sub-concept', '材料'),
#  ('出版', 'sub-concept', '种类'),
#  ('出版', 'sub-concept', '类型'),
#  ('出版', 'sub-concept', '纸张'),
#  ('出版', 'sub-concept', '纸质'),
#  ('出版', 'sub-concept', '记录'),
#  ('出版', 'sub-concept', '资源'),
#  ('出版', 'sub-concept', '载体'),
#  ('出版', 'sub-concept', '集合'),
#  ('出版物', 'sub-concept', '信息'),
#  ('出版物', 'sub-concept', '包括'),
#  ('出版物', 'sub-concept', '印刷'),
#  ('出版物', 'sub-concept', '图书'),
#  ('出版物', 'sub-concept', '复制'),
#  ('出版物', 'sub-concept', '媒体'),
#  ('出版物', 'sub-concept', '思考'),
#  ('出版物', 'sub-concept', '手写'),
#  ('出版物', 'sub-concept', '手段'),
#  ('出版物', 'sub-concept', '指'),
#  ('出版物', 'sub-concept', '材料'),
#  ('出版物', 'sub-concept', '种类'),
#  ('出版物', 'sub-concept', '类型'),
#  ('出版物', 'sub-concept', '纸张'),
#  ('出版物', 'sub-concept', '纸质'),
#  ('出版物', 'sub-concept', '记录'),
#  ('出版物', 'sub-concept', '资源'),
#  ('出版物', 'sub-concept', '载体'),
#  ('出版物', 'sub-concept', '集合'),
#  ('出版物', 'sub-concept', '题'),
#  ('分', 'sub-concept', '信息'),
#  ('分', 'sub-concept', '媒体'),
#  ('分为', 'sub-concept', '信息'),
#  ('分为', 'sub-concept', '类型'),
#  ('分为', 'sub-concept', '纸质'),
#  ('分为', 'sub-concept', '资源'),
#  ('分布', 'sub-concept', '信息'),
#  ('分布', 'sub-concept', '包括'),
#  ('分布', 'sub-concept', '印刷'),
#  ('分布', 'sub-concept', '复制'),
#  ('分布', 'sub-concept', '媒体'),
#  ('分布', 'sub-concept', '手写'),
#  ('分布', 'sub-concept', '手段'),
#  ('分布', 'sub-concept', '指'),
#  ('分布', 'sub-concept', '材料'),
#  ('分布', 'sub-concept', '纸张'),
#  ('分布', 'sub-concept', '纸质'),
#  ('分布', 'sub-concept', '记录'),
#  ('分布', 'sub-concept', '资源'),
#  ('分布', 'sub-concept', '载体'),
#  ('分布', 'sub-concept', '集合'),
#  ('分类表', 'sub-concept', '信息'),
#  ('分类表', 'sub-concept', '类型'),
#  ('分类表', 'sub-concept', '纸质'),
#  ('分类表', 'sub-concept', '资源'),
#  ('刊载', 'sub-concept', '信息'),
#  ('刊载', 'sub-concept', '包括'),
#  ('刊载', 'sub-concept', '印刷'),
#  ('刊载', 'sub-concept', '复制'),
#  ('刊载', 'sub-concept', '媒体'),
#  ('刊载', 'sub-concept', '手写'),
#  ('刊载', 'sub-concept', '手段'),
#  ('刊载', 'sub-concept', '指'),
#  ('刊载', 'sub-concept', '材料'),
#  ('刊载', 'sub-concept', '纸张'),
#  ('刊载', 'sub-concept', '纸质'),
#  ('刊载', 'sub-concept', '记录'),
#  ('刊载', 'sub-concept', '资源'),
#  ('刊载', 'sub-concept', '载体'),
#  ('刊载', 'sub-concept', '集合'),
#  ('划分', 'sub-concept', '信息'),
#  ('划分', 'sub-concept', '种类'),
#  ('划分', 'sub-concept', '资源'),
#  ('创造', 'sub-concept', '信息'),
#  ('创造', 'sub-concept', '含义'),
#  ('创造', 'sub-concept', '多种'),
#  ('创造', 'sub-concept', '看法'),
#  ('创造', 'sub-concept', '资源'),
#  ('判别', 'sub-concept', '信息'),
#  ('判别', 'sub-concept', '包括'),
#  ('判别', 'sub-concept', '印刷'),
#  ('判别', 'sub-concept', '复制'),
#  ('判别', 'sub-concept', '媒体'),
#  ('判别', 'sub-concept', '思考'),
#  ('判别', 'sub-concept', '手写'),
#  ('判别', 'sub-concept', '手段'),
#  ('判别', 'sub-concept', '指'),
#  ('判别', 'sub-concept', '材料'),
#  ('判别', 'sub-concept', '纸张'),
#  ('判别', 'sub-concept', '纸质'),
#  ('判别', 'sub-concept', '记录'),
#  ('判别', 'sub-concept', '资源'),
#  ('判别', 'sub-concept', '载体'),
#  ('判别', 'sub-concept', '集合'),
#  ('判别', 'sub-concept', '题'),
#  ('利用', 'sub-concept', '两'),
#  ('利用', 'sub-concept', '信息'),
#  ('利用', 'sub-concept', '分'),
#  ('利用', 'sub-concept', '含义'),
#  ('利用', 'sub-concept', '多种'),
#  ('利用', 'sub-concept', '媒体'),
#  ('利用', 'sub-concept', '客观'),
#  ('利用', 'sub-concept', '密'),
#  ('利用', 'sub-concept', '看法'),
#  ('利用', 'sub-concept', '称'),
#  ('利用', 'sub-concept', '类'),
#  ('利用', 'sub-concept', '类型'),
#  ('利用', 'sub-concept', '纸质'),
#  ('利用', 'sub-concept', '资源'),
#  ('利用', 'sub-concept', '载体'),
#  ('利用率', 'sub-concept', '信息'),
#  ('利用率', 'sub-concept', '包括'),
#  ('利用率', 'sub-concept', '印刷'),
#  ('利用率', 'sub-concept', '复制'),
#  ('利用率', 'sub-concept', '媒体'),
#  ('利用率', 'sub-concept', '手写'),
#  ('利用率', 'sub-concept', '手段'),
#  ('利用率', 'sub-concept', '指'),
#  ('利用率', 'sub-concept', '材料'),
#  ('利用率', 'sub-concept', '纸张'),
#  ('利用率', 'sub-concept', '纸质'),
#  ('利用率', 'sub-concept', '记录'),
#  ('利用率', 'sub-concept', '资源'),
#  ('利用率', 'sub-concept', '载体'),
#  ('利用率', 'sub-concept', '集合'),
#  ('前', 'sub-concept', '作者'),
#  ('前', 'sub-concept', '内容'),
#  ('前', 'sub-concept', '再版'),
#  ('前', 'sub-concept', '出版'),
#  ('前', 'sub-concept', '出版物'),
#  ('前', 'sub-concept', '卷'),
#  ('前', 'sub-concept', '各期'),
#  ('前', 'sub-concept', '名称'),
#  ('前', 'sub-concept', '周期'),
#  ('前', 'sub-concept', '固定'),
#  ('前', 'sub-concept', '定期'),
#  ('前', 'sub-concept', '少'),
#  ('前', 'sub-concept', '居多'),
#  ('前', 'sub-concept', '年'),
#  ('前', 'sub-concept', '年月'),
#  ('前', 'sub-concept', '文章'),
#  ('前', 'sub-concept', '期'),
#  ('前', 'sub-concept', '期刊'),
#  ('前', 'sub-concept', '极'),
#  ('前', 'sub-concept', '版式'),
#  ('前', 'sub-concept', '登载'),
#  ('前', 'sub-concept', '篇'),
#  ('前', 'sub-concept', '统一'),
#  ('前', 'sub-concept', '续'),
#  ('前', 'sub-concept', '般'),
#  ('前', 'sub-concept', '超过'),
#  ('前', 'sub-concept', '连续'),
#  ('前', 'sub-concept', '重复'),
#  ('前', 'sub-concept', '顺序号'),
#  ('剩下', 'sub-concept', '作者'),
#  ('剩下', 'sub-concept', '内容'),
#  ('剩下', 'sub-concept', '再版'),
#  ('剩下', 'sub-concept', '出版'),
#  ('剩下', 'sub-concept', '出版物'),
#  ('剩下', 'sub-concept', '卷'),
#  ('剩下', 'sub-concept', '各期'),
#  ('剩下', 'sub-concept', '名称'),
#  ('剩下', 'sub-concept', '周期'),
#  ('剩下', 'sub-concept', '固定'),
#  ('剩下', 'sub-concept', '定期'),
#  ('剩下', 'sub-concept', '少'),
#  ('剩下', 'sub-concept', '居多'),
#  ('剩下', 'sub-concept', '年'),
#  ('剩下', 'sub-concept', '年月'),
#  ('剩下', 'sub-concept', '文章'),
#  ('剩下', 'sub-concept', '期'),
#  ('剩下', 'sub-concept', '期刊'),
#  ('剩下', 'sub-concept', '极'),
#  ('剩下', 'sub-concept', '版式'),
#  ('剩下', 'sub-concept', '登载'),
#  ('剩下', 'sub-concept', '篇'),
#  ('剩下', 'sub-concept', '统一'),
#  ('剩下', 'sub-concept', '续'),
#  ('剩下', 'sub-concept', '般'),
#  ('剩下', 'sub-concept', '超过'),
#  ('剩下', 'sub-concept', '连续'),
#  ('剩下', 'sub-concept', '重复'),
#  ('剩下', 'sub-concept', '顺序号'),
#  ('功能', 'sub-concept', '信息'),
#  ('功能', 'sub-concept', '概述'),
#  ('加工', 'sub-concept', '两'),
#  ('加工', 'sub-concept', '信息'),
#  ('加工', 'sub-concept', '分'),
#  ('加工', 'sub-concept', '含义'),
#  ('加工', 'sub-concept', '多种'),
#  ('加工', 'sub-concept', '媒体'),
#  ('加工', 'sub-concept', '客观'),
#  ('加工', 'sub-concept', '密'),
#  ('加工', 'sub-concept', '看法'),
#  ('加工', 'sub-concept', '称'),
#  ('加工', 'sub-concept', '类'),
#  ('加工', 'sub-concept', '资源'),
#  ('加工', 'sub-concept', '载体'),
#  ('动力', 'sub-concept', '作用'),
#  ('动力', 'sub-concept', '信息'),
#  ('动力', 'sub-concept', '功能'),
#  ('动态', 'sub-concept', '信息'),
#  ('动态', 'sub-concept', '种类'),
#  ('动态性', 'sub-concept', '信息'),
#  ('动态性', 'sub-concept', '特性'),
#  ('动态性', 'sub-concept', '资源'),
#  ('劳动', 'sub-concept', '信息'),
#  ('劳动', 'sub-concept', '含义'),
#  ('劳动', 'sub-concept', '多种'),
#  ('劳动', 'sub-concept', '看法'),
#  ('劳动', 'sub-concept', '资源'),
#  ('包含', 'sub-concept', '两'),
#  ('包含', 'sub-concept', '作者'),
#  ('包含', 'sub-concept', '信息'),
#  ('包含', 'sub-concept', '内容'),
#  ('包含', 'sub-concept', '再版'),
#  ('包含', 'sub-concept', '出版'),
#  ('包含', 'sub-concept', '出版物'),
#  ('包含', 'sub-concept', '分'),
#  ('包含', 'sub-concept', '卷'),
#  ('包含', 'sub-concept', '各期'),
#  ('包含', 'sub-concept', '名称'),
#  ('包含', 'sub-concept', '含义'),
#  ('包含', 'sub-concept', '周期'),
#  ('包含', 'sub-concept', '固定'),
#  ('包含', 'sub-concept', '媒体'),
#  ('包含', 'sub-concept', '定期'),
#  ('包含', 'sub-concept', '客观'),
#  ('包含', 'sub-concept', '密'),
#  ('包含', 'sub-concept', '少'),
#  ('包含', 'sub-concept', '居多'),
#  ('包含', 'sub-concept', '年'),
#  ('包含', 'sub-concept', '年月'),
#  ('包含', 'sub-concept', '文章'),
#  ('包含', 'sub-concept', '期'),
#  ('包含', 'sub-concept', '期刊'),
#  ('包含', 'sub-concept', '极'),
#  ('包含', 'sub-concept', '版式'),
#  ('包含', 'sub-concept', '登载'),
#  ('包含', 'sub-concept', '称'),
#  ('包含', 'sub-concept', '篇'),
#  ('包含', 'sub-concept', '类'),
#  ('包含', 'sub-concept', '统一'),
#  ('包含', 'sub-concept', '续'),
#  ('包含', 'sub-concept', '般'),
#  ('包含', 'sub-concept', '超过'),
#  ('包含', 'sub-concept', '载体'),
#  ('包含', 'sub-concept', '连续'),
#  ('包含', 'sub-concept', '重复'),
#  ('包含', 'sub-concept', '顺序号'),
#  ('包括', 'sub-concept', '信息'),
#  ('包括', 'sub-concept', '含义'),
#  ('包括', 'sub-concept', '图书'),
#  ('包括', 'sub-concept', '多种'),
#  ('包括', 'sub-concept', '建设'),
#  ('包括', 'sub-concept', '看法'),
#  ('包括', 'sub-concept', '类型'),
#  ('包括', 'sub-concept', '纸质'),
#  ('包括', 'sub-concept', '资源'),
#  ('区域', 'sub-concept', '作者'),
#  ('区域', 'sub-concept', '信息'),
#  ('区域', 'sub-concept', '内容'),
#  ('区域', 'sub-concept', '再版'),
#  ('区域', 'sub-concept', '出版'),
#  ('区域', 'sub-concept', '出版物'),
#  ('区域', 'sub-concept', '包括'),
#  ('区域', 'sub-concept', '印刷'),
#  ('区域', 'sub-concept', '卷'),
#  ('区域', 'sub-concept', '各期'),
#  ('区域', 'sub-concept', '名称'),
#  ('区域', 'sub-concept', '周期'),
#  ('区域', 'sub-concept', '固定'),
#  ('区域', 'sub-concept', '复制'),
#  ('区域', 'sub-concept', '媒体'),
#  ('区域', 'sub-concept', '定期'),
#  ('区域', 'sub-concept', '少'),
#  ('区域', 'sub-concept', '居多'),
#  ('区域', 'sub-concept', '年'),
#  ('区域', 'sub-concept', '年月'),
#  ('区域', 'sub-concept', '手写'),
#  ('区域', 'sub-concept', '手段'),
#  ('区域', 'sub-concept', '指'),
#  ('区域', 'sub-concept', '文章'),
#  ('区域', 'sub-concept', '期'),
#  ('区域', 'sub-concept', '期刊'),
#  ('区域', 'sub-concept', '材料'),
#  ('区域', 'sub-concept', '极'),
#  ('区域', 'sub-concept', '版式'),
#  ('区域', 'sub-concept', '登载'),
#  ('区域', 'sub-concept', '篇'),
#  ('区域', 'sub-concept', '纸张'),
#  ('区域', 'sub-concept', '纸质'),
#  ('区域', 'sub-concept', '统一'),
#  ('区域', 'sub-concept', '续'),
#  ('区域', 'sub-concept', '般'),
#  ('区域', 'sub-concept', '记录'),
#  ('区域', 'sub-concept', '资源'),
#  ('区域', 'sub-concept', '超过'),
#  ('区域', 'sub-concept', '载体'),
#  ('区域', 'sub-concept', '连续'),
#  ('区域', 'sub-concept', '重复'),
#  ('区域', 'sub-concept', '集合'),
#  ('区域', 'sub-concept', '顺序号'),
#  ('协议', 'sub-concept', '信息'),
#  ('协议', 'sub-concept', '种类'),
#  ('协议', 'sub-concept', '资源'),
#  ('协调', 'sub-concept', '信息'),
#  ('协调', 'sub-concept', '类型'),
#  ('协调', 'sub-concept', '纸质'),
#  ('协调', 'sub-concept', '资源'),
#  ('单位', 'sub-concept', '作者'),
#  ('单位', 'sub-concept', '内容'),
#  ('单位', 'sub-concept', '再版'),
#  ('单位', 'sub-concept', '出版'),
#  ('单位', 'sub-concept', '出版物'),
#  ('单位', 'sub-concept', '卷'),
#  ('单位', 'sub-concept', '各期'),
#  ('单位', 'sub-concept', '名称'),
#  ('单位', 'sub-concept', '周期'),
#  ('单位', 'sub-concept', '固定'),
#  ('单位', 'sub-concept', '定期'),
#  ('单位', 'sub-concept', '少'),
#  ('单位', 'sub-concept', '居多'),
#  ('单位', 'sub-concept', '年'),
#  ('单位', 'sub-concept', '年月'),
#  ('单位', 'sub-concept', '文章'),
#  ('单位', 'sub-concept', '期'),
#  ('单位', 'sub-concept', '期刊'),
#  ('单位', 'sub-concept', '极'),
#  ('单位', 'sub-concept', '版式'),
#  ('单位', 'sub-concept', '登载'),
#  ('单位', 'sub-concept', '篇'),
#  ('单位', 'sub-concept', '统一'),
#  ('单位', 'sub-concept', '续'),
#  ('单位', 'sub-concept', '般'),
#  ('单位', 'sub-concept', '超过'),
#  ('单位', 'sub-concept', '连续'),
#  ('单位', 'sub-concept', '重复'),
#  ('单位', 'sub-concept', '顺序号'),
#  ('单元', 'sub-concept', '图书'),
#  ('印刷', 'sub-concept', '信息'),
#  ('印刷', 'sub-concept', '建设'),
#  ('印刷', 'sub-concept', '资源'),
#  ('印刷型', 'sub-concept', '信息'),
#  ('印刷型', 'sub-concept', '种类'),
#  ('印刷型', 'sub-concept', '资源'),
#  ('即P', 'sub-concept', '信息'),
#  ('即P', 'sub-concept', '包括'),
#  ('即P', 'sub-concept', '印刷'),
#  ('即P', 'sub-concept', '复制'),
#  ('即P', 'sub-concept', '媒体'),
#  ('即P', 'sub-concept', '手写'),
#  ('即P', 'sub-concept', '手段'),
#  ('即P', 'sub-concept', '指'),
#  ('即P', 'sub-concept', '材料'),
#  ('即P', 'sub-concept', '纸张'),
#  ('即P', 'sub-concept', '纸质'),
#  ('即P', 'sub-concept', '记录'),
#  ('即P', 'sub-concept', '资源'),
#  ('即P', 'sub-concept', '载体'),
#  ('即P', 'sub-concept', '集合'),
#  ('卷', 'sub-concept', '信息'),
#  ('卷', 'sub-concept', '包括'),
#  ('卷', 'sub-concept', '印刷'),
#  ('卷', 'sub-concept', '复制'),
#  ('卷', 'sub-concept', '媒体'),
#  ('卷', 'sub-concept', '手写'),
#  ('卷', 'sub-concept', '手段'),
#  ('卷', 'sub-concept', '指'),
#  ('卷', 'sub-concept', '材料'),
#  ('卷', 'sub-concept', '纸张'),
#  ('卷', 'sub-concept', '纸质'),
#  ('卷', 'sub-concept', '记录'),
#  ('卷', 'sub-concept', '资源'),
#  ('卷', 'sub-concept', '载体'),
#  ('卷', 'sub-concept', '集合'),
#  ('历史', 'sub-concept', '信息'),
#  ('历史', 'sub-concept', '类型'),
#  ('历史', 'sub-concept', '纸质'),
#  ('历史', 'sub-concept', '资源'),
#  ('原始', 'sub-concept', '信息'),
#  ('原始', 'sub-concept', '类型'),
#  ('原始', 'sub-concept', '纸质'),
#  ('原始', 'sub-concept', '资源'),
#  ('参考', 'sub-concept', '信息'),
#  ('参考', 'sub-concept', '类型'),
#  ('参考', 'sub-concept', '纸质'),
#  ('参考', 'sub-concept', '资源'),
#  ('参谋', 'sub-concept', '作用'),
#  ('参谋', 'sub-concept', '信息'),
#  ('参谋', 'sub-concept', '功能'),
#  ('反馈', 'sub-concept', '两'),
#  ('反馈', 'sub-concept', '信息'),
#  ('反馈', 'sub-concept', '分'),
#  ('反馈', 'sub-concept', '含义'),
#  ('反馈', 'sub-concept', '媒体'),
#  ('反馈', 'sub-concept', '客观'),
#  ('反馈', 'sub-concept', '密'),
#  ('反馈', 'sub-concept', '称'),
#  ('反馈', 'sub-concept', '类'),
#  ('反馈', 'sub-concept', '载体'),
#  ('发展', 'sub-concept', '作用'),
#  ('发展', 'sub-concept', '信息'),
#  ('发展', 'sub-concept', '功能'),
#  ('发展', 'sub-concept', '包括'),
#  ('发展', 'sub-concept', '印刷'),
#  ('发展', 'sub-concept', '复制'),
#  ('发展', 'sub-concept', '媒体'),
#  ('发展', 'sub-concept', '手写'),
#  ('发展', 'sub-concept', '手段'),
#  ('发展', 'sub-concept', '指'),
#  ('发展', 'sub-concept', '材料'),
#  ('发展', 'sub-concept', '纸张'),
#  ('发展', 'sub-concept', '纸质'),
#  ('发展', 'sub-concept', '记录'),
#  ('发展', 'sub-concept', '资源'),
#  ('发展', 'sub-concept', '载体'),
#  ('发展', 'sub-concept', '集合'),
#  ('发放', 'sub-concept', '信息'),
#  ('发放', 'sub-concept', '类型'),
#  ('发放', 'sub-concept', '纸质'),
#  ('发放', 'sub-concept', '资源'),
#  ('发明', 'sub-concept', '信息'),
#  ('发明', 'sub-concept', '类型'),
#  ('发明', 'sub-concept', '纸质'),
#  ('发明', 'sub-concept', '资源'),
#  ('发现', 'sub-concept', '作者'),
#  ('发现', 'sub-concept', '内容'),
#  ('发现', 'sub-concept', '再版'),
#  ('发现', 'sub-concept', '出版'),
#  ('发现', 'sub-concept', '出版物'),
#  ('发现', 'sub-concept', '卷'),
#  ('发现', 'sub-concept', '各期'),
#  ('发现', 'sub-concept', '名称'),
#  ('发现', 'sub-concept', '周期'),
#  ('发现', 'sub-concept', '固定'),
#  ('发现', 'sub-concept', '定期'),
#  ('发现', 'sub-concept', '少'),
#  ('发现', 'sub-concept', '居多'),
#  ('发现', 'sub-concept', '年'),
#  ('发现', 'sub-concept', '年月'),
#  ('发现', 'sub-concept', '文章'),
#  ('发现', 'sub-concept', '期'),
#  ('发现', 'sub-concept', '期刊'),
#  ('发现', 'sub-concept', '极'),
#  ('发现', 'sub-concept', '版式'),
#  ('发现', 'sub-concept', '登载'),
#  ('发现', 'sub-concept', '篇'),
#  ('发现', 'sub-concept', '统一'),
#  ('发现', 'sub-concept', '续'),
#  ('发现', 'sub-concept', '般'),
#  ('发现', 'sub-concept', '超过'),
#  ('发现', 'sub-concept', '连续'),
#  ('发现', 'sub-concept', '重复'),
#  ('发现', 'sub-concept', '顺序号'),
#  ('发行', 'sub-concept', '信息'),
#  ('发行', 'sub-concept', '类型'),
#  ('发行', 'sub-concept', '纸质'),
#  ('发行', 'sub-concept', '资源'),
#  ('口头', 'sub-concept', '两'),
#  ('口头', 'sub-concept', '信息'),
#  ('口头', 'sub-concept', '分'),
#  ('口头', 'sub-concept', '含义'),
#  ('口头', 'sub-concept', '媒体'),
#  ('口头', 'sub-concept', '客观'),
#  ('口头', 'sub-concept', '密'),
#  ('口头', 'sub-concept', '称'),
#  ('口头', 'sub-concept', '类'),
#  ('口头', 'sub-concept', '载体'),
#  ('可靠', 'sub-concept', '两'),
#  ('可靠', 'sub-concept', '信息'),
#  ('可靠', 'sub-concept', '分'),
#  ('可靠', 'sub-concept', '含义'),
#  ('可靠', 'sub-concept', '媒体'),
#  ('可靠', 'sub-concept', '客观'),
#  ('可靠', 'sub-concept', '密'),
#  ('可靠', 'sub-concept', '称'),
#  ('可靠', 'sub-concept', '类'),
#  ('可靠', 'sub-concept', '类型'),
#  ('可靠', 'sub-concept', '纸质'),
#  ('可靠', 'sub-concept', '资源'),
#  ('可靠', 'sub-concept', '载体'),
#  ('可靠性', 'sub-concept', '两'),
#  ('可靠性', 'sub-concept', '信息'),
#  ('可靠性', 'sub-concept', '分'),
#  ('可靠性', 'sub-concept', '含义'),
#  ('可靠性', 'sub-concept', '媒体'),
#  ('可靠性', 'sub-concept', '客观'),
#  ('可靠性', 'sub-concept', '密'),
#  ('可靠性', 'sub-concept', '称'),
#  ('可靠性', 'sub-concept', '类'),
#  ('可靠性', 'sub-concept', '载体'),
#  ('司法', 'sub-concept', '信息'),
#  ('司法', 'sub-concept', '类型'),
#  ('司法', 'sub-concept', '纸质'),
#  ('司法', 'sub-concept', '资源'),
#  ('各期', 'sub-concept', '信息'),
#  ('各期', 'sub-concept', '包括'),
#  ('各期', 'sub-concept', '印刷'),
#  ('各期', 'sub-concept', '复制'),
#  ('各期', 'sub-concept', '媒体'),
#  ('各期', 'sub-concept', '手写'),
#  ('各期', 'sub-concept', '手段'),
#  ('各期', 'sub-concept', '指'),
#  ('各期', 'sub-concept', '材料'),
#  ('各期', 'sub-concept', '纸张'),
#  ('各期', 'sub-concept', '纸质'),
#  ('各期', 'sub-concept', '记录'),
#  ('各期', 'sub-concept', '资源'),
#  ('各期', 'sub-concept', '载体'),
#  ('各期', 'sub-concept', '集合'),
#  ('各类', 'sub-concept', '信息'),
#  ('各类', 'sub-concept', '种类'),
#  ('各类', 'sub-concept', '资源'),
#  ('合作', 'sub-concept', '信息'),
#  ('合作', 'sub-concept', '类型'),
#  ('合作', 'sub-concept', '纸质'),
#  ('合作', 'sub-concept', '资源'),
#  ('名称', 'sub-concept', '信息'),
#  ('名称', 'sub-concept', '包括'),
#  ('名称', 'sub-concept', '印刷'),
#  ('名称', 'sub-concept', '复制'),
#  ('名称', 'sub-concept', '媒体'),
#  ('名称', 'sub-concept', '手写'),
#  ('名称', 'sub-concept', '手段'),
#  ('名称', 'sub-concept', '指'),
#  ('名称', 'sub-concept', '材料'),
#  ('名称', 'sub-concept', '纸张'),
#  ('名称', 'sub-concept', '纸质'),
#  ('名称', 'sub-concept', '记录'),
#  ('名称', 'sub-concept', '资源'),
#  ('名称', 'sub-concept', '载体'),
#  ('名称', 'sub-concept', '集合'),
#  ('否', 'sub-concept', '信息'),
#  ('否', 'sub-concept', '种类'),
#  ('含', 'sub-concept', '图书'),
#  ('含义', 'sub-concept', '信息'),
#  ('含义', 'sub-concept', '媒体'),
#  ('含义', 'sub-concept', '资源'),
#  ('含有', 'sub-concept', '作者'),
#  ('含有', 'sub-concept', '内容'),
#  ('含有', 'sub-concept', '再版'),
#  ('含有', 'sub-concept', '出版'),
#  ('含有', 'sub-concept', '出版物'),
#  ('含有', 'sub-concept', '卷'),
#  ('含有', 'sub-concept', '各期'),
#  ('含有', 'sub-concept', '名称'),
#  ('含有', 'sub-concept', '周期'),
#  ('含有', 'sub-concept', '固定'),
#  ('含有', 'sub-concept', '定期'),
#  ('含有', 'sub-concept', '少'),
#  ('含有', 'sub-concept', '居多'),
#  ('含有', 'sub-concept', '年'),
#  ('含有', 'sub-concept', '年月'),
#  ('含有', 'sub-concept', '文章'),
#  ('含有', 'sub-concept', '期'),
#  ('含有', 'sub-concept', '期刊'),
#  ('含有', 'sub-concept', '极'),
#  ('含有', 'sub-concept', '版式'),
#  ('含有', 'sub-concept', '登载'),
#  ('含有', 'sub-concept', '篇'),
#  ('含有', 'sub-concept', '统一'),
#  ('含有', 'sub-concept', '续'),
#  ('含有', 'sub-concept', '般'),
#  ('含有', 'sub-concept', '超过'),
#  ('含有', 'sub-concept', '连续'),
#  ('含有', 'sub-concept', '重复'),
#  ('含有', 'sub-concept', '顺序号'),
#  ('含量', 'sub-concept', '信息'),
#  ('含量', 'sub-concept', '包括'),
#  ('含量', 'sub-concept', '印刷'),
#  ('含量', 'sub-concept', '复制'),
#  ('含量', 'sub-concept', '媒体'),
#  ('含量', 'sub-concept', '手写'),
#  ('含量', 'sub-concept', '手段'),
#  ('含量', 'sub-concept', '指'),
#  ('含量', 'sub-concept', '材料'),
#  ('含量', 'sub-concept', '纸张'),
#  ('含量', 'sub-concept', '纸质'),
#  ('含量', 'sub-concept', '记录'),
#  ('含量', 'sub-concept', '资源'),
#  ('含量', 'sub-concept', '载体'),
#  ('含量', 'sub-concept', '集合'),
#  ('周期', 'sub-concept', '信息'),
#  ('周期', 'sub-concept', '包括'),
#  ('周期', 'sub-concept', '印刷'),
#  ('周期', 'sub-concept', '复制'),
#  ('周期', 'sub-concept', '媒体'),
#  ('周期', 'sub-concept', '手写'),
#  ('周期', 'sub-concept', '手段'),
#  ('周期', 'sub-concept', '指'),
#  ('周期', 'sub-concept', '材料'),
#  ('周期', 'sub-concept', '纸张'),
#  ('周期', 'sub-concept', '纸质'),
#  ('周期', 'sub-concept', '记录'),
#  ('周期', 'sub-concept', '资源'),
#  ('周期', 'sub-concept', '载体'),
#  ('周期', 'sub-concept', '集合'),
#  ('命令', 'sub-concept', '信息'),
#  ('命令', 'sub-concept', '类型'),
#  ('命令', 'sub-concept', '纸质'),
#  ('命令', 'sub-concept', '资源'),
#  ('商业', 'sub-concept', '信息'),
#  ('商业', 'sub-concept', '类型'),
#  ('商业', 'sub-concept', '纸质'),
#  ('商业', 'sub-concept', '资源'),
#  ('四', 'sub-concept', '信息'),
#  ('四', 'sub-concept', '思考'),
#  ('四', 'sub-concept', '类型'),
#  ('四', 'sub-concept', '纸质'),
#  ('四', 'sub-concept', '资源'),
#  ('四', 'sub-concept', '题'),
#  ('固定', 'sub-concept', '信息'),
#  ('固定', 'sub-concept', '包括'),
#  ('固定', 'sub-concept', '印刷'),
#  ('固定', 'sub-concept', '复制'),
#  ('固定', 'sub-concept', '媒体'),
#  ('固定', 'sub-concept', '手写'),
#  ('固定', 'sub-concept', '手段'),
#  ('固定', 'sub-concept', '指'),
#  ('固定', 'sub-concept', '材料'),
#  ('固定', 'sub-concept', '纸张'),
#  ('固定', 'sub-concept', '纸质'),
#  ('固定', 'sub-concept', '记录'),
#  ('固定', 'sub-concept', '资源'),
#  ('固定', 'sub-concept', '载体'),
#  ('固定', 'sub-concept', '集合'),
#  ('国', 'sub-concept', '信息'),
#  ('国', 'sub-concept', '类型'),
#  ('国', 'sub-concept', '纸质'),
#  ('国', 'sub-concept', '资源'),
#  ('国会', 'sub-concept', '信息'),
#  ('国会', 'sub-concept', '类型'),
#  ('国会', 'sub-concept', '纸质'),
#  ('国会', 'sub-concept', '资源'),
#  ('国内外', 'sub-concept', '信息'),
#  ('国内外', 'sub-concept', '种类'),
#  ('国内外', 'sub-concept', '类型'),
#  ('国内外', 'sub-concept', '纸质'),
#  ('国内外', 'sub-concept', '资源'),
#  ('国内外贸易', 'sub-concept', '信息'),
#  ('国内外贸易', 'sub-concept', '类型'),
#  ('国内外贸易', 'sub-concept', '纸质'),
#  ('国内外贸易', 'sub-concept', '资源'),
#  ('国防部', 'sub-concept', '信息'),
#  ('国防部', 'sub-concept', '类型'),
#  ('国防部', 'sub-concept', '纸质'),
#  ('国防部', 'sub-concept', '资源'),
#  ('国际', 'sub-concept', '信息'),
#  ('国际', 'sub-concept', '类型'),
#  ('国际', 'sub-concept', '纸质'),
#  ('国际', 'sub-concept', '资源'),
#  ('图', 'sub-concept', '信息'),
#  ('图', 'sub-concept', '包括'),
#  ('图', 'sub-concept', '印刷'),
#  ('图', 'sub-concept', '复制'),
#  ('图', 'sub-concept', '媒体'),
#  ('图', 'sub-concept', '手写'),
#  ('图', 'sub-concept', '手段'),
#  ('图', 'sub-concept', '指'),
#  ('图', 'sub-concept', '材料'),
#  ('图', 'sub-concept', '纸张'),
#  ('图', 'sub-concept', '纸质'),
#  ('图', 'sub-concept', '记录'),
#  ('图', 'sub-concept', '资源'),
#  ('图', 'sub-concept', '载体'),
#  ('图', 'sub-concept', '集合'),
#  ('图书', 'sub-concept', '信息'),
#  ('图书', 'sub-concept', '包括'),
#  ('图书', 'sub-concept', '印刷'),
#  ('图书', 'sub-concept', '图书'),
#  ('图书', 'sub-concept', '复制'),
#  ('图书', 'sub-concept', '媒体'),
#  ('图书', 'sub-concept', '手写'),
#  ('图书', 'sub-concept', '手段'),
#  ('图书', 'sub-concept', '指'),
#  ('图书', 'sub-concept', '材料'),
#  ('图书', 'sub-concept', '种类'),
#  ('图书', 'sub-concept', '纸张'),
#  ('图书', 'sub-concept', '纸质'),
#  ('图书', 'sub-concept', '记录'),
#  ('图书', 'sub-concept', '资源'),
#  ('图书', 'sub-concept', '载体'),
#  ('图书', 'sub-concept', '集合'),
#  ('培养', 'sub-concept', '作者'),
#  ('培养', 'sub-concept', '内容'),
#  ('培养', 'sub-concept', '再版'),
#  ('培养', 'sub-concept', '出版'),
#  ('培养', 'sub-concept', '出版物'),
#  ('培养', 'sub-concept', '卷'),
#  ('培养', 'sub-concept', '各期'),
#  ('培养', 'sub-concept', '名称'),
#  ('培养', 'sub-concept', '周期'),
# ...
#  ('表达', 'sub-concept', '含义'),
#  ('表达', 'sub-concept', '图书'),
#  ('表达', 'sub-concept', '媒体'),
#  ('表达', 'sub-concept', '客观'),
#  ('表达', 'sub-concept', '密'),
#  ('表达', 'sub-concept', '称'),
#  ('表达', 'sub-concept', '类'),
#  ('表达', 'sub-concept', '要素'),
#  ('表达', 'sub-concept', '载体'),
#  ('表述', 'sub-concept', '信息'),
#  ('表述', 'sub-concept', '媒体'),
#  ('表述', 'sub-concept', '要素'),
#  ('被摘率', 'sub-concept', '信息'),
#  ('被摘率', 'sub-concept', '包括'),
#  ('被摘率', 'sub-concept', '印刷'),
#  ('被摘率', 'sub-concept', '复制'),
#  ('被摘率', 'sub-concept', '媒体'),
#  ('被摘率', 'sub-concept', '手写'),
#  ('被摘率', 'sub-concept', '手段'),
#  ('被摘率', 'sub-concept', '指'),
#  ('被摘率', 'sub-concept', '材料'),
#  ('被摘率', 'sub-concept', '纸张'),
#  ('被摘率', 'sub-concept', '纸质'),
#  ('被摘率', 'sub-concept', '记录'),
#  ('被摘率', 'sub-concept', '资源'),
#  ('被摘率', 'sub-concept', '载体'),
#  ('被摘率', 'sub-concept', '集合'),
#  ('要点', 'sub-concept', '信息'),
#  ('要点', 'sub-concept', '含义'),
#  ('要点', 'sub-concept', '多种'),
#  ('要点', 'sub-concept', '看法'),
#  ('要点', 'sub-concept', '资源'),
#  ('要素', 'sub-concept', '信息'),
#  ('要素', 'sub-concept', '含义'),
#  ('要素', 'sub-concept', '多种'),
#  ('要素', 'sub-concept', '媒体'),
#  ('要素', 'sub-concept', '看法'),
#  ('要素', 'sub-concept', '种类'),
#  ('要素', 'sub-concept', '资源'),
#  ('观点', 'sub-concept', '信息'),
#  ('观点', 'sub-concept', '含义'),
#  ('观点', 'sub-concept', '多种'),
#  ('观点', 'sub-concept', '看法'),
#  ('观点', 'sub-concept', '类型'),
#  ('观点', 'sub-concept', '纸质'),
#  ('观点', 'sub-concept', '资源'),
#  ('规律', 'sub-concept', '信息'),
#  ('规律', 'sub-concept', '概述'),
#  ('规章制度', 'sub-concept', '信息'),
#  ('规章制度', 'sub-concept', '类型'),
#  ('规章制度', 'sub-concept', '纸质'),
#  ('规章制度', 'sub-concept', '资源'),
#  ('规避', 'sub-concept', '信息'),
#  ('规避', 'sub-concept', '类型'),
#  ('规避', 'sub-concept', '纸质'),
#  ('规避', 'sub-concept', '资源'),
#  ('视听型', 'sub-concept', '信息'),
#  ('视听型', 'sub-concept', '种类'),
#  ('视听型', 'sub-concept', '资源'),
#  ('解', 'sub-concept', '信息'),
#  ('解', 'sub-concept', '类型'),
#  ('解', 'sub-concept', '纸质'),
#  ('解', 'sub-concept', '资源'),
#  ('记录', 'sub-concept', '两'),
#  ('记录', 'sub-concept', '信息'),
#  ('记录', 'sub-concept', '分'),
#  ('记录', 'sub-concept', '含义'),
#  ('记录', 'sub-concept', '图书'),
#  ('记录', 'sub-concept', '媒体'),
#  ('记录', 'sub-concept', '客观'),
#  ('记录', 'sub-concept', '密'),
#  ('记录', 'sub-concept', '建设'),
#  ('记录', 'sub-concept', '称'),
#  ('记录', 'sub-concept', '类'),
#  ('记录', 'sub-concept', '类型'),
#  ('记录', 'sub-concept', '纸质'),
#  ('记录', 'sub-concept', '要素'),
#  ('记录', 'sub-concept', '资源'),
#  ('记录', 'sub-concept', '载体'),
#  ('记载', 'sub-concept', '作者'),
#  ('记载', 'sub-concept', '内容'),
#  ('记载', 'sub-concept', '再版'),
#  ('记载', 'sub-concept', '出版'),
#  ('记载', 'sub-concept', '出版物'),
#  ('记载', 'sub-concept', '卷'),
#  ('记载', 'sub-concept', '各期'),
#  ('记载', 'sub-concept', '名称'),
#  ('记载', 'sub-concept', '周期'),
#  ('记载', 'sub-concept', '固定'),
#  ('记载', 'sub-concept', '定期'),
#  ('记载', 'sub-concept', '少'),
#  ('记载', 'sub-concept', '居多'),
#  ('记载', 'sub-concept', '年'),
#  ('记载', 'sub-concept', '年月'),
#  ('记载', 'sub-concept', '文章'),
#  ('记载', 'sub-concept', '期'),
#  ('记载', 'sub-concept', '期刊'),
#  ('记载', 'sub-concept', '极'),
#  ('记载', 'sub-concept', '版式'),
#  ('记载', 'sub-concept', '登载'),
#  ('记载', 'sub-concept', '篇'),
#  ('记载', 'sub-concept', '统一'),
#  ('记载', 'sub-concept', '续'),
#  ('记载', 'sub-concept', '般'),
#  ('记载', 'sub-concept', '超过'),
#  ('记载', 'sub-concept', '连续'),
#  ('记载', 'sub-concept', '重复'),
#  ('记载', 'sub-concept', '顺序号'),
#  ('论文', 'sub-concept', '作者'),
#  ('论文', 'sub-concept', '信息'),
#  ('论文', 'sub-concept', '内容'),
#  ('论文', 'sub-concept', '再版'),
#  ('论文', 'sub-concept', '出版'),
#  ('论文', 'sub-concept', '出版物'),
#  ('论文', 'sub-concept', '包括'),
#  ('论文', 'sub-concept', '印刷'),
#  ('论文', 'sub-concept', '卷'),
#  ('论文', 'sub-concept', '各期'),
#  ('论文', 'sub-concept', '名称'),
#  ('论文', 'sub-concept', '周期'),
#  ('论文', 'sub-concept', '固定'),
#  ('论文', 'sub-concept', '复制'),
#  ('论文', 'sub-concept', '媒体'),
#  ('论文', 'sub-concept', '定期'),
#  ('论文', 'sub-concept', '少'),
#  ('论文', 'sub-concept', '居多'),
#  ('论文', 'sub-concept', '年'),
#  ('论文', 'sub-concept', '年月'),
#  ('论文', 'sub-concept', '思考'),
#  ('论文', 'sub-concept', '手写'),
#  ('论文', 'sub-concept', '手段'),
#  ('论文', 'sub-concept', '指'),
#  ('论文', 'sub-concept', '文章'),
#  ('论文', 'sub-concept', '期'),
#  ('论文', 'sub-concept', '期刊'),
#  ('论文', 'sub-concept', '材料'),
#  ('论文', 'sub-concept', '极'),
#  ('论文', 'sub-concept', '版式'),
#  ('论文', 'sub-concept', '登载'),
#  ('论文', 'sub-concept', '种类'),
#  ('论文', 'sub-concept', '篇'),
#  ('论文', 'sub-concept', '类型'),
#  ('论文', 'sub-concept', '纸张'),
#  ('论文', 'sub-concept', '纸质'),
#  ('论文', 'sub-concept', '统一'),
#  ('论文', 'sub-concept', '续'),
#  ('论文', 'sub-concept', '般'),
#  ('论文', 'sub-concept', '记录'),
#  ('论文', 'sub-concept', '资源'),
#  ('论文', 'sub-concept', '超过'),
#  ('论文', 'sub-concept', '载体'),
#  ('论文', 'sub-concept', '连续'),
#  ('论文', 'sub-concept', '重复'),
#  ('论文', 'sub-concept', '集合'),
#  ('论文', 'sub-concept', '顺序号'),
#  ('论文', 'sub-concept', '题'),
#  ('设备', 'sub-concept', '信息'),
#  ('设备', 'sub-concept', '含义'),
#  ('设备', 'sub-concept', '多种'),
#  ('设备', 'sub-concept', '看法'),
#  ('设备', 'sub-concept', '资源'),
#  ('设置', 'sub-concept', '信息'),
#  ('设置', 'sub-concept', '种类'),
#  ('设置', 'sub-concept', '资源'),
#  ('设计', 'sub-concept', '信息'),
#  ('设计', 'sub-concept', '类型'),
#  ('设计', 'sub-concept', '纸质'),
#  ('设计', 'sub-concept', '资源'),
#  ('详细性', 'sub-concept', '信息'),
#  ('详细性', 'sub-concept', '类型'),
#  ('详细性', 'sub-concept', '纸质'),
#  ('详细性', 'sub-concept', '资源'),
#  ('语言', 'sub-concept', '两'),
#  ('语言', 'sub-concept', '信息'),
#  ('语言', 'sub-concept', '分'),
#  ('语言', 'sub-concept', '含义'),
#  ('语言', 'sub-concept', '媒体'),
#  ('语言', 'sub-concept', '客观'),
#  ('语言', 'sub-concept', '密'),
#  ('语言', 'sub-concept', '称'),
#  ('语言', 'sub-concept', '类'),
#  ('语言', 'sub-concept', '载体'),
#  ('说明书', 'sub-concept', '信息'),
#  ('说明书', 'sub-concept', '类型'),
#  ('说明书', 'sub-concept', '纸质'),
#  ('说明书', 'sub-concept', '资源'),
#  ('读者', 'sub-concept', '信息'),
#  ('读者', 'sub-concept', '包括'),
#  ('读者', 'sub-concept', '印刷'),
#  ('读者', 'sub-concept', '复制'),
#  ('读者', 'sub-concept', '媒体'),
#  ('读者', 'sub-concept', '手写'),
#  ('读者', 'sub-concept', '手段'),
#  ('读者', 'sub-concept', '指'),
#  ('读者', 'sub-concept', '材料'),
#  ('读者', 'sub-concept', '纸张'),
#  ('读者', 'sub-concept', '纸质'),
#  ('读者', 'sub-concept', '记录'),
#  ('读者', 'sub-concept', '资源'),
#  ('读者', 'sub-concept', '载体'),
#  ('读者', 'sub-concept', '集合'),
#  ('课程', 'sub-concept', '信息'),
#  ('课程', 'sub-concept', '类型'),
#  ('课程', 'sub-concept', '纸质'),
#  ('课程', 'sub-concept', '资源'),
#  ('课题', 'sub-concept', '信息'),
#  ('课题', 'sub-concept', '类型'),
#  ('课题', 'sub-concept', '纸质'),
#  ('课题', 'sub-concept', '资源'),
#  ('调查', 'sub-concept', '信息'),
#  ('调查', 'sub-concept', '类型'),
#  ('调查', 'sub-concept', '纸质'),
#  ('调查', 'sub-concept', '资源'),
#  ('负担', 'sub-concept', '信息'),
#  ('负担', 'sub-concept', '类型'),
#  ('负担', 'sub-concept', '纸质'),
#  ('负担', 'sub-concept', '资源'),
#  ('负责', 'sub-concept', '信息'),
#  ('负责', 'sub-concept', '种类'),
#  ('负责', 'sub-concept', '资源'),
#  ('责任', 'sub-concept', '信息'),
#  ('责任', 'sub-concept', '种类'),
#  ('责任', 'sub-concept', '资源'),
#  ('质量', 'sub-concept', '信息'),
#  ('质量', 'sub-concept', '类型'),
#  ('质量', 'sub-concept', '纸质'),
#  ('质量', 'sub-concept', '资源'),
#  ('资料', 'sub-concept', '信息'),
#  ('资料', 'sub-concept', '概述'),
#  ('资料', 'sub-concept', '类型'),
#  ('资料', 'sub-concept', '纸质'),
#  ('资料', 'sub-concept', '资源'),
#  ('资源', 'sub-concept', '两'),
#  ('资源', 'sub-concept', '信息'),
#  ('资源', 'sub-concept', '分'),
#  ('资源', 'sub-concept', '包括'),
#  ('资源', 'sub-concept', '印刷'),
#  ('资源', 'sub-concept', '含义'),
#  ('资源', 'sub-concept', '复制'),
#  ('资源', 'sub-concept', '多种'),
#  ('资源', 'sub-concept', '媒体'),
#  ('资源', 'sub-concept', '客观'),
#  ('资源', 'sub-concept', '密'),
#  ('资源', 'sub-concept', '建设'),
#  ('资源', 'sub-concept', '手写'),
#  ('资源', 'sub-concept', '手段'),
#  ('资源', 'sub-concept', '指'),
#  ('资源', 'sub-concept', '材料'),
#  ('资源', 'sub-concept', '看法'),
#  ('资源', 'sub-concept', '种类'),
#  ('资源', 'sub-concept', '称'),
#  ('资源', 'sub-concept', '类'),
#  ('资源', 'sub-concept', '纸张'),
#  ('资源', 'sub-concept', '纸质'),
#  ('资源', 'sub-concept', '记录'),
#  ('资源', 'sub-concept', '资源'),
#  ('资源', 'sub-concept', '载体'),
#  ('资源', 'sub-concept', '集合'),
#  ('资源库', 'sub-concept', '信息'),
#  ('资源库', 'sub-concept', '种类'),
#  ('资源库', 'sub-concept', '资源'),
#  ('超过', 'sub-concept', '信息'),
#  ('超过', 'sub-concept', '包括'),
#  ('超过', 'sub-concept', '印刷'),
#  ('超过', 'sub-concept', '复制'),
#  ('超过', 'sub-concept', '媒体'),
#  ('超过', 'sub-concept', '手写'),
#  ('超过', 'sub-concept', '手段'),
#  ('超过', 'sub-concept', '指'),
#  ('超过', 'sub-concept', '材料'),
#  ('超过', 'sub-concept', '纸张'),
#  ('超过', 'sub-concept', '纸质'),
#  ('超过', 'sub-concept', '记录'),
#  ('超过', 'sub-concept', '资源'),
#  ('超过', 'sub-concept', '载体'),
#  ('超过', 'sub-concept', '集合'),
#  ('足', 'sub-concept', '两'),
#  ('足', 'sub-concept', '信息'),
#  ('足', 'sub-concept', '分'),
#  ('足', 'sub-concept', '含义'),
#  ('足', 'sub-concept', '媒体'),
#  ('足', 'sub-concept', '客观'),
#  ('足', 'sub-concept', '密'),
#  ('足', 'sub-concept', '称'),
#  ('足', 'sub-concept', '类'),
#  ('足', 'sub-concept', '载体'),
#  ('转换', 'sub-concept', '信息'),
#  ('转换', 'sub-concept', '含义'),
#  ('转换', 'sub-concept', '多种'),
#  ('转换', 'sub-concept', '看法'),
#  ('转换', 'sub-concept', '资源'),
#  ('软载体', 'sub-concept', '两'),
#  ('软载体', 'sub-concept', '信息'),
#  ('软载体', 'sub-concept', '分'),
#  ('软载体', 'sub-concept', '含义'),
#  ('软载体', 'sub-concept', '媒体'),
#  ('软载体', 'sub-concept', '客观'),
#  ('软载体', 'sub-concept', '密'),
#  ('软载体', 'sub-concept', '称'),
#  ('软载体', 'sub-concept', '类'),
#  ('软载体', 'sub-concept', '载体'),
#  ('载体', 'sub-concept', '两'),
#  ('载体', 'sub-concept', '信息'),
#  ('载体', 'sub-concept', '分'),
#  ('载体', 'sub-concept', '含义'),
#  ('载体', 'sub-concept', '图书'),
#  ('载体', 'sub-concept', '媒体'),
#  ('载体', 'sub-concept', '客观'),
#  ('载体', 'sub-concept', '密'),
#  ('载体', 'sub-concept', '建设'),
#  ('载体', 'sub-concept', '种类'),
#  ('载体', 'sub-concept', '称'),
#  ('载体', 'sub-concept', '类'),
#  ('载体', 'sub-concept', '要素'),
#  ('载体', 'sub-concept', '资源'),
#  ('载体', 'sub-concept', '载体'),
#  ('输出', 'sub-concept', '信息'),
#  ('输出', 'sub-concept', '类型'),
#  ('输出', 'sub-concept', '纸质'),
#  ('输出', 'sub-concept', '资源'),
#  ('辗转', 'sub-concept', '两'),
#  ('辗转', 'sub-concept', '信息'),
#  ('辗转', 'sub-concept', '分'),
#  ('辗转', 'sub-concept', '含义'),
#  ('辗转', 'sub-concept', '媒体'),
#  ('辗转', 'sub-concept', '客观'),
#  ('辗转', 'sub-concept', '密'),
#  ('辗转', 'sub-concept', '称'),
#  ('辗转', 'sub-concept', '类'),
#  ('辗转', 'sub-concept', '载体'),
#  ('过程', 'sub-concept', '信息'),
#  ('过程', 'sub-concept', '包括'),
#  ('过程', 'sub-concept', '印刷'),
#  ('过程', 'sub-concept', '含义'),
#  ('过程', 'sub-concept', '复制'),
#  ('过程', 'sub-concept', '多种'),
#  ('过程', 'sub-concept', '媒体'),
#  ('过程', 'sub-concept', '手写'),
#  ('过程', 'sub-concept', '手段'),
#  ('过程', 'sub-concept', '指'),
#  ('过程', 'sub-concept', '材料'),
#  ('过程', 'sub-concept', '看法'),
#  ('过程', 'sub-concept', '纸张'),
#  ('过程', 'sub-concept', '纸质'),
#  ('过程', 'sub-concept', '记录'),
#  ('过程', 'sub-concept', '资源'),
#  ('过程', 'sub-concept', '载体'),
#  ('过程', 'sub-concept', '集合'),
#  ('运动', 'sub-concept', '信息'),
#  ('运动', 'sub-concept', '概述'),
#  ('运动', 'sub-concept', '种类'),
#  ('进展期', 'sub-concept', '信息'),
#  ('进展期', 'sub-concept', '类型'),
#  ('进展期', 'sub-concept', '纸质'),
#  ('进展期', 'sub-concept', '资源'),
#  ('远程', 'sub-concept', '信息'),
#  ('远程', 'sub-concept', '种类'),
#  ('远程', 'sub-concept', '资源'),
#  ('连续', 'sub-concept', '信息'),
#  ('连续', 'sub-concept', '包括'),
#  ('连续', 'sub-concept', '印刷'),
#  ('连续', 'sub-concept', '复制'),
#  ('连续', 'sub-concept', '媒体'),
#  ('连续', 'sub-concept', '手写'),
#  ('连续', 'sub-concept', '手段'),
#  ('连续', 'sub-concept', '指'),
#  ('连续', 'sub-concept', '材料'),
#  ('连续', 'sub-concept', '纸张'),
#  ('连续', 'sub-concept', '纸质'),
#  ('连续', 'sub-concept', '记录'),
#  ('连续', 'sub-concept', '资源'),
#  ('连续', 'sub-concept', '载体'),
#  ('连续', 'sub-concept', '集合'),
#  ('选择', 'sub-concept', '信息'),
#  ('选择', 'sub-concept', '含义'),
#  ('选择', 'sub-concept', '多种'),
#  ('选择', 'sub-concept', '看法'),
#  ('选择', 'sub-concept', '资源'),
#  ('选题', 'sub-concept', '信息'),
#  ('选题', 'sub-concept', '类型'),
#  ('选题', 'sub-concept', '纸质'),
#  ('选题', 'sub-concept', '资源'),
#  ('重复', 'sub-concept', '信息'),
#  ('重复', 'sub-concept', '包括'),
#  ('重复', 'sub-concept', '印刷'),
#  ('重复', 'sub-concept', '复制'),
#  ('重复', 'sub-concept', '媒体'),
#  ('重复', 'sub-concept', '手写'),
#  ('重复', 'sub-concept', '手段'),
#  ('重复', 'sub-concept', '指'),
#  ('重复', 'sub-concept', '材料'),
#  ('重复', 'sub-concept', '类型'),
#  ('重复', 'sub-concept', '纸张'),
#  ('重复', 'sub-concept', '纸质'),
#  ('重复', 'sub-concept', '记录'),
#  ('重复', 'sub-concept', '资源'),
#  ('重复', 'sub-concept', '载体'),
#  ('重复', 'sub-concept', '集合'),
#  ('重点', 'sub-concept', '信息'),
#  ('重点', 'sub-concept', '包括'),
#  ('重点', 'sub-concept', '印刷'),
#  ('重点', 'sub-concept', '复制'),
#  ('重点', 'sub-concept', '媒体'),
#  ('重点', 'sub-concept', '手写'),
#  ('重点', 'sub-concept', '手段'),
#  ('重点', 'sub-concept', '指'),
#  ('重点', 'sub-concept', '材料'),
#  ('重点', 'sub-concept', '纸张'),
#  ('重点', 'sub-concept', '纸质'),
#  ('重点', 'sub-concept', '记录'),
#  ('重点', 'sub-concept', '资源'),
#  ('重点', 'sub-concept', '载体'),
#  ('重点', 'sub-concept', '集合'),
#  ('针对性', 'sub-concept', '两'),
#  ('针对性', 'sub-concept', '信息'),
#  ('针对性', 'sub-concept', '分'),
#  ('针对性', 'sub-concept', '含义'),
#  ('针对性', 'sub-concept', '媒体'),
#  ('针对性', 'sub-concept', '客观'),
#  ('针对性', 'sub-concept', '密'),
#  ('针对性', 'sub-concept', '称'),
#  ('针对性', 'sub-concept', '类'),
#  ('针对性', 'sub-concept', '类型'),
#  ('针对性', 'sub-concept', '纸质'),
#  ('针对性', 'sub-concept', '资源'),
#  ('针对性', 'sub-concept', '载体'),
#  ('链接', 'sub-concept', '信息'),
#  ('链接', 'sub-concept', '种类'),
#  ('链接', 'sub-concept', '资源'),
#  ('镜像', 'sub-concept', '信息'),
#  ('镜像', 'sub-concept', '种类'),
#  ('镜像', 'sub-concept', '资源'),
#  ('长', 'sub-concept', '信息'),
#  ('长', 'sub-concept', '包括'),
#  ('长', 'sub-concept', '印刷'),
#  ('长', 'sub-concept', '复制'),
#  ('长', 'sub-concept', '媒体'),
#  ('长', 'sub-concept', '手写'),
#  ('长', 'sub-concept', '手段'),
#  ('长', 'sub-concept', '指'),
#  ('长', 'sub-concept', '材料'),
#  ('长', 'sub-concept', '纸张'),
#  ('长', 'sub-concept', '纸质'),
#  ('长', 'sub-concept', '记录'),
#  ('长', 'sub-concept', '资源'),
#  ('长', 'sub-concept', '载体'),
#  ('长', 'sub-concept', '集合'),
#  ('长期', 'sub-concept', '信息'),
#  ('长期', 'sub-concept', '种类'),
#  ('长期', 'sub-concept', '资源'),
#  ('门', 'sub-concept', '信息'),
#  ('门', 'sub-concept', '类型'),
#  ('门', 'sub-concept', '纸质'),
#  ('门', 'sub-concept', '资源'),
#  ('间接', 'sub-concept', '信息'),
#  ('间接', 'sub-concept', '种类'),
#  ('院校', 'sub-concept', '信息'),
#  ('院校', 'sub-concept', '类型'),
#  ('院校', 'sub-concept', '纸质'),
#  ('院校', 'sub-concept', '资源'),
#  ('随意性', 'sub-concept', '两'),
#  ('随意性', 'sub-concept', '信息'),
#  ('随意性', 'sub-concept', '分'),
#  ('随意性', 'sub-concept', '含义'),
#  ('随意性', 'sub-concept', '媒体'),
#  ('随意性', 'sub-concept', '客观'),
#  ('随意性', 'sub-concept', '密'),
#  ('随意性', 'sub-concept', '称'),
#  ('随意性', 'sub-concept', '类'),
#  ('随意性', 'sub-concept', '载体'),
#  ('隐性', 'sub-concept', '信息'),
#  ('隐性', 'sub-concept', '种类'),
#  ('隐蔽', 'sub-concept', '两'),
#  ('隐蔽', 'sub-concept', '信息'),
#  ('隐蔽', 'sub-concept', '分'),
#  ('隐蔽', 'sub-concept', '含义'),
#  ('隐蔽', 'sub-concept', '媒体'),
#  ('隐蔽', 'sub-concept', '客观'),
#  ('隐蔽', 'sub-concept', '密'),
#  ('隐蔽', 'sub-concept', '称'),
#  ('隐蔽', 'sub-concept', '类'),
#  ('隐蔽', 'sub-concept', '载体'),
#  ('集合', 'sub-concept', '信息'),
#  ('集合', 'sub-concept', '含义'),
#  ('集合', 'sub-concept', '多种'),
#  ('集合', 'sub-concept', '建设'),
#  ('集合', 'sub-concept', '看法'),
#  ('集合', 'sub-concept', '资源'),
#  ('静态', 'sub-concept', '信息'),
#  ('静态', 'sub-concept', '种类'),
#  ('非定期', 'sub-concept', '图书'),
#  ('非密', 'sub-concept', '信息'),
#  ('非密', 'sub-concept', '类型'),
#  ('非密', 'sub-concept', '纸质'),
#  ('非密', 'sub-concept', '资源'),
#  ('页', 'sub-concept', '图书'),
#  ('顺序号', 'sub-concept', '信息'),
#  ('顺序号', 'sub-concept', '包括'),
#  ('顺序号', 'sub-concept', '印刷'),
#  ('顺序号', 'sub-concept', '复制'),
#  ('顺序号', 'sub-concept', '媒体'),
#  ('顺序号', 'sub-concept', '手写'),
#  ('顺序号', 'sub-concept', '手段'),
#  ('顺序号', 'sub-concept', '指'),
#  ('顺序号', 'sub-concept', '材料'),
#  ('顺序号', 'sub-concept', '纸张'),
#  ('顺序号', 'sub-concept', '纸质'),
#  ('顺序号', 'sub-concept', '记录'),
#  ('顺序号', 'sub-concept', '资源'),
#  ('顺序号', 'sub-concept', '载体'),
#  ('顺序号', 'sub-concept', '集合'),
#  ('题', 'sub-concept', '信息'),
#  ('题', 'sub-concept', '建设'),
#  ('题', 'sub-concept', '种类'),
#  ('题', 'sub-concept', '资源'),
#  ('高', 'sub-concept', '信息'),
#  ('高', 'sub-concept', '包括'),
#  ('高', 'sub-concept', '印刷'),
#  ('高', 'sub-concept', '复制'),
#  ('高', 'sub-concept', '媒体'),
#  ('高', 'sub-concept', '手写'),
#  ('高', 'sub-concept', '手段'),
#  ('高', 'sub-concept', '指'),
#  ('高', 'sub-concept', '材料'),
#  ('高', 'sub-concept', '纸张'),
#  ('高', 'sub-concept', '纸质'),
#  ('高', 'sub-concept', '记录'),
#  ('高', 'sub-concept', '资源'),
#  ('高', 'sub-concept', '载体'),
#  ('高', 'sub-concept', '集合'),
#  ('高等院校', 'sub-concept', '信息'),
#  ('高等院校', 'sub-concept', '类型'),
#  ('高等院校', 'sub-concept', '纸质'),
#  ('高等院校', 'sub-concept', '资源')}

# %% [markdown]
# 至此，一篇文档就由文本转换成了三元组
# 浏览上面的结果，目前比较难判断处理的效果，但是从一些元组中可以明显看到可用的逻辑
# 对于并不很严肃的课件能得到这样的结果是满意的

# %%
trigram_file_update = open(r"../tmp/trigram_update.csv","w",encoding="utf-8")
csv_writer = csv.writer(trigram_file_update)
for item in triple_set:
    csv_writer.writerow(item)
trigram_file_update.close()

# %%
trigram_b = open(r"../tmp/trigram.dat","wb")
pickle.dump(triple_set,trigram_b)
trigram_b.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-5e334ba8e56b> in <module>
#       1 trigram_b = open(r"../tmp/trigram.dat","w")
# ----> 2 pickle.dump(triple_set,trigram_b)
#       3 trigram_b.close()
#
# TypeError: write() argument must be str, not bytes
