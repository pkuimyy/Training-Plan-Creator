# %%
import csv

# %%
csv_file = open("../tmp/trigram_update.csv","r",encoding="utf-8")
csv_reader = csv.DictReader(csv_file)
trigram_list = []
for line in csv_reader:
    print(line)
#     trigram_list.append(line)
# print(trigram_list)
# Out:
# OrderedDict([('人脑', '期刊'), ('sub-concept', 'sub-concept'), ('密', '内容')])
# OrderedDict([('人脑', '行业'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '针对性'), ('sub-concept', 'sub-concept'), ('密', '载体')])
# OrderedDict([('人脑', '中'), ('sub-concept', 'sub-concept'), ('密', '包括')])
# OrderedDict([('人脑', '称'), ('sub-concept', 'sub-concept'), ('密', '客观')])
# OrderedDict([('人脑', '连续'), ('sub-concept', 'sub-concept'), ('密', '集合')])
# OrderedDict([('人脑', '固定'), ('sub-concept', 'sub-concept'), ('密', '记录')])
# OrderedDict([('人脑', '作者'), ('sub-concept', 'sub-concept'), ('密', '手段')])
# OrderedDict([('人脑', '成就'), ('sub-concept', 'sub-concept'), ('密', '期')])
# OrderedDict([('人脑', '保存'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '信息'), ('sub-concept', 'sub-concept'), ('密', '作者')])
# OrderedDict([('人脑', '发展'), ('sub-concept', 'sub-concept'), ('密', '纸张')])
# OrderedDict([('人脑', '加工'), ('sub-concept', 'sub-concept'), ('密', '分')])
# OrderedDict([('人脑', 'n倍'), ('sub-concept', 'sub-concept'), ('密', '统一')])
# OrderedDict([('人脑', '劳动'), ('sub-concept', 'sub-concept'), ('密', '看法')])
# OrderedDict([('人脑', '撰写'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', 'n倍'), ('sub-concept', 'sub-concept'), ('密', '超过')])
# OrderedDict([('人脑', '模仿'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '积累'), ('sub-concept', 'sub-concept'), ('密', '含义')])
# OrderedDict([('人脑', '49'), ('sub-concept', 'sub-concept'), ('密', '作者')])
# OrderedDict([('人脑', '成就'), ('sub-concept', 'sub-concept'), ('密', '极')])
# OrderedDict([('人脑', '固定'), ('sub-concept', 'sub-concept'), ('密', '手段')])
# OrderedDict([('人脑', '交流'), ('sub-concept', 'sub-concept'), ('密', '类')])
# OrderedDict([('人脑', '藏'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '人才'), ('sub-concept', 'sub-concept'), ('密', '卷')])
# OrderedDict([('人脑', '媒体'), ('sub-concept', 'sub-concept'), ('密', '文章')])
# OrderedDict([('人脑', '分为'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '即P'), ('sub-concept', 'sub-concept'), ('密', '包括')])
# OrderedDict([('人脑', '登载'), ('sub-concept', 'sub-concept'), ('密', '材料')])
# OrderedDict([('人脑', '学术性'), ('sub-concept', 'sub-concept'), ('密', '版式')])
# OrderedDict([('人脑', '文献'), ('sub-concept', 'sub-concept'), ('密', '续')])
# OrderedDict([('人脑', '足'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', 'p'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '利用率'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '人脑'), ('sub-concept', 'sub-concept'), ('密', '类')])
# OrderedDict([('人脑', '记载'), ('sub-concept', 'sub-concept'), ('密', '连续')])
# OrderedDict([('人脑', '协调'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '极'), ('sub-concept', 'sub-concept'), ('密', '集合')])
# OrderedDict([('人脑', '论文'), ('sub-concept', 'sub-concept'), ('密', '篇')])
# OrderedDict([('人脑', '缺点'), ('sub-concept', 'sub-concept'), ('密', '两')])
# OrderedDict([('人脑', '称'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '足'), ('sub-concept', 'sub-concept'), ('密', '类')])
# OrderedDict([('人脑', '记载'), ('sub-concept', 'sub-concept'), ('密', '名称')])
# OrderedDict([('人脑', '人类'), ('sub-concept', 'sub-concept'), ('密', '载体')])
# OrderedDict([('人脑', '官方'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '磁盘'), ('sub-concept', 'sub-concept'), ('密', '客观')])
# OrderedDict([('人脑', '定义'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '培养'), ('sub-concept', 'sub-concept'), ('密', '期')])
# OrderedDict([('人脑', '表达'), ('sub-concept', 'sub-concept'), ('密', '类')])
# OrderedDict([('人脑', '即P'), ('sub-concept', 'sub-concept'), ('密', '指')])
# OrderedDict([('人脑', '含义'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '公布'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '信息'), ('sub-concept', 'sub-concept'), ('密', '重复')])
# OrderedDict([('人脑', '水平'), ('sub-concept', 'sub-concept'), ('密', '纸张')])
# OrderedDict([('人脑', '续'), ('sub-concept', 'sub-concept'), ('密', '手写')])
# OrderedDict([('人脑', '纸张'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '记载'), ('sub-concept', 'sub-concept'), ('密', '固定')])
# OrderedDict([('人脑', '分布'), ('sub-concept', 'sub-concept'), ('密', '记录')])
# OrderedDict([('人脑', '学科'), ('sub-concept', 'sub-concept'), ('密', '材料')])
# OrderedDict([('人脑', 'n倍'), ('sub-concept', 'sub-concept'), ('密', '作者')])
# OrderedDict([('人脑', '统计'), ('sub-concept', 'sub-concept'), ('密', '续')])
# OrderedDict([('人脑', '称为'), ('sub-concept', 'sub-concept'), ('密', '印刷')])
# OrderedDict([('人脑', '学位'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '剩下'), ('sub-concept', 'sub-concept'), ('密', '出版')])
# OrderedDict([('人脑', 'n'), ('sub-concept', 'sub-concept'), ('密', '手写')])
# OrderedDict([('人脑', '登载'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '称为'), ('sub-concept', 'sub-concept'), ('密', '材料')])
# OrderedDict([('人脑', '总称'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '工具'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '区域'), ('sub-concept', 'sub-concept'), ('密', '印刷')])
# OrderedDict([('人脑', '审查'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '获取'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '长期'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '284'), ('sub-concept', 'sub-concept'), ('密', '周期')])
# OrderedDict([('人脑', '情况'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '文献'), ('sub-concept', 'sub-concept'), ('密', '般')])
# OrderedDict([('人脑', '值'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '形式'), ('sub-concept', 'sub-concept'), ('密', '多种')])
# OrderedDict([('人脑', '媒体'), ('sub-concept', 'sub-concept'), ('密', '般')])
# OrderedDict([('人脑', '引用率'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '传递'), ('sub-concept', 'sub-concept'), ('密', '载体')])
# OrderedDict([('人脑', '结论'), ('sub-concept', 'sub-concept'), ('密', '作者')])
# OrderedDict([('人脑', '信息源'), ('sub-concept', 'sub-concept'), ('密', '密')])
# OrderedDict([('人脑', '顺序号'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '电子型'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '第三'), ('sub-concept', 'sub-concept'), ('密', '期')])
# OrderedDict([('人脑', '数量'), ('sub-concept', 'sub-concept'), ('密', '登载')])
# OrderedDict([('人脑', '宣传品'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '定义'), ('sub-concept', 'sub-concept'), ('密', '手写')])
# OrderedDict([('人脑', '声波'), ('sub-concept', 'sub-concept'), ('密', '类')])
# OrderedDict([('人脑', '纸张'), ('sub-concept', 'sub-concept'), ('密', '客观')])
# OrderedDict([('人脑', '文章'), ('sub-concept', 'sub-concept'), ('密', '包括')])
# OrderedDict([('人脑', '表达'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '文献'), ('sub-concept', 'sub-concept'), ('密', '多种')])
# OrderedDict([('人脑', '续'), ('sub-concept', 'sub-concept'), ('密', '载体')])
# OrderedDict([('人脑', '记载'), ('sub-concept', 'sub-concept'), ('密', '定期')])
# OrderedDict([('人脑', '收集'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '相关'), ('sub-concept', 'sub-concept'), ('密', '多种')])
# OrderedDict([('人脑', '定期'), ('sub-concept', 'sub-concept'), ('密', '材料')])
# OrderedDict([('人脑', '成果'), ('sub-concept', 'sub-concept'), ('密', '极')])
# OrderedDict([('人脑', '国防部'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '有用'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '少'), ('sub-concept', 'sub-concept'), ('密', '包括')])
# OrderedDict([('人脑', '区域'), ('sub-concept', 'sub-concept'), ('密', '纸张')])
# OrderedDict([('人脑', '剩下'), ('sub-concept', 'sub-concept'), ('密', '再版')])
# OrderedDict([('人脑', '声波'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '版式'), ('sub-concept', 'sub-concept'), ('密', '记录')])
# OrderedDict([('人脑', '中'), ('sub-concept', 'sub-concept'), ('密', '重复')])
# OrderedDict([('人脑', '媒体'), ('sub-concept', 'sub-concept'), ('密', '篇')])
# OrderedDict([('人脑', '统计'), ('sub-concept', 'sub-concept'), ('密', '各期')])
# OrderedDict([('人脑', '成果'), ('sub-concept', 'sub-concept'), ('密', '统一')])
# OrderedDict([('人脑', '依附性'), ('sub-concept', 'sub-concept'), ('密', '特征')])
# OrderedDict([('人脑', '若干'), ('sub-concept', 'sub-concept'), ('密', '顺序号')])
# OrderedDict([('人脑', 'n2'), ('sub-concept', 'sub-concept'), ('密', '名称')])
# OrderedDict([('人脑', '失真'), ('sub-concept', 'sub-concept'), ('密', '两')])
# OrderedDict([('人脑', '篇'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '流通'), ('sub-concept', 'sub-concept'), ('密', '手写')])
# OrderedDict([('人脑', '资源'), ('sub-concept', 'sub-concept'), ('密', '多种')])
# OrderedDict([('人脑', '记录'), ('sub-concept', 'sub-concept'), ('密', '两')])
# OrderedDict([('人脑', '光盘'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '年月'), ('sub-concept', 'sub-concept'), ('密', '纸张')])
# OrderedDict([('人脑', '人才'), ('sub-concept', 'sub-concept'), ('密', '居多')])
# OrderedDict([('人脑', '统计'), ('sub-concept', 'sub-concept'), ('密', '登载')])
# OrderedDict([('人脑', '光波'), ('sub-concept', 'sub-concept'), ('密', '含义')])
# OrderedDict([('人脑', '文献'), ('sub-concept', 'sub-concept'), ('密', '期刊')])
# OrderedDict([('人脑', '成果'), ('sub-concept', 'sub-concept'), ('密', '周期')])
# OrderedDict([('人脑', '存取'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '检阅'), ('sub-concept', 'sub-concept'), ('密', '期刊')])
# OrderedDict([('人脑', '刊载'), ('sub-concept', 'sub-concept'), ('密', '手写')])
# OrderedDict([('人脑', '媒体'), ('sub-concept', 'sub-concept'), ('密', '续')])
# OrderedDict([('人脑', '美国'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '提取'), ('sub-concept', 'sub-concept'), ('密', '密')])
# OrderedDict([('人脑', '284'), ('sub-concept', 'sub-concept'), ('密', '年月')])
# OrderedDict([('人脑', ' '), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '剩下'), ('sub-concept', 'sub-concept'), ('密', '期')])
# OrderedDict([('人脑', '作用'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '社会'), ('sub-concept', 'sub-concept'), ('密', '看法')])
# OrderedDict([('人脑', '区域'), ('sub-concept', 'sub-concept'), ('密', '各期')])
# OrderedDict([('人脑', '电'), ('sub-concept', 'sub-concept'), ('密', '版式')])
# OrderedDict([('人脑', '权威'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '年'), ('sub-concept', 'sub-concept'), ('密', '手写')])
# OrderedDict([('人脑', '利用率'), ('sub-concept', 'sub-concept'), ('密', '手段')])
# OrderedDict([('人脑', '纸质'), ('sub-concept', 'sub-concept'), ('密', '建设')])
# OrderedDict([('人脑', '等同'), ('sub-concept', 'sub-concept'), ('密', '多种')])
# OrderedDict([('人脑', '现状'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '本体'), ('sub-concept', 'sub-concept'), ('密', '多种')])
# OrderedDict([('人脑', '信息源'), ('sub-concept', 'sub-concept'), ('密', '分')])
# OrderedDict([('人脑', '布拉德福'), ('sub-concept', 'sub-concept'), ('密', '续')])
# OrderedDict([('人脑', '引用率'), ('sub-concept', 'sub-concept'), ('密', '手写')])
# OrderedDict([('人脑', '远程'), ('sub-concept', 'sub-concept'), ('密', '种类')])
# OrderedDict([('人脑', '布拉德福'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '加工'), ('sub-concept', 'sub-concept'), ('密', '两')])
# OrderedDict([('人脑', '剩下'), ('sub-concept', 'sub-concept'), ('密', '作者')])
# OrderedDict([('人脑', '随意性'), ('sub-concept', 'sub-concept'), ('密', '客观')])
# OrderedDict([('人脑', '中'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '论文'), ('sub-concept', 'sub-concept'), ('密', '极')])
# OrderedDict([('人脑', '分布'), ('sub-concept', 'sub-concept'), ('密', '手段')])
# OrderedDict([('人脑', '图书'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '等同'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '学术性'), ('sub-concept', 'sub-concept'), ('密', '出版')])
# OrderedDict([('人脑', '内容'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '周期'), ('sub-concept', 'sub-concept'), ('密', '包括')])
# OrderedDict([('人脑', '知识'), ('sub-concept', 'sub-concept'), ('密', '称')])
# OrderedDict([('人脑', '学术'), ('sub-concept', 'sub-concept'), ('密', '再版')])
# OrderedDict([('人脑', '定义'), ('sub-concept', 'sub-concept'), ('密', '多种')])
# OrderedDict([('人脑', '前'), ('sub-concept', 'sub-concept'), ('密', '极')])
# OrderedDict([('人脑', '出版物'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '布拉德福'), ('sub-concept', 'sub-concept'), ('密', '记录')])
# OrderedDict([('人脑', '内容'), ('sub-concept', 'sub-concept'), ('密', '密')])
# OrderedDict([('人脑', '方法'), ('sub-concept', 'sub-concept'), ('密', '图书')])
# OrderedDict([('人脑', '资源'), ('sub-concept', 'sub-concept'), ('密', '手段')])
# OrderedDict([('人脑', '文献'), ('sub-concept', 'sub-concept'), ('密', '思考')])
# OrderedDict([('人脑', '包含'), ('sub-concept', 'sub-concept'), ('密', '顺序号')])
# OrderedDict([('人脑', '含有'), ('sub-concept', 'sub-concept'), ('密', '版式')])
# OrderedDict([('人脑', '内外'), ('sub-concept', 'sub-concept'), ('密', '多种')])
# OrderedDict([('人脑', '物质'), ('sub-concept', 'sub-concept'), ('密', '密')])
# OrderedDict([('人脑', '序化'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '时常'), ('sub-concept', 'sub-concept'), ('密', '载体')])
# OrderedDict([('人脑', '永久'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '各期'), ('sub-concept', 'sub-concept'), ('密', '指')])
# OrderedDict([('人脑', '倍'), ('sub-concept', 'sub-concept'), ('密', '重复')])
# OrderedDict([('人脑', '结论'), ('sub-concept', 'sub-concept'), ('密', '年')])
# OrderedDict([('人脑', '代表'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '被摘率'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '篇'), ('sub-concept', 'sub-concept'), ('密', '记录')])
# OrderedDict([('人脑', '成就'), ('sub-concept', 'sub-concept'), ('密', '各期')])
# OrderedDict([('人脑', '胶片'), ('sub-concept', 'sub-concept'), ('密', '类')])
# OrderedDict([('人脑', '水平'), ('sub-concept', 'sub-concept'), ('密', '手写')])
# OrderedDict([('人脑', '国际'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '国防部'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '使用者'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '种类'), ('sub-concept', 'sub-concept'), ('密', '概述')])
# OrderedDict([('人脑', 'n2'), ('sub-concept', 'sub-concept'), ('密', '印刷')])
# OrderedDict([('人脑', '前'), ('sub-concept', 'sub-concept'), ('密', '居多')])
# OrderedDict([('人脑', '发展'), ('sub-concept', 'sub-concept'), ('密', '载体')])
# OrderedDict([('人脑', '两'), ('sub-concept', 'sub-concept'), ('密', '周期')])
# OrderedDict([('人脑', '登载'), ('sub-concept', 'sub-concept'), ('密', '固定')])
# OrderedDict([('人脑', '年月'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '剩下'), ('sub-concept', 'sub-concept'), ('密', '篇')])
# OrderedDict([('人脑', '细节'), ('sub-concept', 'sub-concept'), ('密', '两')])
# OrderedDict([('人脑', '动态性'), ('sub-concept', 'sub-concept'), ('密', '特性')])
# OrderedDict([('人脑', '核心'), ('sub-concept', 'sub-concept'), ('密', '年月')])
# OrderedDict([('人脑', '高'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '光波'), ('sub-concept', 'sub-concept'), ('密', '类')])
# OrderedDict([('人脑', '伴随'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '固定'), ('sub-concept', 'sub-concept'), ('密', '载体')])
# OrderedDict([('人脑', '源优点'), ('sub-concept', 'sub-concept'), ('密', '客观')])
# OrderedDict([('人脑', 'n倍'), ('sub-concept', 'sub-concept'), ('密', '内容')])
# OrderedDict([('人脑', '审查'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '研究'), ('sub-concept', 'sub-concept'), ('密', '版式')])
# OrderedDict([('人脑', '水平'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '倍'), ('sub-concept', 'sub-concept'), ('密', '出版物')])
# OrderedDict([('人脑', '得以'), ('sub-concept', 'sub-concept'), ('密', '类')])
# OrderedDict([('人脑', '文献'), ('sub-concept', 'sub-concept'), ('密', '看法')])
# OrderedDict([('人脑', '现状'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '包含'), ('sub-concept', 'sub-concept'), ('密', '分')])
# OrderedDict([('人脑', '电'), ('sub-concept', 'sub-concept'), ('密', '重复')])
# OrderedDict([('人脑', '论文'), ('sub-concept', 'sub-concept'), ('密', '期')])
# OrderedDict([('人脑', '选题'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '分布'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '产品'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '超过'), ('sub-concept', 'sub-concept'), ('密', '记录')])
# OrderedDict([('人脑', '核心'), ('sub-concept', 'sub-concept'), ('密', '出版')])
# OrderedDict([('人脑', '高'), ('sub-concept', 'sub-concept'), ('密', '手写')])
# OrderedDict([('人脑', '各期'), ('sub-concept', 'sub-concept'), ('密', '材料')])
# OrderedDict([('人脑', '结论'), ('sub-concept', 'sub-concept'), ('密', '连续')])
# OrderedDict([('人脑', '缺点'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', 'n2'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '核心'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '中'), ('sub-concept', 'sub-concept'), ('密', '纸张')])
# OrderedDict([('人脑', '足'), ('sub-concept', 'sub-concept'), ('密', '两')])
# OrderedDict([('人脑', '即P'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '水平'), ('sub-concept', 'sub-concept'), ('密', '载体')])
# OrderedDict([('人脑', '动态性'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '年月'), ('sub-concept', 'sub-concept'), ('密', '印刷')])
# OrderedDict([('人脑', '技术'), ('sub-concept', 'sub-concept'), ('密', '出版物')])
# OrderedDict([('人脑', '学科'), ('sub-concept', 'sub-concept'), ('密', '般')])
# OrderedDict([('人脑', '科学'), ('sub-concept', 'sub-concept'), ('密', '功能')])
# OrderedDict([('人脑', '定律'), ('sub-concept', 'sub-concept'), ('密', '记录')])
# OrderedDict([('人脑', '共'), ('sub-concept', 'sub-concept'), ('密', '超过')])
# OrderedDict([('人脑', '定期'), ('sub-concept', 'sub-concept'), ('密', '手写')])
# OrderedDict([('人脑', '中'), ('sub-concept', 'sub-concept'), ('密', '复制')])
# OrderedDict([('人脑', '过程'), ('sub-concept', 'sub-concept'), ('密', '纸张')])
# OrderedDict([('人脑', '检测'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '登载'), ('sub-concept', 'sub-concept'), ('密', '指')])
# OrderedDict([('人脑', '图书'), ('sub-concept', 'sub-concept'), ('密', '复制')])
# OrderedDict([('人脑', '科学技术'), ('sub-concept', 'sub-concept'), ('密', '版式')])
# OrderedDict([('人脑', '固定'), ('sub-concept', 'sub-concept'), ('密', '包括')])
# OrderedDict([('人脑', '期'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '期刊'), ('sub-concept', 'sub-concept'), ('密', '期')])
# OrderedDict([('人脑', '49'), ('sub-concept', 'sub-concept'), ('密', '内容')])
# OrderedDict([('人脑', '代表'), ('sub-concept', 'sub-concept'), ('密', '手段')])
# OrderedDict([('人脑', '被摘率'), ('sub-concept', 'sub-concept'), ('密', '手段')])
# OrderedDict([('人脑', '媒体'), ('sub-concept', 'sub-concept'), ('密', '期刊')])
# OrderedDict([('人脑', '文献'), ('sub-concept', 'sub-concept'), ('密', '包括')])
# OrderedDict([('人脑', '核心'), ('sub-concept', 'sub-concept'), ('密', '材料')])
# OrderedDict([('人脑', '社会'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '可靠'), ('sub-concept', 'sub-concept'), ('密', '两')])
# OrderedDict([('人脑', '称'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '登载'), ('sub-concept', 'sub-concept'), ('密', '版式')])
# OrderedDict([('人脑', '光盘'), ('sub-concept', 'sub-concept'), ('密', '种类')])
# OrderedDict([('人脑', '传递'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '含有'), ('sub-concept', 'sub-concept'), ('密', '登载')])
# OrderedDict([('人脑', '综合国'), ('sub-concept', 'sub-concept'), ('密', '看法')])
# OrderedDict([('人脑', '定义'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '结论'), ('sub-concept', 'sub-concept'), ('密', '卷')])
# OrderedDict([('人脑', '永久'), ('sub-concept', 'sub-concept'), ('密', '种类')])
# OrderedDict([('人脑', '内容'), ('sub-concept', 'sub-concept'), ('密', '复制')])
# OrderedDict([('人脑', '媒体'), ('sub-concept', 'sub-concept'), ('密', '再版')])
# OrderedDict([('人脑', '反馈'), ('sub-concept', 'sub-concept'), ('密', '密')])
# OrderedDict([('人脑', '含有'), ('sub-concept', 'sub-concept'), ('密', '各期')])
# OrderedDict([('人脑', '发展'), ('sub-concept', 'sub-concept'), ('密', '印刷')])
# OrderedDict([('人脑', '命令'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '居多'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '期'), ('sub-concept', 'sub-concept'), ('密', '印刷')])
# OrderedDict([('人脑', '负担'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '人脑'), ('sub-concept', 'sub-concept'), ('密', '客观')])
# OrderedDict([('人脑', '交流'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '即P'), ('sub-concept', 'sub-concept'), ('密', '集合')])
# OrderedDict([('人脑', '年'), ('sub-concept', 'sub-concept'), ('密', '版式')])
# OrderedDict([('人脑', '结论'), ('sub-concept', 'sub-concept'), ('密', '定期')])
# OrderedDict([('人脑', '定义'), ('sub-concept', 'sub-concept'), ('密', '材料')])
# OrderedDict([('人脑', '成就'), ('sub-concept', 'sub-concept'), ('密', '作者')])
# OrderedDict([('人脑', '信息'), ('sub-concept', 'sub-concept'), ('密', '期')])
# OrderedDict([('人脑', '续'), ('sub-concept', 'sub-concept'), ('密', '记录')])
# OrderedDict([('人脑', '利用率'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '公司'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '寿命'), ('sub-concept', 'sub-concept'), ('密', '手段')])
# OrderedDict([('人脑', 'n'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '培养'), ('sub-concept', 'sub-concept'), ('密', '卷')])
# OrderedDict([('人脑', 'PB'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '远程'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', ' '), ('sub-concept', 'sub-concept'), ('密', '续')])
# OrderedDict([('人脑', '读者'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '再版'), ('sub-concept', 'sub-concept'), ('密', '手写')])
# OrderedDict([('人脑', '本体'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '两'), ('sub-concept', 'sub-concept'), ('密', '固定')])
# OrderedDict([('人脑', '广义'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '含有'), ('sub-concept', 'sub-concept'), ('密', '般')])
# OrderedDict([('人脑', '统计'), ('sub-concept', 'sub-concept'), ('密', '出版物')])
# OrderedDict([('人脑', '少'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '区域'), ('sub-concept', 'sub-concept'), ('密', '版式')])
# OrderedDict([('人脑', '人才'), ('sub-concept', 'sub-concept'), ('密', '期')])
# OrderedDict([('人脑', '若干'), ('sub-concept', 'sub-concept'), ('密', '内容')])
# OrderedDict([('人脑', '物质'), ('sub-concept', 'sub-concept'), ('密', '两')])
# OrderedDict([('人脑', '文献'), ('sub-concept', 'sub-concept'), ('密', '密')])
# OrderedDict([('人脑', '记录'), ('sub-concept', 'sub-concept'), ('密', '载体')])
# OrderedDict([('人脑', '用以'), ('sub-concept', 'sub-concept'), ('密', '图书')])
# OrderedDict([('人脑', '科技'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '引进'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '学科'), ('sub-concept', 'sub-concept'), ('密', '手写')])
# OrderedDict([('人脑', '剩下'), ('sub-concept', 'sub-concept'), ('密', '卷')])
# OrderedDict([('人脑', '开发'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '对象'), ('sub-concept', 'sub-concept'), ('密', '称')])
# OrderedDict([('人脑', '卷'), ('sub-concept', 'sub-concept'), ('密', '指')])
# OrderedDict([('人脑', '读者'), ('sub-concept', 'sub-concept'), ('密', '材料')])
# OrderedDict([('人脑', '可靠性'), ('sub-concept', 'sub-concept'), ('密', '两')])
# OrderedDict([('人脑', '承担'), ('sub-concept', 'sub-concept'), ('密', '种类')])
# OrderedDict([('人脑', '共'), ('sub-concept', 'sub-concept'), ('密', '名称')])
# OrderedDict([('人脑', '手写'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '名称'), ('sub-concept', 'sub-concept'), ('密', '载体')])
# OrderedDict([('人脑', 'n倍'), ('sub-concept', 'sub-concept'), ('密', '极')])
# OrderedDict([('人脑', '有用'), ('sub-concept', 'sub-concept'), ('密', '多种')])
# OrderedDict([('人脑', '磁带'), ('sub-concept', 'sub-concept'), ('密', '载体')])
# OrderedDict([('人脑', '统计'), ('sub-concept', 'sub-concept'), ('密', '再版')])
# OrderedDict([('人脑', '高'), ('sub-concept', 'sub-concept'), ('密', '纸张')])
# OrderedDict([('人脑', '成就'), ('sub-concept', 'sub-concept'), ('密', '统一')])
# OrderedDict([('人脑', '传递'), ('sub-concept', 'sub-concept'), ('密', '固定')])
# OrderedDict([('人脑', '定律'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '技术'), ('sub-concept', 'sub-concept'), ('密', '年月')])
# OrderedDict([('人脑', '单位'), ('sub-concept', 'sub-concept'), ('密', '重复')])
# OrderedDict([('人脑', 'n倍'), ('sub-concept', 'sub-concept'), ('密', '期')])
# OrderedDict([('人脑', '期刊'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '论文'), ('sub-concept', 'sub-concept'), ('密', '再版')])
# OrderedDict([('人脑', '中'), ('sub-concept', 'sub-concept'), ('密', '期')])
# OrderedDict([('人脑', '倍'), ('sub-concept', 'sub-concept'), ('密', '统一')])
# OrderedDict([('人脑', '代表'), ('sub-concept', 'sub-concept'), ('密', '记录')])
# OrderedDict([('人脑', '图书'), ('sub-concept', 'sub-concept'), ('密', '纸张')])
# OrderedDict([('人脑', '被摘率'), ('sub-concept', 'sub-concept'), ('密', '记录')])
# OrderedDict([('人脑', '家'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '竞争'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '学科'), ('sub-concept', 'sub-concept'), ('密', '指')])
# OrderedDict([('人脑', '年'), ('sub-concept', 'sub-concept'), ('密', '周期')])
# OrderedDict([('人脑', '含有'), ('sub-concept', 'sub-concept'), ('密', '续')])
# OrderedDict([('人脑', '少'), ('sub-concept', 'sub-concept'), ('密', '印刷')])
# OrderedDict([('人脑', '期刊'), ('sub-concept', 'sub-concept'), ('密', '出版')])
# OrderedDict([('人脑', '期刊'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '反馈'), ('sub-concept', 'sub-concept'), ('密', '客观')])
# OrderedDict([('人脑', '经费'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '各期'), ('sub-concept', 'sub-concept'), ('密', '载体')])
# OrderedDict([('人脑', '统一'), ('sub-concept', 'sub-concept'), ('密', '包括')])
# OrderedDict([('人脑', '再版'), ('sub-concept', 'sub-concept'), ('密', '载体')])
# OrderedDict([('人脑', 'p'), ('sub-concept', 'sub-concept'), ('密', '包括')])
# OrderedDict([('人脑', '反馈'), ('sub-concept', 'sub-concept'), ('密', '称')])
# OrderedDict([('人脑', '称'), ('sub-concept', 'sub-concept'), ('密', '材料')])
# OrderedDict([('人脑', '第三'), ('sub-concept', 'sub-concept'), ('密', '年月')])
# OrderedDict([('人脑', ' '), ('sub-concept', 'sub-concept'), ('密', '居多')])
# OrderedDict([('人脑', '包含'), ('sub-concept', 'sub-concept'), ('密', '密')])
# OrderedDict([('人脑', 'n'), ('sub-concept', 'sub-concept'), ('密', '记录')])
# OrderedDict([('人脑', '信息源'), ('sub-concept', 'sub-concept'), ('密', '客观')])
# OrderedDict([('人脑', ' '), ('sub-concept', 'sub-concept'), ('密', '顺序号')])
# OrderedDict([('人脑', '有序化'), ('sub-concept', 'sub-concept'), ('密', '多种')])
# OrderedDict([('人脑', '单位'), ('sub-concept', 'sub-concept'), ('密', '少')])
# OrderedDict([('人脑', '发现'), ('sub-concept', 'sub-concept'), ('密', '超过')])
# OrderedDict([('人脑', '建设'), ('sub-concept', 'sub-concept'), ('密', '客观')])
# OrderedDict([('人脑', '超过'), ('sub-concept', 'sub-concept'), ('密', '手段')])
# OrderedDict([('人脑', '情报'), ('sub-concept', 'sub-concept'), ('密', '要素')])
# OrderedDict([('人脑', '建设性'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '高'), ('sub-concept', 'sub-concept'), ('密', '材料')])
# OrderedDict([('人脑', '组织'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '光盘'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '发展'), ('sub-concept', 'sub-concept'), ('密', '手段')])
# OrderedDict([('人脑', '光波'), ('sub-concept', 'sub-concept'), ('密', '分')])
# OrderedDict([('人脑', '登载'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '区域'), ('sub-concept', 'sub-concept'), ('密', '文章')])
# OrderedDict([('人脑', '剩下'), ('sub-concept', 'sub-concept'), ('密', '内容')])
# OrderedDict([('人脑', '续'), ('sub-concept', 'sub-concept'), ('密', '包括')])
# OrderedDict([('人脑', '政务'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '学科'), ('sub-concept', 'sub-concept'), ('密', '年月')])
# OrderedDict([('人脑', '传递'), ('sub-concept', 'sub-concept'), ('密', '版式')])
# OrderedDict([('人脑', 'n2'), ('sub-concept', 'sub-concept'), ('密', '居多')])
# OrderedDict([('人脑', '意识'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '纸'), ('sub-concept', 'sub-concept'), ('密', '种类')])
# OrderedDict([('人脑', '人才'), ('sub-concept', 'sub-concept'), ('密', '作者')])
# OrderedDict([('人脑', '可靠性'), ('sub-concept', 'sub-concept'), ('密', '密')])
# OrderedDict([('人脑', '版式'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '周期'), ('sub-concept', 'sub-concept'), ('密', '手段')])
# OrderedDict([('人脑', '年'), ('sub-concept', 'sub-concept'), ('密', '登载')])
# OrderedDict([('人脑', '登载'), ('sub-concept', 'sub-concept'), ('密', '包括')])
# OrderedDict([('人脑', '登载'), ('sub-concept', 'sub-concept'), ('密', '出版')])
# OrderedDict([('人脑', '284'), ('sub-concept', 'sub-concept'), ('密', '期')])
# OrderedDict([('人脑', '记载'), ('sub-concept', 'sub-concept'), ('密', '文章')])
# OrderedDict([('人脑', '称为'), ('sub-concept', 'sub-concept'), ('密', '手写')])
# OrderedDict([('人脑', '培养'), ('sub-concept', 'sub-concept'), ('密', '超过')])
# OrderedDict([('人脑', '年'), ('sub-concept', 'sub-concept'), ('密', '各期')])
# OrderedDict([('人脑', '寿命'), ('sub-concept', 'sub-concept'), ('密', '复制')])
# OrderedDict([('人脑', '足'), ('sub-concept', 'sub-concept'), ('密', '客观')])
# OrderedDict([('人脑', '社会'), ('sub-concept', 'sub-concept'), ('密', '作用')])
# OrderedDict([('人脑', '资源'), ('sub-concept', 'sub-concept'), ('密', '包括')])
# OrderedDict([('人脑', '225'), ('sub-concept', 'sub-concept'), ('密', '登载')])
# OrderedDict([('人脑', '四'), ('sub-concept', 'sub-concept'), ('密', '思考')])
# OrderedDict([('人脑', '官方'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '研究'), ('sub-concept', 'sub-concept'), ('密', '固定')])
# OrderedDict([('人脑', '细节'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '前'), ('sub-concept', 'sub-concept'), ('密', '重复')])
# OrderedDict([('人脑', '成果'), ('sub-concept', 'sub-concept'), ('密', '重复')])
# OrderedDict([('人脑', '光盘'), ('sub-concept', 'sub-concept'), ('密', '客观')])
# OrderedDict([('人脑', '内容'), ('sub-concept', 'sub-concept'), ('密', '手段')])
# OrderedDict([('人脑', '利用'), ('sub-concept', 'sub-concept'), ('密', '两')])
# OrderedDict([('人脑', '国会'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '学术性'), ('sub-concept', 'sub-concept'), ('密', '各期')])
# OrderedDict([('人脑', '信息'), ('sub-concept', 'sub-concept'), ('密', '称')])
# OrderedDict([('人脑', '共'), ('sub-concept', 'sub-concept'), ('密', '卷')])
# OrderedDict([('人脑', '定期'), ('sub-concept', 'sub-concept'), ('密', '指')])
# OrderedDict([('人脑', '年'), ('sub-concept', 'sub-concept'), ('密', '般')])
# OrderedDict([('人脑', '引用率'), ('sub-concept', 'sub-concept'), ('密', '纸张')])
# OrderedDict([('人脑', '表达'), ('sub-concept', 'sub-concept'), ('密', '称')])
# OrderedDict([('人脑', '隐蔽'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '称为'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '思想'), ('sub-concept', 'sub-concept'), ('密', '要素')])
# OrderedDict([('人脑', '藏'), ('sub-concept', 'sub-concept'), ('密', '种类')])
# OrderedDict([('人脑', '足'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '记载'), ('sub-concept', 'sub-concept'), ('密', '出版')])
# OrderedDict([('人脑', '统一'), ('sub-concept', 'sub-concept'), ('密', '集合')])
# OrderedDict([('人脑', '水平'), ('sub-concept', 'sub-concept'), ('密', '复制')])
# OrderedDict([('人脑', '常用'), ('sub-concept', 'sub-concept'), ('密', '种类')])
# OrderedDict([('人脑', '文献'), ('sub-concept', 'sub-concept'), ('密', '材料')])
# OrderedDict([('人脑', '信息'), ('sub-concept', 'sub-concept'), ('密', '分')])
# OrderedDict([('人脑', '区域'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '新颖性'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '活动'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '期刊'), ('sub-concept', 'sub-concept'), ('密', '材料')])
# OrderedDict([('人脑', '成就'), ('sub-concept', 'sub-concept'), ('密', '超过')])
# OrderedDict([('人脑', '电'), ('sub-concept', 'sub-concept'), ('密', '超过')])
# OrderedDict([('人脑', '49'), ('sub-concept', 'sub-concept'), ('密', '篇')])
# OrderedDict([('人脑', '含量'), ('sub-concept', 'sub-concept'), ('密', '指')])
# OrderedDict([('人脑', '学术性'), ('sub-concept', 'sub-concept'), ('密', '篇')])
# OrderedDict([('人脑', '加工'), ('sub-concept', 'sub-concept'), ('密', '看法')])
# OrderedDict([('人脑', '高'), ('sub-concept', 'sub-concept'), ('密', '指')])
# OrderedDict([('人脑', '用于'), ('sub-concept', 'sub-concept'), ('密', '称')])
# OrderedDict([('人脑', '编辑'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '中'), ('sub-concept', 'sub-concept'), ('密', '固定')])
# OrderedDict([('人脑', '统计'), ('sub-concept', 'sub-concept'), ('密', '少')])
# OrderedDict([('人脑', '家'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '年月'), ('sub-concept', 'sub-concept'), ('密', '手写')])
# OrderedDict([('人脑', '再版'), ('sub-concept', 'sub-concept'), ('密', '材料')])
# OrderedDict([('人脑', '瞬时性'), ('sub-concept', 'sub-concept'), ('密', '两')])
# OrderedDict([('人脑', '相关'), ('sub-concept', 'sub-concept'), ('密', '含义')])
# OrderedDict([('人脑', '成果'), ('sub-concept', 'sub-concept'), ('密', '出版物')])
# OrderedDict([('人脑', '年'), ('sub-concept', 'sub-concept'), ('密', '固定')])
# OrderedDict([('人脑', '培养'), ('sub-concept', 'sub-concept'), ('密', '名称')])
# OrderedDict([('人脑', '资源'), ('sub-concept', 'sub-concept'), ('密', '材料')])
# OrderedDict([('人脑', '技术'), ('sub-concept', 'sub-concept'), ('密', '居多')])
# OrderedDict([('人脑', '实物'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '要点'), ('sub-concept', 'sub-concept'), ('密', '含义')])
# OrderedDict([('人脑', '单位'), ('sub-concept', 'sub-concept'), ('密', '篇')])
# OrderedDict([('人脑', '高'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', 'n2'), ('sub-concept', 'sub-concept'), ('密', '手段')])
# OrderedDict([('人脑', '包含'), ('sub-concept', 'sub-concept'), ('密', '客观')])
# OrderedDict([('人脑', '发现'), ('sub-concept', 'sub-concept'), ('密', '般')])
# OrderedDict([('人脑', '引用率'), ('sub-concept', 'sub-concept'), ('密', '材料')])
# OrderedDict([('人脑', '文件'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '可靠'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '含有'), ('sub-concept', 'sub-concept'), ('密', '周期')])
# OrderedDict([('人脑', '年'), ('sub-concept', 'sub-concept'), ('密', '续')])
# OrderedDict([('人脑', '观点'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '存贮'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '超过'), ('sub-concept', 'sub-concept'), ('密', '包括')])
# OrderedDict([('人脑', '共'), ('sub-concept', 'sub-concept'), ('密', '期')])
# OrderedDict([('人脑', '要点'), ('sub-concept', 'sub-concept'), ('密', '看法')])
# OrderedDict([('人脑', '论文'), ('sub-concept', 'sub-concept'), ('密', '思考')])
# OrderedDict([('人脑', '书目'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '流通'), ('sub-concept', 'sub-concept'), ('密', '复制')])
# OrderedDict([('人脑', '225'), ('sub-concept', 'sub-concept'), ('密', '周期')])
# OrderedDict([('人脑', '重点'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '成果'), ('sub-concept', 'sub-concept'), ('密', '登载')])
# OrderedDict([('人脑', '判别'), ('sub-concept', 'sub-concept'), ('密', '题')])
# OrderedDict([('人脑', 'n2'), ('sub-concept', 'sub-concept'), ('密', '卷')])
# OrderedDict([('人脑', '极'), ('sub-concept', 'sub-concept'), ('密', '载体')])
# OrderedDict([('人脑', '信息'), ('sub-concept', 'sub-concept'), ('密', '出版物')])
# OrderedDict([('人脑', '中'), ('sub-concept', 'sub-concept'), ('密', '超过')])
# OrderedDict([('人脑', '类型'), ('sub-concept', 'sub-concept'), ('密', '集合')])
# OrderedDict([('人脑', '统计'), ('sub-concept', 'sub-concept'), ('密', '统一')])
# OrderedDict([('人脑', '指向性'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '加工'), ('sub-concept', 'sub-concept'), ('密', '含义')])
# OrderedDict([('人脑', '表述'), ('sub-concept', 'sub-concept'), ('密', '要素')])
# OrderedDict([('人脑', '政府'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '名称'), ('sub-concept', 'sub-concept'), ('密', '材料')])
# OrderedDict([('人脑', '核心'), ('sub-concept', 'sub-concept'), ('密', '统一')])
# OrderedDict([('人脑', '10'), ('sub-concept', 'sub-concept'), ('密', '年')])
# OrderedDict([('人脑', '倍'), ('sub-concept', 'sub-concept'), ('密', '篇')])
# OrderedDict([('人脑', '重点'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '出版物'), ('sub-concept', 'sub-concept'), ('密', '种类')])
# OrderedDict([('人脑', '统计'), ('sub-concept', 'sub-concept'), ('密', '极')])
# OrderedDict([('人脑', '宣传品'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '永久'), ('sub-concept', 'sub-concept'), ('密', '两')])
# OrderedDict([('人脑', '瞬时性'), ('sub-concept', 'sub-concept'), ('密', '称')])
# OrderedDict([('人脑', '各期'), ('sub-concept', 'sub-concept'), ('密', '手写')])
# OrderedDict([('人脑', '潜在性'), ('sub-concept', 'sub-concept'), ('密', '特性')])
# OrderedDict([('人脑', '镜像'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '失真'), ('sub-concept', 'sub-concept'), ('密', '称')])
# OrderedDict([('人脑', '解'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', 'n'), ('sub-concept', 'sub-concept'), ('密', '纸张')])
# OrderedDict([('人脑', '印刷型'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '49'), ('sub-concept', 'sub-concept'), ('密', '期')])
# OrderedDict([('人脑', '实力'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '利用率'), ('sub-concept', 'sub-concept'), ('密', '纸张')])
# OrderedDict([('人脑', 'DOE'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '排序'), ('sub-concept', 'sub-concept'), ('密', '版式')])
# OrderedDict([('人脑', '布拉德福'), ('sub-concept', 'sub-concept'), ('密', '固定')])
# OrderedDict([('人脑', '学科'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '门'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '指'), ('sub-concept', 'sub-concept'), ('密', '图书')])
# OrderedDict([('人脑', '技术'), ('sub-concept', 'sub-concept'), ('密', '少')])
# OrderedDict([('人脑', '媒体'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '纸张'), ('sub-concept', 'sub-concept'), ('密', '两')])
# OrderedDict([('人脑', '发现'), ('sub-concept', 'sub-concept'), ('密', '文章')])
# OrderedDict([('人脑', '国会'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '完整'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '协议'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '永久'), ('sub-concept', 'sub-concept'), ('密', '密')])
# OrderedDict([('人脑', '承载'), ('sub-concept', 'sub-concept'), ('密', '分')])
# OrderedDict([('人脑', '复制'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '名称'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '登载'), ('sub-concept', 'sub-concept'), ('密', '期刊')])
# OrderedDict([('人脑', '文献'), ('sub-concept', 'sub-concept'), ('密', '出版')])
# OrderedDict([('人脑', '检索'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '意识'), ('sub-concept', 'sub-concept'), ('密', '要素')])
# OrderedDict([('人脑', '搜集'), ('sub-concept', 'sub-concept'), ('密', '定期')])
# OrderedDict([('人脑', '含量'), ('sub-concept', 'sub-concept'), ('密', '记录')])
# OrderedDict([('人脑', '培养'), ('sub-concept', 'sub-concept'), ('密', '各期')])
# OrderedDict([('人脑', '人类'), ('sub-concept', 'sub-concept'), ('密', '多种')])
# OrderedDict([('人脑', ' '), ('sub-concept', 'sub-concept'), ('密', '连续')])
# OrderedDict([('人脑', '年'), ('sub-concept', 'sub-concept'), ('密', '超过')])
# OrderedDict([('人脑', '非密'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '点击'), ('sub-concept', 'sub-concept'), ('密', '种类')])
# OrderedDict([('人脑', '培养'), ('sub-concept', 'sub-concept'), ('密', '登载')])
# OrderedDict([('人脑', '49'), ('sub-concept', 'sub-concept'), ('密', '再版')])
# OrderedDict([('人脑', 'p'), ('sub-concept', 'sub-concept'), ('密', '集合')])
# OrderedDict([('人脑', '技术'), ('sub-concept', 'sub-concept'), ('密', '年')])
# OrderedDict([('人脑', '284'), ('sub-concept', 'sub-concept'), ('密', '各期')])
# OrderedDict([('人脑', '重复'), ('sub-concept', 'sub-concept'), ('密', '复制')])
# OrderedDict([('人脑', '含有'), ('sub-concept', 'sub-concept'), ('密', '定期')])
# OrderedDict([('人脑', '分布'), ('sub-concept', 'sub-concept'), ('密', '复制')])
# OrderedDict([('人脑', '定律'), ('sub-concept', 'sub-concept'), ('密', '手写')])
# OrderedDict([('人脑', '学科'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '刊载'), ('sub-concept', 'sub-concept'), ('密', '指')])
# OrderedDict([('人脑', '利用率'), ('sub-concept', 'sub-concept'), ('密', '材料')])
# OrderedDict([('人脑', '推销'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '口头'), ('sub-concept', 'sub-concept'), ('密', '载体')])
# OrderedDict([('人脑', '重点'), ('sub-concept', 'sub-concept'), ('密', '纸张')])
# OrderedDict([('人脑', 'n倍'), ('sub-concept', 'sub-concept'), ('密', '出版物')])
# OrderedDict([('人脑', '布拉德福'), ('sub-concept', 'sub-concept'), ('密', '手段')])
# OrderedDict([('人脑', '家'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '知识'), ('sub-concept', 'sub-concept'), ('密', '密')])
# OrderedDict([('人脑', '期刊'), ('sub-concept', 'sub-concept'), ('密', '重复')])
# OrderedDict([('人脑', '作用'), ('sub-concept', 'sub-concept'), ('密', '各期')])
# OrderedDict([('人脑', '卷'), ('sub-concept', 'sub-concept'), ('密', '印刷')])
# OrderedDict([('人脑', '流通'), ('sub-concept', 'sub-concept'), ('密', '指')])
# OrderedDict([('人脑', 'n2'), ('sub-concept', 'sub-concept'), ('密', '定期')])
# OrderedDict([('人脑', '文献'), ('sub-concept', 'sub-concept'), ('密', '纸张')])
# OrderedDict([('人脑', '作用'), ('sub-concept', 'sub-concept'), ('密', '连续')])
# OrderedDict([('人脑', 'n2'), ('sub-concept', 'sub-concept'), ('密', '包括')])
# OrderedDict([('人脑', '发明'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '文献'), ('sub-concept', 'sub-concept'), ('密', '文章')])
# OrderedDict([('人脑', '成就'), ('sub-concept', 'sub-concept'), ('密', '周期')])
# OrderedDict([('人脑', '决策'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '再生性'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '针对性'), ('sub-concept', 'sub-concept'), ('密', '类')])
# OrderedDict([('人脑', 'n倍'), ('sub-concept', 'sub-concept'), ('密', '居多')])
# OrderedDict([('人脑', '密级'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '宣传品'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '登载'), ('sub-concept', 'sub-concept'), ('密', '集合')])
# OrderedDict([('人脑', '课题'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '含有'), ('sub-concept', 'sub-concept'), ('密', '固定')])
# OrderedDict([('人脑', '49'), ('sub-concept', 'sub-concept'), ('密', '出版')])
# OrderedDict([('人脑', '指'), ('sub-concept', 'sub-concept'), ('密', '类')])
# OrderedDict([('人脑', '语言'), ('sub-concept', 'sub-concept'), ('密', '分')])
# OrderedDict([('人脑', '定期'), ('sub-concept', 'sub-concept'), ('密', '印刷')])
# OrderedDict([('人脑', '284'), ('sub-concept', 'sub-concept'), ('密', '篇')])
# OrderedDict([('人脑', '出版物'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '社会'), ('sub-concept', 'sub-concept'), ('密', '多种')])
# OrderedDict([('人脑', '定'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '学术'), ('sub-concept', 'sub-concept'), ('密', '重复')])
# OrderedDict([('人脑', '媒体'), ('sub-concept', 'sub-concept'), ('密', '要素')])
# OrderedDict([('人脑', '前'), ('sub-concept', 'sub-concept'), ('密', '统一')])
# OrderedDict([('人脑', '推销'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '定义'), ('sub-concept', 'sub-concept'), ('密', '指')])
# OrderedDict([('人脑', '研究'), ('sub-concept', 'sub-concept'), ('密', '续')])
# OrderedDict([('人脑', '文字'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '搜集'), ('sub-concept', 'sub-concept'), ('密', '连续')])
# OrderedDict([('人脑', '随意性'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '有限'), ('sub-concept', 'sub-concept'), ('密', '称')])
# OrderedDict([('人脑', '10'), ('sub-concept', 'sub-concept'), ('密', '少')])
# OrderedDict([('人脑', '长'), ('sub-concept', 'sub-concept'), ('密', '手段')])
# OrderedDict([('人脑', '加工'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', ' '), ('sub-concept', 'sub-concept'), ('密', '定期')])
# OrderedDict([('人脑', '即P'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '大型'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '机构'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '提取'), ('sub-concept', 'sub-concept'), ('密', '两')])
# OrderedDict([('人脑', '共'), ('sub-concept', 'sub-concept'), ('密', '般')])
# OrderedDict([('人脑', '学科'), ('sub-concept', 'sub-concept'), ('密', '集合')])
# OrderedDict([('人脑', '光波'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '政府'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '含有'), ('sub-concept', 'sub-concept'), ('密', '连续')])
# OrderedDict([('人脑', '存放'), ('sub-concept', 'sub-concept'), ('密', '种类')])
# OrderedDict([('人脑', '性质'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '学术'), ('sub-concept', 'sub-concept'), ('密', '少')])
# OrderedDict([('人脑', '数量'), ('sub-concept', 'sub-concept'), ('密', '篇')])
# OrderedDict([('人脑', '称为'), ('sub-concept', 'sub-concept'), ('密', '集合')])
# OrderedDict([('人脑', '225'), ('sub-concept', 'sub-concept'), ('密', '连续')])
# OrderedDict([('人脑', '科学技术'), ('sub-concept', 'sub-concept'), ('密', '少')])
# OrderedDict([('人脑', 'n'), ('sub-concept', 'sub-concept'), ('密', '指')])
# OrderedDict([('人脑', '文献'), ('sub-concept', 'sub-concept'), ('密', '载体')])
# OrderedDict([('人脑', '记录'), ('sub-concept', 'sub-concept'), ('密', '密')])
# OrderedDict([('人脑', 'n倍'), ('sub-concept', 'sub-concept'), ('密', '少')])
# OrderedDict([('人脑', '研究'), ('sub-concept', 'sub-concept'), ('密', '统一')])
# OrderedDict([('人脑', '成果'), ('sub-concept', 'sub-concept'), ('密', '出版')])
# OrderedDict([('人脑', '区域'), ('sub-concept', 'sub-concept'), ('密', '材料')])
# OrderedDict([('人脑', '共'), ('sub-concept', 'sub-concept'), ('密', '各期')])
# OrderedDict([('人脑', 'n2'), ('sub-concept', 'sub-concept'), ('密', '连续')])
# OrderedDict([('人脑', '定期'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '续'), ('sub-concept', 'sub-concept'), ('密', '指')])
# OrderedDict([('人脑', '作用'), ('sub-concept', 'sub-concept'), ('密', '定期')])
# OrderedDict([('人脑', '书目'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '信息'), ('sub-concept', 'sub-concept'), ('密', '图书')])
# OrderedDict([('人脑', '有用'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '数据库'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '即P'), ('sub-concept', 'sub-concept'), ('密', '手写')])
# OrderedDict([('人脑', '确认'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '代号'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '结论'), ('sub-concept', 'sub-concept'), ('密', '期')])
# OrderedDict([('人脑', '共'), ('sub-concept', 'sub-concept'), ('密', '登载')])
# OrderedDict([('人脑', '数量'), ('sub-concept', 'sub-concept'), ('密', '各期')])
# OrderedDict([('人脑', '规章制度'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '有限'), ('sub-concept', 'sub-concept'), ('密', '类')])
# OrderedDict([('人脑', '顺序号'), ('sub-concept', 'sub-concept'), ('密', '复制')])
# OrderedDict([('人脑', '历史'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '准确'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '两'), ('sub-concept', 'sub-concept'), ('密', '内容')])
# OrderedDict([('人脑', '足'), ('sub-concept', 'sub-concept'), ('密', '称')])
# OrderedDict([('人脑', '统计'), ('sub-concept', 'sub-concept'), ('密', '篇')])
# OrderedDict([('人脑', '结论'), ('sub-concept', 'sub-concept'), ('密', '居多')])
# OrderedDict([('人脑', '发行'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '核心'), ('sub-concept', 'sub-concept'), ('密', '篇')])
# OrderedDict([('人脑', '若干'), ('sub-concept', 'sub-concept'), ('密', '固定')])
# OrderedDict([('人脑', '称为'), ('sub-concept', 'sub-concept'), ('密', '纸张')])
# OrderedDict([('人脑', 'DOE'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '感知'), ('sub-concept', 'sub-concept'), ('密', '种类')])
# OrderedDict([('人脑', '登载'), ('sub-concept', 'sub-concept'), ('密', '卷')])
# OrderedDict([('人脑', '磁带'), ('sub-concept', 'sub-concept'), ('密', '密')])
# OrderedDict([('人脑', '包含'), ('sub-concept', 'sub-concept'), ('密', '极')])
# OrderedDict([('人脑', '随意性'), ('sub-concept', 'sub-concept'), ('密', '含义')])
# OrderedDict([('人脑', '225'), ('sub-concept', 'sub-concept'), ('密', '卷')])
# OrderedDict([('人脑', '含有'), ('sub-concept', 'sub-concept'), ('密', '超过')])
# OrderedDict([('人脑', '资源'), ('sub-concept', 'sub-concept'), ('密', '纸张')])
# OrderedDict([('人脑', '媒介'), ('sub-concept', 'sub-concept'), ('密', '要素')])
# OrderedDict([('人脑', '保存'), ('sub-concept', 'sub-concept'), ('密', '含义')])
# ...
# OrderedDict([('人脑', '重复'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '文献'), ('sub-concept', 'sub-concept'), ('密', '分')])
# OrderedDict([('人脑', '语言'), ('sub-concept', 'sub-concept'), ('密', '称')])
# OrderedDict([('人脑', '什'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '两'), ('sub-concept', 'sub-concept'), ('密', '版式')])
# OrderedDict([('人脑', '读者'), ('sub-concept', 'sub-concept'), ('密', '集合')])
# OrderedDict([('人脑', '若干'), ('sub-concept', 'sub-concept'), ('密', '年')])
# OrderedDict([('人脑', '各期'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '用户'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '类型'), ('sub-concept', 'sub-concept'), ('密', '种类')])
# OrderedDict([('人脑', '文献'), ('sub-concept', 'sub-concept'), ('密', '固定')])
# OrderedDict([('人脑', '内容'), ('sub-concept', 'sub-concept'), ('密', '记录')])
# OrderedDict([('人脑', '统计'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '居多'), ('sub-concept', 'sub-concept'), ('密', '集合')])
# OrderedDict([('人脑', '含有'), ('sub-concept', 'sub-concept'), ('密', '年')])
# OrderedDict([('人脑', '信息'), ('sub-concept', 'sub-concept'), ('密', '记录')])
# OrderedDict([('人脑', '学术'), ('sub-concept', 'sub-concept'), ('密', '期')])
# OrderedDict([('人脑', '发展'), ('sub-concept', 'sub-concept'), ('密', '材料')])
# OrderedDict([('人脑', '媒介'), ('sub-concept', 'sub-concept'), ('密', '看法')])
# OrderedDict([('人脑', '225'), ('sub-concept', 'sub-concept'), ('密', '年')])
# OrderedDict([('人脑', '读者'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '文献'), ('sub-concept', 'sub-concept'), ('密', '名称')])
# OrderedDict([('人脑', '版式'), ('sub-concept', 'sub-concept'), ('密', '手写')])
# OrderedDict([('人脑', '卷'), ('sub-concept', 'sub-concept'), ('密', '手写')])
# OrderedDict([('人脑', '资料'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '合作'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '排序'), ('sub-concept', 'sub-concept'), ('密', '年月')])
# OrderedDict([('人脑', '少'), ('sub-concept', 'sub-concept'), ('密', '集合')])
# OrderedDict([('人脑', '寿命'), ('sub-concept', 'sub-concept'), ('密', '纸张')])
# OrderedDict([('人脑', '书刊'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '权限'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '信息'), ('sub-concept', 'sub-concept'), ('密', '种类')])
# OrderedDict([('人脑', '知识'), ('sub-concept', 'sub-concept'), ('密', '类')])
# OrderedDict([('人脑', '学科'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '加工'), ('sub-concept', 'sub-concept'), ('密', '载体')])
# OrderedDict([('人脑', '电子型'), ('sub-concept', 'sub-concept'), ('密', '种类')])
# OrderedDict([('人脑', '提取'), ('sub-concept', 'sub-concept'), ('密', '称')])
# OrderedDict([('人脑', 'n2'), ('sub-concept', 'sub-concept'), ('密', '期刊')])
# OrderedDict([('人脑', '记载'), ('sub-concept', 'sub-concept'), ('密', '续')])
# OrderedDict([('人脑', '年'), ('sub-concept', 'sub-concept'), ('密', '文章')])
# OrderedDict([('人脑', '数量'), ('sub-concept', 'sub-concept'), ('密', '超过')])
# OrderedDict([('人脑', '著名'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '称'), ('sub-concept', 'sub-concept'), ('密', '集合')])
# OrderedDict([('人脑', '流行'), ('sub-concept', 'sub-concept'), ('密', '多种')])
# OrderedDict([('人脑', '重复'), ('sub-concept', 'sub-concept'), ('密', '手写')])
# OrderedDict([('人脑', '报告'), ('sub-concept', 'sub-concept'), ('密', '题')])
# OrderedDict([('人脑', '文献'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '载体'), ('sub-concept', 'sub-concept'), ('密', '两')])
# OrderedDict([('人脑', '搜集'), ('sub-concept', 'sub-concept'), ('密', '重复')])
# OrderedDict([('人脑', '提供'), ('sub-concept', 'sub-concept'), ('密', '客观')])
# OrderedDict([('人脑', '再版'), ('sub-concept', 'sub-concept'), ('密', '指')])
# OrderedDict([('人脑', '年月'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '加工'), ('sub-concept', 'sub-concept'), ('密', '类')])
# OrderedDict([('人脑', '学术'), ('sub-concept', 'sub-concept'), ('密', '登载')])
# OrderedDict([('人脑', '49'), ('sub-concept', 'sub-concept'), ('密', '卷')])
# OrderedDict([('人脑', '寿命'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '过程'), ('sub-concept', 'sub-concept'), ('密', '印刷')])
# OrderedDict([('人脑', '题'), ('sub-concept', 'sub-concept'), ('密', '建设')])
# OrderedDict([('人脑', '反馈'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '人脑'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '284'), ('sub-concept', 'sub-concept'), ('密', '超过')])
# OrderedDict([('人脑', '研究'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '论文'), ('sub-concept', 'sub-concept'), ('密', '内容')])
# OrderedDict([('人脑', '社会'), ('sub-concept', 'sub-concept'), ('密', '含义')])
# OrderedDict([('人脑', '核心'), ('sub-concept', 'sub-concept'), ('密', '期刊')])
# OrderedDict([('人脑', '类型'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '机构'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '发现'), ('sub-concept', 'sub-concept'), ('密', '版式')])
# OrderedDict([('人脑', '水平'), ('sub-concept', 'sub-concept'), ('密', '材料')])
# OrderedDict([('人脑', '概述'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '代表'), ('sub-concept', 'sub-concept'), ('密', '复制')])
# OrderedDict([('人脑', '技术'), ('sub-concept', 'sub-concept'), ('密', '周期')])
# OrderedDict([('人脑', '被摘率'), ('sub-concept', 'sub-concept'), ('密', '复制')])
# OrderedDict([('人脑', ' '), ('sub-concept', 'sub-concept'), ('密', '名称')])
# OrderedDict([('人脑', '链接'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '指'), ('sub-concept', 'sub-concept'), ('密', '两')])
# OrderedDict([('人脑', '单位'), ('sub-concept', 'sub-concept'), ('密', '定期')])
# OrderedDict([('人脑', '瞬时性'), ('sub-concept', 'sub-concept'), ('密', '密')])
# OrderedDict([('人脑', '媒体'), ('sub-concept', 'sub-concept'), ('密', '含义')])
# OrderedDict([('人脑', '年月'), ('sub-concept', 'sub-concept'), ('密', '包括')])
# OrderedDict([('人脑', '撰写'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '出版物'), ('sub-concept', 'sub-concept'), ('密', '纸张')])
# OrderedDict([('人脑', '区域'), ('sub-concept', 'sub-concept'), ('密', '出版')])
# OrderedDict([('人脑', '会议'), ('sub-concept', 'sub-concept'), ('密', '种类')])
# OrderedDict([('人脑', '标准'), ('sub-concept', 'sub-concept'), ('密', '记录')])
# OrderedDict([('人脑', '论文'), ('sub-concept', 'sub-concept'), ('密', '作者')])
# OrderedDict([('人脑', '资源'), ('sub-concept', 'sub-concept'), ('密', '分')])
# OrderedDict([('人脑', '登载'), ('sub-concept', 'sub-concept'), ('密', '手写')])
# OrderedDict([('人脑', '资源'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '排序'), ('sub-concept', 'sub-concept'), ('密', '年')])
# OrderedDict([('人脑', '搜集'), ('sub-concept', 'sub-concept'), ('密', '居多')])
# OrderedDict([('人脑', '成就'), ('sub-concept', 'sub-concept'), ('密', '居多')])
# OrderedDict([('人脑', '磁盘'), ('sub-concept', 'sub-concept'), ('密', '两')])
# OrderedDict([('人脑', '真实性'), ('sub-concept', 'sub-concept'), ('密', '特征')])
# OrderedDict([('人脑', '记载'), ('sub-concept', 'sub-concept'), ('密', '登载')])
# OrderedDict([('人脑', '数量'), ('sub-concept', 'sub-concept'), ('密', '少')])
# OrderedDict([('人脑', '论文'), ('sub-concept', 'sub-concept'), ('密', '统一')])
# OrderedDict([('人脑', '倍'), ('sub-concept', 'sub-concept'), ('密', '再版')])
# OrderedDict([('人脑', '重复'), ('sub-concept', 'sub-concept'), ('密', '载体')])
# OrderedDict([('人脑', '记载'), ('sub-concept', 'sub-concept'), ('密', '各期')])
# OrderedDict([('人脑', '核心'), ('sub-concept', 'sub-concept'), ('密', '手段')])
# OrderedDict([('人脑', '表现'), ('sub-concept', 'sub-concept'), ('密', '客观')])
# OrderedDict([('人脑', '美国'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '传递'), ('sub-concept', 'sub-concept'), ('密', '周期')])
# OrderedDict([('人脑', '登载'), ('sub-concept', 'sub-concept'), ('密', '续')])
# OrderedDict([('人脑', '区域'), ('sub-concept', 'sub-concept'), ('密', '般')])
# OrderedDict([('人脑', '分类表'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '期刊'), ('sub-concept', 'sub-concept'), ('密', '集合')])
# OrderedDict([('人脑', '引用率'), ('sub-concept', 'sub-concept'), ('密', '复制')])
# OrderedDict([('人脑', '两'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '载体'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '保存'), ('sub-concept', 'sub-concept'), ('密', '载体')])
# OrderedDict([('人脑', '排序'), ('sub-concept', 'sub-concept'), ('密', '少')])
# OrderedDict([('人脑', '流通'), ('sub-concept', 'sub-concept'), ('密', '材料')])
# OrderedDict([('人脑', '49'), ('sub-concept', 'sub-concept'), ('密', '版式')])
# OrderedDict([('人脑', '研究'), ('sub-concept', 'sub-concept'), ('密', '重复')])
# OrderedDict([('人脑', '作用'), ('sub-concept', 'sub-concept'), ('密', '年月')])
# OrderedDict([('人脑', '硬载体'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '再版'), ('sub-concept', 'sub-concept'), ('密', '集合')])
# OrderedDict([('人脑', '培养'), ('sub-concept', 'sub-concept'), ('密', '再版')])
# OrderedDict([('人脑', '电'), ('sub-concept', 'sub-concept'), ('密', '极')])
# OrderedDict([('人脑', '数量'), ('sub-concept', 'sub-concept'), ('密', '年')])
# OrderedDict([('人脑', '49'), ('sub-concept', 'sub-concept'), ('密', '登载')])
# OrderedDict([('人脑', 'n2'), ('sub-concept', 'sub-concept'), ('密', '作者')])
# OrderedDict([('人脑', '寿命'), ('sub-concept', 'sub-concept'), ('密', '记录')])
# OrderedDict([('人脑', '正式'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '进展期'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '成果'), ('sub-concept', 'sub-concept'), ('密', '超过')])
# OrderedDict([('人脑', '负担'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '知识'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '隐蔽'), ('sub-concept', 'sub-concept'), ('密', '客观')])
# OrderedDict([('人脑', '电'), ('sub-concept', 'sub-concept'), ('密', '期')])
# OrderedDict([('人脑', '论文'), ('sub-concept', 'sub-concept'), ('密', '重复')])
# OrderedDict([('人脑', '单位'), ('sub-concept', 'sub-concept'), ('密', '再版')])
# OrderedDict([('人脑', '信息源'), ('sub-concept', 'sub-concept'), ('密', '含义')])
# OrderedDict([('人脑', '种类'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '图'), ('sub-concept', 'sub-concept'), ('密', '记录')])
# OrderedDict([('人脑', '判别'), ('sub-concept', 'sub-concept'), ('密', '手段')])
# OrderedDict([('人脑', '获取'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '内容'), ('sub-concept', 'sub-concept'), ('密', '纸张')])
# OrderedDict([('人脑', '内容'), ('sub-concept', 'sub-concept'), ('密', '客观')])
# OrderedDict([('人脑', '定义'), ('sub-concept', 'sub-concept'), ('密', '分')])
# OrderedDict([('人脑', '信息源'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '单位'), ('sub-concept', 'sub-concept'), ('密', '连续')])
# OrderedDict([('人脑', '期'), ('sub-concept', 'sub-concept'), ('密', '载体')])
# OrderedDict([('人脑', '检阅'), ('sub-concept', 'sub-concept'), ('密', '年月')])
# OrderedDict([('人脑', '研究'), ('sub-concept', 'sub-concept'), ('密', '文章')])
# OrderedDict([('人脑', '文献'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '情况'), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '宣读'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '技术'), ('sub-concept', 'sub-concept'), ('密', '定期')])
# OrderedDict([('人脑', '学科'), ('sub-concept', 'sub-concept'), ('密', '版式')])
# OrderedDict([('人脑', '指'), ('sub-concept', 'sub-concept'), ('密', '集合')])
# OrderedDict([('人脑', '成果'), ('sub-concept', 'sub-concept'), ('密', '各期')])
# OrderedDict([('人脑', '用于'), ('sub-concept', 'sub-concept'), ('密', '载体')])
# OrderedDict([('人脑', '般'), ('sub-concept', 'sub-concept'), ('密', '印刷')])
# OrderedDict([('人脑', '284'), ('sub-concept', 'sub-concept'), ('密', '年')])
# OrderedDict([('人脑', '49'), ('sub-concept', 'sub-concept'), ('密', '超过')])
# OrderedDict([('人脑', '结论'), ('sub-concept', 'sub-concept'), ('密', '名称')])
# OrderedDict([('人脑', '区域'), ('sub-concept', 'sub-concept'), ('密', '期刊')])
# OrderedDict([('人脑', '重复'), ('sub-concept', 'sub-concept'), ('密', '纸张')])
# OrderedDict([('人脑', '学术性'), ('sub-concept', 'sub-concept'), ('密', '再版')])
# OrderedDict([('人脑', '社会'), ('sub-concept', 'sub-concept'), ('密', '种类')])
# OrderedDict([('人脑', '标准'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '机构'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '冗余性'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '水平'), ('sub-concept', 'sub-concept'), ('密', '指')])
# OrderedDict([('人脑', ' '), ('sub-concept', 'sub-concept'), ('密', '印刷')])
# OrderedDict([('人脑', '信息'), ('sub-concept', 'sub-concept'), ('密', '超过')])
# OrderedDict([('人脑', '综合国'), ('sub-concept', 'sub-concept'), ('密', '含义')])
# OrderedDict([('人脑', '利用'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '包含'), ('sub-concept', 'sub-concept'), ('密', '两')])
# OrderedDict([('人脑', '电'), ('sub-concept', 'sub-concept'), ('密', '少')])
# OrderedDict([('人脑', '名称'), ('sub-concept', 'sub-concept'), ('密', '集合')])
# OrderedDict([('人脑', '含义'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '检阅'), ('sub-concept', 'sub-concept'), ('密', '出版')])
# OrderedDict([('人脑', '作用'), ('sub-concept', 'sub-concept'), ('密', '思考')])
# OrderedDict([('人脑', '纸张'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '卷'), ('sub-concept', 'sub-concept'), ('密', '纸张')])
# OrderedDict([('人脑', '论文'), ('sub-concept', 'sub-concept'), ('密', '集合')])
# OrderedDict([('人脑', '信息'), ('sub-concept', 'sub-concept'), ('密', '居多')])
# OrderedDict([('人脑', '内容'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', '光盘'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '包含'), ('sub-concept', 'sub-concept'), ('密', '含义')])
# OrderedDict([('人脑', '保存'), ('sub-concept', 'sub-concept'), ('密', '分')])
# OrderedDict([('人脑', '中'), ('sub-concept', 'sub-concept'), ('密', '文章')])
# OrderedDict([('人脑', '出版'), ('sub-concept', 'sub-concept'), ('密', '复制')])
# OrderedDict([('人脑', '重复'), ('sub-concept', 'sub-concept'), ('密', '材料')])
# OrderedDict([('人脑', '统一'), ('sub-concept', 'sub-concept'), ('密', '载体')])
# OrderedDict([('人脑', '再版'), ('sub-concept', 'sub-concept'), ('密', '包括')])
# OrderedDict([('人脑', '中'), ('sub-concept', 'sub-concept'), ('密', '少')])
# OrderedDict([('人脑', '共'), ('sub-concept', 'sub-concept'), ('密', '年月')])
# OrderedDict([('人脑', '倍'), ('sub-concept', 'sub-concept'), ('密', '登载')])
# OrderedDict([('人脑', '政务'), ('sub-concept', 'sub-concept'), ('密', '类型')])
# OrderedDict([('人脑', '数量'), ('sub-concept', 'sub-concept'), ('密', '极')])
# OrderedDict([('人脑', '利用率'), ('sub-concept', 'sub-concept'), ('密', '复制')])
# OrderedDict([('人脑', '前'), ('sub-concept', 'sub-concept'), ('密', '出版物')])
# OrderedDict([('人脑', '政策'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '文献'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '极'), ('sub-concept', 'sub-concept'), ('密', '包括')])
# OrderedDict([('人脑', '研究'), ('sub-concept', 'sub-concept'), ('密', '顺序号')])
# OrderedDict([('人脑', '科学技术'), ('sub-concept', 'sub-concept'), ('密', '出版物')])
# OrderedDict([('人脑', '区域'), ('sub-concept', 'sub-concept'), ('密', '名称')])
# OrderedDict([('人脑', '利用'), ('sub-concept', 'sub-concept'), ('密', '客观')])
# OrderedDict([('人脑', '各期'), ('sub-concept', 'sub-concept'), ('密', '包括')])
# OrderedDict([('人脑', '核心'), ('sub-concept', 'sub-concept'), ('密', '思考')])
# OrderedDict([('人脑', '状态'), ('sub-concept', 'sub-concept'), ('密', '种类')])
# OrderedDict([('人脑', '对象'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '定期'), ('sub-concept', 'sub-concept'), ('密', '纸张')])
# OrderedDict([('人脑', ' '), ('sub-concept', 'sub-concept'), ('密', '纸质')])
# OrderedDict([('人脑', '狭义'), ('sub-concept', 'sub-concept'), ('密', '信息')])
# OrderedDict([('人脑', '连续'), ('sub-concept', 'sub-concept'), ('密', '媒体')])
# OrderedDict([('人脑', 'p'), ('sub-concept', 'sub-concept'), ('密', '印刷')])
# OrderedDict([('人脑', '技术'), ('sub-concept', 'sub-concept'), ('密', '连续')])
# OrderedDict([('人脑', '引用率'), ('sub-concept', 'sub-concept'), ('密', '指')])
# OrderedDict([('人脑', '年'), ('sub-concept', 'sub-concept'), ('密', '指')])
# OrderedDict([('人脑', '研究'), ('sub-concept', 'sub-concept'), ('密', '般')])
# OrderedDict([('人脑', '各期'), ('sub-concept', 'sub-concept'), ('密', '资源')])
# OrderedDict([('人脑', '倍'), ('sub-concept', 'sub-concept'), ('密', '少')])
