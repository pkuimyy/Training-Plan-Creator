# %%
import sys
sys.path.append(".")
from doctree import node

# %%
# text_tuple_list = []
# for line in text_list:
#     if not pattern_all.match(line):
#         text_tuple_list.append((line,0))
#     for i in range(len(pattern)):
#         if pattern[i].match(line):
#             text_tuple_list.append((re.sub(pstring[i],"",line),i+1))

# myprint(text_tuple_list)

# %% [markdown]
# 根据上面正则表达式确定的规则，给句子标记等级，一般文本等级为0。
# 序号的前后顺序是无关的，因此可以去掉。
# 在这个时候的结果中，仍然有带有序号的项目，但是数量太少，不多考虑，在分词的环节有很大几率会被筛掉。

# %%
# for s,r in text_tuple_list:
#     if r == 0:
#         pass
#     else:
#         print(r)

# root = node()

# tmp = node()
# tmp.add_data(text_tuple_list[0][0])
# tmp.set_father(root)
# root.add_child(tmp)
# cur = tmp

# for i in range(len(text_tuple_list)-1):        
#     s1,r1 = text_tuple_list[i]
#     s2,r2 = text_tuple_list[i+1]
#     if r2 == 0:
#         cur.add_data(s2)
#     elif r2 > r1:
#         tmp = node()
#         tmp.add_data(s2)
#         tmp.set_father(cur)
#         cur.add_child(tmp)

# root.print_all()
